# %% [markdown]
# # Initial Prep

# %% [markdown]
# ## Library Import

# %%
from ast import literal_eval
import math
import os
import re
import warnings

import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
warnings.filterwarnings(action= 'ignore')

# %% [markdown]
# ## Connect to Drive

# %%
# from google.colab import drive

# drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ### Copy Files from Drive

# %%
# !mkdir update_changes/
# !mkdir update_changes/tw/
# !mkdir update_changes/tw/20220808
# !mkdir update_changes/tw/20220808/cleaned
# !mkdir update_changes/20220808/
# !mkdir update_changes/20220808/parsed

# !cp -r /content/drive/MyDrive/update_changes/tw/20220808/cleaned/* ./update_changes/tw/20220808/cleaned/

# %% [markdown]
# ## Folder Prep

# %%
APK_DATE = "20220808"
MAIN_DIR = "./update_changes/tw"
MAIN_CLEANED_DIR = f"{MAIN_DIR}/{APK_DATE}/cleaned"
MAIN_PARSED_DIR = f"./update_changes/{APK_DATE}/parsed"

if not os.path.isdir(MAIN_PARSED_DIR):
  os.mkdir(MAIN_PARSED_DIR)

# %% [markdown]
# ## Function Initializtion

# %%
def get_id_value(text: str, context: str, with_underscore: bool = False) -> tuple:
  """
  Get the id for the key this id will be used
  to connect the information to the other
  tables (basically primary key for the information
  provided)

  Parameters
  ----------
  text
    Text in the form of the data dump mostly it 
    looks like this
    `["AttrPool_11010023"]="Refine to +9, ATK +5%",`
  context
    The name of the key before the id, for 
    example for the text above, the context will
    be `AttrPool`
  with_underscore
    Whether the attr contains underscore in its name
    or not

  Returns
  -------
  id, value
    tuple containing id and value of the attr
  """
  
  regex = f'\"{context}([\d\ \_]*)\"]=\"(.*)\"'

  if with_underscore:
    regex = f'\"{context}_(\w*)\"]=\"(.*)\"'

  return re.findall(regex, text)[0]

def create_and_add_entry_tw(context: str, key: str, with_underscore: bool) -> None:
  """
  Create entry for table and append it to the
  existing dictionary

  Parameters
  ----------
  context
    The name of the key before the id, for 
    example for the text above, the context will
    be `AttrPool`
  key
    The name of the key in the dictionary
  with_underscore
    Whether the attr contains underscore in its name
    or not

  Returns
  -------
  None
  """

  try:
    entry = {}

    id, value = get_id_value(text, context, with_underscore=with_underscore)
    entry["id"] = id
    entry["value"] = value

    tw_parsed_data[key].append(entry)
  except:
    pass

def create_and_add_entry_en(context: str, key: str, with_underscore: bool) -> None:
  """
  Create entry for table and append it to the
  existing dictionary

  Parameters
  ----------
  context
    The name of the key before the id, for 
    example for the text above, the context will
    be `AttrPool`
  key
    The name of the key in the dictionary
  with_underscore
    Whether the attr contains underscore in its name
    or not

  Returns
  -------
  None
  """

  try:
    entry = {}

    id, value = get_id_value(text, context, with_underscore=with_underscore)
    entry["id"] = id
    entry["value"] = value

    en_parsed_data[key].append(entry)
  except:
    pass

# %%
def parse_and_convert(texts):
  texts = " ".join(texts)
  texts = re.sub(r'\[([\w\"]+)\]=', '\g<1>:', texts)
  texts = re.sub(r'{ ([\d,]+) }', '[\g<1>]', texts)
  texts = re.sub(r'\:\{([\d\,\ ]+)\}', ':[\g<1>]', texts)

  texts = texts.replace("{}", "[]")
  texts = texts.replace("{ {", "[ {")
  texts = texts.replace("} }", "} ]")

  texts = "{" + texts + "}"

  parsed_dict = literal_eval(texts)

  return parsed_dict

# %% [markdown]
# # Parser

# %% [markdown]
# ## En_langs

# %% [markdown]
# ### Declare RE for cleaning Chinese chars

# %%
RE = re.compile(u'[⺀-⺙⺛-⻳⼀-⿕々〇〡-〩〸-〺〻㐀-䶵一-鿃豈-鶴侮-頻並-龎]', re.UNICODE)

# %% [markdown]
# ### Parse data

# %%
tw_parsed_data = {
    "area_name": [],
    "area_name_new": [],
    "attr_pool": [],
    "attr": [],
    "battle_pass_quest_desc": [],
    "battle_pass_quest_name": [],
    "size": [],
    "buff_desc": [],
    "buff_name": [],
    "card_attr_desc": [],
    "card_coordinates": [],
    "equip_desc": [],
    "equip_name": [],
    "equip_type": [],
    "goods_desc": [],
    "item_desc": [],
    "item_name": [],
    "item_type": [],
    "instance_description": [],
    "job_name": [],
    "mvp_desc": [],
    "mvp_name": [],
    "map_npc_name": [],
    "monster_desc": [],
    "monster_name": [],
    "monster_type": [],
    "ox_exam_question": [],
    "property": [],
    "race": [],
    "scene_name": [],
    "shadow_weapon": [],
    "shadow_weapon_name": [],
    "shadow_weapon_task": [],
    "shadow_weapon_task_name": [],
    "shadow_weapon_prop_des": [],
    "skill_name": [],
    "skill_desc": [],
    "suit_name": [],
    "title": [],
    "weather": [],
    "weather_desc": [],
    "mount_name": [],
    "mount_desc": [],
    "mount_job": [],
    "scene_name": []
}

# Initially I want to create something like this for DRY, but for
# the sake of readability will do it manually
# contexts = ["Areaname", "AttrPool", "Attr", "BattlePassQuestDesc"]

with open(f"{MAIN_CLEANED_DIR}/tw_langs.bytes", "r", encoding="utf8") as filename:
  for text in filename.readlines():
    if text.startswith('["areaname'):
      create_and_add_entry_tw("areaname", "area_name", False)
    elif text.startswith('["Areaname'):
      create_and_add_entry_tw("Areaname", "area_name_new", False)
    elif text.startswith('["AttrPool'):
      create_and_add_entry_tw("AttrPool", "attr_pool", True)
    elif text.startswith('["Attr'):
      create_and_add_entry_tw("Attr", "attr", True)
    elif text.startswith('["BattlePassQuestDesc'):
      create_and_add_entry_tw("BattlePassQuestDesc", "battle_pass_quest_desc", True)
    elif text.startswith('["BattlePassQuestName'):
      create_and_add_entry_tw("BattlePassQuestName", "battle_pass_quest_desc", True)
    elif text.startswith('["Body'):
      create_and_add_entry_tw("Body", "body", True)
    elif text.startswith('["BuffDes'):
      create_and_add_entry_tw("BuffDes", "buff_desc", True)
    elif text.startswith('["BuffName'):
      create_and_add_entry_tw("BuffName", "buff_name", True)
    elif text.startswith('["CardAttributeDescription'):
      create_and_add_entry_tw("CardAttributeDescription", "card_attr_desc", True)
    elif text.startswith('["CardCoordinates'):
      create_and_add_entry_tw("CardCoordinates", "card_coordinates", True)
    elif text.startswith('["EquipDesc'):
      create_and_add_entry_tw("EquipDesc", "equip_desc", True)
    elif text.startswith('["EquipName'):
      create_and_add_entry_tw("EquipName", "equip_name", True)
    elif text.startswith('["equipmentType'):
      create_and_add_entry_tw("equipmentType", "equip_type", True)
    elif text.startswith('["GoodsDes'):
      create_and_add_entry_tw("GoodsDes", "goods_desc", False)
    elif text.startswith('["ItemDes'):
      create_and_add_entry_tw("ItemDes", "item_desc", True)
    elif text.startswith('["ItemName'):
      create_and_add_entry_tw("ItemName", "item_name", True)
    elif text.startswith('["ItemType'):
      create_and_add_entry_tw("ItemType", "item_type", False)
    elif text.startswith('["InstanceDescription'):
      create_and_add_entry_tw("InstanceDescription", "instance_description", False)
    elif text.startswith('["JobName'):
      create_and_add_entry_tw("JobName", "job_name", True)
    elif text.startswith('["JobName'):
      create_and_add_entry_tw("JobName", "job_name", True)
    elif text.startswith('["MVPDes'):
      create_and_add_entry_tw("MVPDes", "mvp_desc", True)
    elif text.startswith('["MVPName'):
      create_and_add_entry_tw("MVPName", "mvp_name", True)
    elif text.startswith('["MapNpcName'):
      create_and_add_entry_tw("MapNpcName", "map_npc_name", False)
    elif text.startswith('["MonsterCollection'):
      create_and_add_entry_tw("MonsterCollection", "monster_desc", False)
    elif text.startswith('["MonsterName'):
      create_and_add_entry_tw("MonsterName", "monster_name", False)
    elif text.startswith('["MonsterType'):
      create_and_add_entry_tw("MonsterType", "monster_type", True)
    elif text.startswith('["OXExam'):
      create_and_add_entry_tw("OXExam", "ox_exam_question", True)
    elif text.startswith('["Property'):
      create_and_add_entry_tw("Property", "property", False)
    elif text.startswith('["Race'):
      create_and_add_entry_tw("Race", "race", True)
    elif text.startswith('["SceneName'):
      create_and_add_entry_tw("SceneName", "scene_name", False)
    elif text.startswith('["ShadowWeaponName'):
      create_and_add_entry_tw("ShadowWeaponName", "shadow_weapon_name", True)
    elif text.startswith('["ShadowWeaponTaskName'):
      create_and_add_entry_tw("ShadowWeaponTaskName", "shadow_weapon_task_name", True)
    elif text.startswith('["ShadowWeaponPropDes'):
      create_and_add_entry_tw("ShadowWeaponPropDes", "shadow_weapon_prop_des", True)
    elif text.startswith('["ShadowWeaponTask'):
      create_and_add_entry_tw("ShadowWeaponTask", "shadow_weapon_task", True)
    elif text.startswith('["SkillDesc'):
      create_and_add_entry_tw("SkillDesc", "skill_desc", True)
    elif text.startswith('["SkillName'):
      create_and_add_entry_tw("SkillName", "skill_name", True)
    elif text.startswith('["SuitName'):
      create_and_add_entry_tw("SuitName", "suit_name", False)
    elif text.startswith('["Title'):
      create_and_add_entry_tw("Title", "title", True)
    elif text.startswith('["WeatherDes'):
      create_and_add_entry_tw("WeatherDes", "weather_desc", True)
    elif text.startswith('["Weather'):
      create_and_add_entry_tw("Weather", "weather", True)
    elif text.startswith('["SceneName'):
      create_and_add_entry_tw("SceneName", "scene_name", True)

# %%
en_parsed_data = {
    "area_name": [],
    "area_name_new": [],
    "attr_pool": [],
    "attr": [],
    "battle_pass_quest_desc": [],
    "battle_pass_quest_name": [],
    "size": [],
    "buff_desc": [],
    "buff_name": [],
    "card_attr_desc": [],
    "card_coordinates": [],
    "equip_desc": [],
    "equip_name": [],
    "equip_type": [],
    "goods_desc": [],
    "item_desc": [],
    "item_name": [],
    "item_type": [],
    "instance_description": [],
    "job_name": [],
    "mvp_desc": [],
    "mvp_name": [],
    "map_npc_name": [],
    "monster_desc": [],
    "monster_name": [],
    "monster_type": [],
    "ox_exam_question": [],
    "property": [],
    "race": [],
    "scene_name": [],
    "shadow_weapon": [],
    "shadow_weapon_name": [],
    "shadow_weapon_task": [],
    "shadow_weapon_task_name": [],
    "shadow_weapon_prop_des": [],
    "skill_name": [],
    "skill_desc": [],
    "suit_name": [],
    "title": [],
    "weather": [],
    "weather_desc": [],
    "mount_name": [],
    "mount_desc": [],
    "mount_job": [],
    "scene_name": []
}

# Initially I want to create something like this for DRY, but for
# the sake of readability will do it manually
# contexts = ["Areaname", "AttrPool", "Attr", "BattlePassQuestDesc"]

with open(f"{MAIN_CLEANED_DIR}/en_langs.bytes", "r", encoding="utf8") as filename:
  for text in filename.readlines():
    if text.startswith('["areaname'):
      create_and_add_entry_en("areaname", "area_name", False)
    elif text.startswith('["Areaname'):
      create_and_add_entry_en("Areaname", "area_name_new", False)
    elif text.startswith('["AttrPool'):
      create_and_add_entry_en("AttrPool", "attr_pool", True)
    elif text.startswith('["Attr'):
      create_and_add_entry_en("Attr", "attr", True)
    elif text.startswith('["BattlePassQuestDesc'):
      create_and_add_entry_en("BattlePassQuestDesc", "battle_pass_quest_desc", True)
    elif text.startswith('["BattlePassQuestName'):
      create_and_add_entry_en("BattlePassQuestName", "battle_pass_quest_desc", True)
    elif text.startswith('["Body'):
      create_and_add_entry_en("Body", "body", True)
    elif text.startswith('["BuffDes'):
      create_and_add_entry_en("BuffDes", "buff_desc", True)
    elif text.startswith('["BuffName'):
      create_and_add_entry_en("BuffName", "buff_name", True)
    elif text.startswith('["CardAttributeDescription'):
      create_and_add_entry_en("CardAttributeDescription", "card_attr_desc", True)
    elif text.startswith('["CardCoordinates'):
      create_and_add_entry_en("CardCoordinates", "card_coordinates", True)
    elif text.startswith('["EquipDesc'):
      create_and_add_entry_en("EquipDesc", "equip_desc", True)
    elif text.startswith('["EquipName'):
      create_and_add_entry_en("EquipName", "equip_name", True)
    elif text.startswith('["equipmentType'):
      create_and_add_entry_en("equipmentType", "equip_type", True)
    elif text.startswith('["GoodsDes'):
      create_and_add_entry_en("GoodsDes", "goods_desc", False)
    elif text.startswith('["ItemDes'):
      create_and_add_entry_en("ItemDes", "item_desc", True)
    elif text.startswith('["ItemName'):
      create_and_add_entry_en("ItemName", "item_name", True)
    elif text.startswith('["ItemType'):
      create_and_add_entry_en("ItemType", "item_type", False)
    elif text.startswith('["InstanceDescription'):
      create_and_add_entry_en("InstanceDescription", "instance_description", False)
    elif text.startswith('["JobName'):
      create_and_add_entry_en("JobName", "job_name", True)
    elif text.startswith('["JobName'):
      create_and_add_entry_en("JobName", "job_name", True)
    elif text.startswith('["MVPDes'):
      create_and_add_entry_en("MVPDes", "mvp_desc", True)
    elif text.startswith('["MVPName'):
      create_and_add_entry_en("MVPName", "mvp_name", True)
    elif text.startswith('["MapNpcName'):
      create_and_add_entry_en("MapNpcName", "map_npc_name", False)
    elif text.startswith('["MonsterCollection'):
      create_and_add_entry_en("MonsterCollection", "monster_desc", False)
    elif text.startswith('["MonsterName'):
      create_and_add_entry_en("MonsterName", "monster_name", False)
    elif text.startswith('["MonsterType'):
      create_and_add_entry_en("MonsterType", "monster_type", True)
    elif text.startswith('["OXExam'):
      create_and_add_entry_en("OXExam", "ox_exam_question", True)
    elif text.startswith('["Property'):
      create_and_add_entry_en("Property", "property", False)
    elif text.startswith('["Race'):
      create_and_add_entry_en("Race", "race", True)
    elif text.startswith('["SceneName'):
      create_and_add_entry_en("SceneName", "scene_name", False)
    elif text.startswith('["ShadowWeaponName'):
      create_and_add_entry_en("ShadowWeaponName", "shadow_weapon_name", True)
    elif text.startswith('["ShadowWeaponTaskName'):
      create_and_add_entry_en("ShadowWeaponTaskName", "shadow_weapon_task_name", True)
    elif text.startswith('["ShadowWeaponPropDes'):
      create_and_add_entry_en("ShadowWeaponPropDes", "shadow_weapon_prop_des", True)
    elif text.startswith('["ShadowWeaponTask'):
      create_and_add_entry_en("ShadowWeaponTask", "shadow_weapon_task", True)
    elif text.startswith('["SkillDesc'):
      create_and_add_entry_en("SkillDesc", "skill_desc", True)
    elif text.startswith('["SkillName'):
      create_and_add_entry_en("SkillName", "skill_name", True)
    elif text.startswith('["SuitName'):
      create_and_add_entry_en("SuitName", "suit_name", False)
    elif text.startswith('["Title'):
      create_and_add_entry_en("Title", "title", True)
    elif text.startswith('["WeatherDes'):
      create_and_add_entry_en("WeatherDes", "weather_desc", True)
    elif text.startswith('["Weather'):
      create_and_add_entry_en("Weather", "weather", True)
    elif text.startswith('["SceneName'):
      create_and_add_entry_en("SceneName", "scene_name", True)

# %% [markdown]
# ## Skill

# %% [markdown]
# ### Get information from `en_langs`

# %%
tw_skill_name_df = pd.DataFrame(tw_parsed_data["skill_name"]).rename(columns={"value": "tw_name"})
tw_skill_desc_df = pd.DataFrame(tw_parsed_data["skill_desc"]).rename(columns={"value": "tw_description"})

# %%
tw_skill_df = pd.merge(tw_skill_name_df, tw_skill_desc_df, how="left", left_on="id", right_on="id")

# %%
tw_skill_df[tw_skill_df["id"].str.contains("15320")]
# Out:
# Empty DataFrame
# Columns: [id, tw_name, tw_description]
# Index: []

# %%
en_skill_name_df = pd.DataFrame(en_parsed_data["skill_name"]).rename(columns={"value": "name"})
en_skill_desc_df = pd.DataFrame(en_parsed_data["skill_desc"]).rename(columns={"value": "description"})

# %%
en_skill_df = pd.merge(en_skill_name_df, en_skill_desc_df, how="left", left_on="id", right_on="id")

# %%
skill_df = pd.merge(tw_skill_df, en_skill_df, how="left", left_on="id", right_on="id")

# %%
skill_df["name"] = skill_df["name"].fillna(skill_df["tw_name"])

# %%
skill_df["description"] = skill_df["description"].fillna(skill_df["tw_description"])

# %%
skill_final_df = skill_df.drop(["tw_name", "tw_description"], axis=1)

# %%
skill_final_df
# Out:
#             id                   name  \
# 0       100001          Normal Attack
# 1       100002        Monster spawned
# 2       100003               Gather!!
# 3       100004        Test Buff Skill
# 4       100010  Ignore defense attack
# ...        ...                    ...
# 2051  84020000          Nield's Power
# 2052  85020000         Moonlight Gift
# 2053  86000000           Wind Revival
# 2054  89005000              Hurricane
# 2055  89006000                  Blitz
#
#                                             description
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2051  When attacked, there is a %s chance to cast a ...
# 2052  Removes self debuffs every 6 seconds and becom...
# 2053  When taking fatal damage, you are saved from d...
# 2054  In PVP, each skill cast increases your PVP Fin...
# 2055  In PVP, upon dealing a total of 6 critical hit...
#
# [2056 rows x 3 columns]

# %%
skill_final_df.query("id == 1532001")
# Out:
# Empty DataFrame
# Columns: [id, name, description]
# Index: []

# %% [markdown]
# ### Save data for database

# %%
skill_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Advanced

# %% [markdown]
# ### Parse data

# %%
texts = []
LIMIT = 999999

# with open(f"test.txt", "r", encoding="utf8") as filename:
with open(f"{MAIN_CLEANED_DIR}/data_skill_Skill.bytes", "r", encoding="utf8") as filename:
  for i, text in enumerate(filename.readlines()):
    if i == LIMIT:
      break
    else:
      texts.append(text.strip())

  texts = " ".join(texts)

  texts = re.sub(r'\[([\w\"]+)\]=', '\g<1>:', texts)
  texts = re.sub(r'{ ([\d,]+) }', '[\g<1>]', texts)
  texts = re.sub(r'\:\{([\d\,\ ]+)\}', ':[\g<1>]', texts)

  texts = texts.replace("{}", "[]")
  texts = texts.replace("{ {", "[ {")
  texts = texts.replace("} } }, {", "AAAAA")
  texts = texts.replace("} } } }", "BBBBB")
  texts = texts.replace("} } }", "XXXXX")
  texts = texts.replace("} }, {", "ZZZZZ")
  texts = texts.replace("} }", "YYYYY")
  texts = texts.replace("XXXXX", "} } ]")
  texts = texts.replace("ZZZZZ", "} }, {")
  texts = texts.replace("YYYYY", "} ]")
  texts = texts.replace("AAAAA", "} ] }, {")
  texts = texts.replace("BBBBB", "} ] } ]")

  texts = "{" + texts + "}"
  skills = literal_eval(texts)

# %% [markdown]
# ### Create entries for DataFrame creation

# %%
skill_entries = []

for id, parsed_dict in skills.items():
  skill_entry = {}
  default_key_dict = {
      "is_mount_combat": "IsMountCombat",
      "range": "range",
      "is_damage_skill": "IsDamageSkill",
      "require_mount_combat": "RequireMountCombat",
      "skill_group_id" : "SkillGroupID",
      "max_level" : "MaxLevel",
      "pre_skill" : "PreSkill",
      "extra_range_skill_id": "ExtraRangeSkillId",
      "buff_list": "BuffList",
      "type": "Type",
      "cooldown": "CoolDown",
      "related_buff" : "RelatedBuff",
      "pet_skill_type": "PetSkillType",
      "must_equip": "mustEquip",
      "job": "Job",
      "max_hp_cost": "MaxHpCost",
      "skill_id": "SkillId",
      "is_pet_skill_can_use_when_master_die": "IsPetSkillCanUseWhenMasterDie",
      "auto_battle_type": "AutoBattleType",
      "skill_weapon": "SkillWeapon",
      "cost_zeny": "CostZeny",
      "name": "Name",
      "desc_args": "Desc_args",
      "combo": "combo",
      "skill_sketch": "SkillSketch",
      "res_id": "ResID",
      "require_mount_id": "RequireMountID",
      "pet_skill_element": "PetSkillElement",
      "desc": "Desc",
      "fixed_cooldown": "FixedCoolDown",
      "suit_skills_or_not": "SuitSkillsOrNot",
      "pre_item": 'PreItem',
      "cost_item": "CostItem",
      "cost": "Cost",
      "is_show_skill_tree": "isShowSkillTree",

  }
  
  skill_entry["id"] = id
  for col, def_key in default_key_dict.items():
    try:
      skill_entry[col] = parsed_dict[def_key]
    except:
      pass
  skill_entries.append(skill_entry)

skill_df = pd.DataFrame(skill_entries)

# %% [markdown]
# ### Merge with information from `en_langs`

# %%
skill_df = skill_df.fillna("-9999")

# %% [markdown]
# #### Skill name

# %%
tw_skill_name_df = pd.DataFrame(tw_parsed_data["skill_name"]).rename(columns={"value": "tw_name"})
en_skill_name_df = pd.DataFrame(en_parsed_data["skill_name"]).rename(columns={"value": "name"})

skill_name_df = pd.merge(tw_skill_name_df, en_skill_name_df, how="left", left_on="id", right_on="id")
skill_name_df["name"] = skill_name_df["name"].fillna(skill_name_df["tw_name"])

skill_final_df = skill_name_df.drop(["tw_name"], axis=1)

# %%
skill_name_df = skill_final_df[["id", "name"]].rename(columns={"id": "skill_name_id"})

skill_df["skill_name_id"] = skill_df["name"].str.replace("SkillName_", "")
skill_df = skill_df.drop("name", axis=1)
skill_df = pd.merge(skill_df, skill_name_df, how="left", left_on=["skill_name_id"], right_on=["skill_name_id"])

# %% [markdown]
# #### Skill description

# %%
tw_skill_desc_df = pd.DataFrame(tw_parsed_data["skill_desc"]).rename(columns={"value": "tw_desc"})
en_skill_desc_df = pd.DataFrame(en_parsed_data["skill_desc"]).rename(columns={"value": "desc"})

skill_desc_df = pd.merge(tw_skill_desc_df, en_skill_desc_df, how="left", left_on="id", right_on="id")
skill_desc_df["desc"] = skill_desc_df["desc"].fillna(skill_desc_df["tw_desc"])

skill_final_df = skill_desc_df.drop(["tw_desc"], axis=1)

# %%
isnull = skill_df["desc"].isnull()
skill_df.loc[isnull, 'desc'] = pd.Series([[None]] * isnull.sum()).values
skill_df["desc"] = skill_df["desc"].apply(list).str[0]

skill_df["skill_desc_id"] = skill_df["desc"].str.replace("SkillDesc_", "")
skill_df = skill_df.drop("desc", axis=1)

skill_desc_df = skill_final_df[["id", "desc"]].rename(columns={"id": "skill_desc_id"})
skill_df = pd.merge(skill_df, skill_desc_df, how="left", left_on=["skill_desc_id"], right_on=["skill_desc_id"])

# %%
skill_df.query("id == 1532001")
# Out:
#            id  is_mount_combat  is_damage_skill  require_mount_combat  \
# 1406  1532001                1                1                     0
#
#       skill_group_id  max_level pre_skill buff_list  type  \
# 1406               0         10        []        []     1
#
#                                                cooldown  pet_skill_type  \
# 1406  [9000, 12000, 15000, 18000, 21000, 24000, 2700...               1
#
#      must_equip   job max_hp_cost  skill_id  \
# 1406         []  1532          []   1532001
#
#       is_pet_skill_can_use_when_master_die  auto_battle_type  \
# 1406                                     0                 9
#
#                 skill_weapon cost_zeny desc_args  combo        skill_sketch  \
# 1406  [{'skillweapon': 311}]        []        []  -9999  SkillSketch1522001
#
#        res_id require_mount_id  pet_skill_element fixed_cooldown  \
# 1406  1522001               []                  0         [6000]
#
#       suit_skills_or_not pre_item cost_item  \
# 1406                   0       []        []
#
#                                                 cost  is_show_skill_tree  \
# 1406  [40, 56, 72, 88, 104, 120, 136, 152, 168, 184]                   1
#
#      related_buff  range skill_name_id  name skill_desc_id  \
# 1406        -9999  -9999       1522001  金属摇滚       1532001
#
#                                                    desc
# 1406  對指定目標發出高音，對其造成物理攻擊*<color=#44afee>%s%%</color>...

# %% [markdown]
# ### Fix missing values

# %%
skill_df["is_damage_skill"] = skill_df["is_damage_skill"].fillna(1)

skill_df["type"] = skill_df["type"].fillna(1)

isnull = skill_df["cooldown"].isnull()
skill_df.loc[isnull, 'cooldown'] = pd.Series([[None]] * isnull.sum()).values
skill_df["cooldown"] = skill_df["cooldown"].apply(list).str[0]

isnull = skill_df["cost"].isnull()
skill_df.loc[isnull, 'cost'] = pd.Series([[None]] * isnull.sum()).values
skill_df["cost"] = skill_df["cost"].apply(list).str[0]

skill_df["is_mount_combat"] = skill_df["is_mount_combat"].fillna(0)

skill_df["is_show_skill_tree"] = skill_df["is_show_skill_tree"].fillna(0)

# %% [markdown]
# ### Select columns for database

# %%
skill_final_df = skill_df[["id", "name", "desc", "skill_group_id", "is_damage_skill", "max_level", "type", "cooldown", "job", "res_id", "cost", "is_mount_combat", "is_show_skill_tree", "skill_weapon", "fixed_cooldown", "combo", "range", "require_mount_combat", "pet_skill_type", "is_pet_skill_can_use_when_master_die", "pet_skill_element", "suit_skills_or_not"]]

# %%
skill_final_df = skill_final_df.rename(columns={"desc": "description", "skill_group_id": "group_id"})

# %%
skill_final_df["skill_weapon"] = skill_final_df["skill_weapon"].apply(lambda x: np.nan if x == [] else x)

# %%
skill_final_df["fixed_cooldown"] = skill_final_df["fixed_cooldown"].apply(lambda x: np.nan if x == [] else x[0])

# %% [markdown]
# ### Save for database

# %%
skill_complex_final_df = skill_final_df.drop("skill_weapon", axis=1)

# %%
skill_complex_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_complex_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Item

# %% [markdown]
# ### Get item information from `en_langs`

# %%
tw_item_name_df = pd.DataFrame(tw_parsed_data["item_name"])
tw_item_desc_df = pd.DataFrame(tw_parsed_data["item_desc"])
tw_item_type_df = pd.DataFrame(tw_parsed_data["item_type"])

# %%
en_item_name_df = pd.DataFrame(en_parsed_data["item_name"])
en_item_desc_df = pd.DataFrame(en_parsed_data["item_desc"])
en_item_type_df = pd.DataFrame(en_parsed_data["item_type"])

# %% [markdown]
# ### Parse data

# %%
texts = []
LIMIT = 9999999
# LIMIT = 72566
# with open(f"test.txt", "r", encoding="utf8") as filename:
with open(f"{MAIN_CLEANED_DIR}/data_item_Item.bytes", "r", encoding="utf8") as filename:
  for i, text in enumerate(filename.readlines()):
    if i == LIMIT:
      break
    else:
      texts.append(text.strip())
    
  texts = " ".join(texts)

  texts = re.sub(r'\[([\w\"]+)\] =', '\g<1>:', texts)
  texts = re.sub(r'{ ([\d,]+) }', '[\g<1>]', texts)
  texts = re.sub(r'\{([\d\, ]+)\}', '[\g<1>]', texts)
  texts = re.sub(r'\:\{([\d\,\ ]+)\}', ':[\g<1>]', texts)
  
  # print(texts)

  texts = texts.replace("{ {", "AAAAA")
  texts = texts.replace("}, }, },", "BBBBB")
  texts = texts.replace("}, }, {", "DDDDD")
  texts = re.sub(r'\}, \}, (\d)', 'FFFFF \g<1>', texts)
  texts = re.sub(r'\}, \},$', 'EEEEE', texts)
  texts = texts.replace("}, },", "CCCCC")

  texts = texts.replace("AAAAA", "[ {")
  texts = texts.replace("BBBBB", "}, }, ],")
  texts = texts.replace("CCCCC", "}, ],")
  texts = texts.replace("DDDDD", "}, }, {")
  texts = texts.replace("EEEEE", "}, },")
  texts = texts.replace("FFFFF", "}, }, ")

  texts = "{" + texts + "}"
  

  # print(texts)

items = literal_eval(texts)
print(len(items))
# Out:
# 4711

# %% [markdown]
# ### Create entries for DataFrame creation

# %%
item_entries = []

for id, parsed_dict in items.items():
  item_entry = {}

  default_key_dict = {
      "cd": "cd",
      "item_desc": "itemDesc",
      "item_type": "itemType",
      "max_stack": "maxStack",
      "page": "page",
      "res_id": "resId",
      "stackable": "stackable",
      "weight": "weight",
      "static_id": "staticId",
      "card_attrs": "CardAttrs",
      "card_quality": "cardQuality",
      "card_slots": "cardSlots",
      "deposite_attrs": "DepositeAttrs",
      "is_mvp_card": "IsMvpCard",
      "item_subtype": "itemSubType",
      "min_level": "minLevel",
      "monster_id": "monster_id",
      "name": "name",
      "unlock_adventure_exp": "UnlockAdventureExp",
      "expired_date": "ExpiredDate",
      "is_bind": "isBind",
      "item_expired_type": "itemExpiredType",
      "sub_page": "subPage",
      "is_hide": "isHide",
      "use": "use",
      "show_in_ui": "showInUi",
      "acquire": "Acquire",
      "card_coordinate_point": "CardCoordinatePoint",
      "is_in_collection": "IsInCollection",
      "monster": "Monster",
      "sell_price": "SellPrice",
      "area_id": "AreaId",
      "cd_group_id": 'CdGroupId',
      "cd_type": 'CdType',
      "element": 'Element',
      "exp": 'Exp',
      "fish_rod_type": 'FishRodType',
      "fish_tool_type": 'FishToolType',
      "gift_send_limit": 'GiftSendLimit',
      "if_can_quick_use": 'IfCanQuickUse',
      "if_combined_for_life": 'IfCombinedForLife',
      "if_get_off_mount": 'IfGetOffMount',
      "if_stop_navigation": 'IfStopNavigation',
      "interface_id": 'InterfaceId',
      "is_gift_item": 'IsGiftItem',
      "item_quality": 'ItemQuality',
      "item_static_id": 'ItemStaticId',
      "max_use": 'MaxUse',
      "mine_tool_type": 'MineToolType',
      "npc_id": "NpcId",
      "npc_navigation": 'NpcNavigation',
      "oon_box_loot_bind_status": 'OONBoxLootBindStatus',
      "oon_box_loot_id": 'OONBoxLootId',
      "oon_box_loot_number": 'OONBoxLootNumber',
      "oon_box_loot_type": 'OONBoxLootType',
      "pet_pill_bullet_id": 'PetPillBulletId',
      "pet_pill_fixed_damage_rate": 'PetPillFixedDamageRate',
      "pet_pill_max_damage": 'PetPillMaxDamage',
      "related_activity_type": 'RelatedActivityType',
      "related_pet_skill": 'RelatedPetSkill',
      "scene_id": 'SceneId',
      "sell_navigation": 'SellNavigation',
      "sell_price": 'SellPrice',
      "stall_currency_type": 'StallCurrencyType',
      "stall_item_level": 'StallItemLevel',
      "stall_price_lower_limit": 'StallPriceLowerLimit',
      "stall_price_type": 'StallPriceType',
      "stall_price_upper_limit": 'StallPriceUpperLimit',
      "stall_type": 'StallType',
      "stall_zeny_child_label": 'StallZenyChildLabel',
      "is_all_job": 'isAllJob',
      "is_bind": 'isBind',
      "item_expired_type": 'itemExpiredType',
      "item_subtype_task": 'itemSubTypeTask',
      "job_limit": 'jobLimit',
      "min_level": 'minLevel',
      "pet_cage_type": 'petcagetype',
      "related_gm_activity_type": 'relatedGMActivityType',
      "res_id": 'resId',
      "stackable": 'stackable',
      "static_id": 'staticId',
  }

  item_entry["id"] = id
  for col, def_key in default_key_dict.items():
    try:
      item_entry[col] = parsed_dict[def_key]
    except:
      pass
  item_entries.append(item_entry)

item_df = pd.DataFrame(item_entries)

# %% [markdown]
# ### Merge with information from `en_langs`

# %% [markdown]
# #### Item name

# %%
tw_item_name_df = pd.DataFrame(tw_parsed_data["item_name"]).rename(columns={"value": "tw_name"})
tw_item_desc_df = pd.DataFrame(tw_parsed_data["item_desc"]).rename(columns={"value": "tw_description"})

tw_item_df = pd.merge(tw_item_name_df, tw_item_desc_df, how="left", left_on="id", right_on="id")

tw_item_df.head()

en_item_name_df = pd.DataFrame(en_parsed_data["item_name"]).rename(columns={"value": "name"})
en_item_desc_df = pd.DataFrame(en_parsed_data["item_desc"]).rename(columns={"value": "description"})

en_item_df = pd.merge(en_item_name_df, en_item_desc_df, how="left", left_on="id", right_on="id")

# %%
item_all_df = pd.merge(tw_item_df, en_item_df, how="left", left_on="id", right_on="id")

item_all_df["name"] = item_all_df["name"].fillna(item_all_df["tw_name"])
item_all_df["description"] = item_all_df["description"].fillna(item_all_df["tw_description"])

# %%
item_all_df = item_all_df.drop(["tw_name", "tw_description"], axis=1)

# %%
item_all_df["id"] = item_all_df["id"].apply(int)
item_df["id"] = item_df["id"].apply(int)

# %%
item_df = pd.merge(item_df, item_all_df, how="left", left_on="id", right_on="id")

# %%
item_df = item_df.drop("item_desc", axis=1)

# %% [markdown]
# #### Item type

# %%
item_df["item_type"] = item_df["item_type"].fillna(0).apply(int)
item_df["item_subtype"] = item_df["item_subtype"].fillna(0).apply(int)
item_df["item_type_subtype"] = item_df.apply(lambda x: f'{x["item_type"]}_{x["item_subtype"]}', axis=1)

item_type_df = en_item_type_df.rename(columns={"id": "item_type_subtype", "value": "item_type_en"})
item_df = pd.merge(item_df, item_type_df, how="left", left_on="item_type_subtype", right_on="item_type_subtype")

# %% [markdown]
# ### Save raw data

# %%
item_df.to_csv(f"{MAIN_PARSED_DIR}/item_raw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ### Save data for database

# %%
item_final_df = item_df[["id", "name_y", "description", "res_id", "item_type_en"]].rename(columns={"name_y": "item_name"})
item_final_df["res_id"] = item_final_df["res_id"].fillna(item_final_df["id"])
item_final_df = item_final_df[~item_final_df["item_name"].isnull()]

item_final_df = item_final_df.rename(columns={
    "item_name": "name",
    "item_desc_en": "description",
    "res_id": "res_id",
    "item_type_en": "type"
    })

item_final_df.loc[item_final_df["name"].str.contains(" Card"), 'res_id'] = 99999
item_final_df["type"] = item_final_df["type"].fillna("Uncategorized")
item_final_df["name"] = item_final_df["name"].str.lower()
item_final_df["is_visible"] = item_final_df["id"].apply(lambda x: 0 if x < 20000 else 1)

item_final_df.to_csv(f"{MAIN_PARSED_DIR}/item_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Preitem

# %% [markdown]
# ### Create entries for dataframe creation

# %%
skill_pre_item_records = skill_df[~skill_df["pre_item"].isnull()][["id", "pre_item"]].to_dict(orient="records")

# %%
skill_pre_item_fins = []

for record in skill_pre_item_records:
  if record["pre_item"] != {}:
    for pre_item in record["pre_item"]:
      skill_pre_item_fin = {}
      skill_pre_item_fin["skill_id"] = record["id"]
      skill_pre_item_fin["item_id"] = pre_item["ItemId"]
      skill_pre_item_fin["item_num"] = pre_item["Number"]
      
      skill_pre_item_fins.append(skill_pre_item_fin)

# %%
skill_pre_item_df = pd.DataFrame(skill_pre_item_fins)

# %%
intersections = set(skill_pre_item_df["skill_id"].astype(float)).intersection(set(skill_complex_final_df["id"].astype(float)))
skill_pre_item_df = skill_pre_item_df[skill_pre_item_df["skill_id"].astype(float).isin(intersections)]

intersections = set(skill_pre_item_df["item_id"].astype(float)).intersection(set(item_final_df["id"].astype(float)))
skill_pre_item_df = skill_pre_item_df[skill_pre_item_df["item_id"].astype(float).isin(intersections)]

# %%
skill_pre_item_final_df = skill_pre_item_df.reset_index().rename(columns={"index": "id"})

# %% [markdown]
# ### Save for database

# %%
skill_pre_item_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_pre_item_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Buff

# %% [markdown]
# ### Create entries for dataframe creation

# %%
skill_buff_list_records = skill_df[~skill_df["buff_list"].isnull()][["id", "buff_list"]].to_dict(orient="records")

# %%
skill_buff_list_fins = []

for record in skill_buff_list_records:
  if record["buff_list"] != {}:
    for buff_list in list(record["buff_list"]):
      skill_buff_list_fin = {}
      skill_buff_list_fin["skill_id"] = record["id"]
      skill_buff_list_fin["buff"] = buff_list
      
      skill_buff_list_fins.append(skill_buff_list_fin)

# %%
skill_buff_df = pd.DataFrame(skill_buff_list_fins)

# %%
intersections = set(skill_buff_df["skill_id"].astype(float)).intersection(set(skill_complex_final_df["id"].astype(float)))
skill_buff_df = skill_buff_df[skill_buff_df["skill_id"].astype(float).isin(intersections)]

# %%
skill_buff_final_df = skill_buff_df.reset_index().rename(columns={"index": "id"})

# %% [markdown]
# ### Save for database

# %%
skill_buff_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_buff_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Cost Item

# %% [markdown]
# ### Create entries for dataframe creation

# %%
skill_cost_item_records = skill_df[~skill_df["cost_item"].isnull()][["id", "cost_item"]].to_dict(orient="records")

# %%
skill_cost_item_fins = []

for record in skill_cost_item_records:
  if record["cost_item"] != {}:
    for cost_item in record["cost_item"]:
      skill_cost_item_fin = {}
      skill_cost_item_fin["skill_id"] = record["id"]
      skill_cost_item_fin["item_id"] = cost_item["ItemId"]
      skill_cost_item_fin["item_num"] = cost_item["Number"]
      
      skill_cost_item_fins.append(skill_cost_item_fin)

# %%
skill_cost_item_df = pd.DataFrame(skill_cost_item_fins)

# %%
skill_cost_item_df
# Out:
#    skill_id   item_id  item_num
# 0    199994  10202072         1
# 1    199995  10202070         1
# 2    199995  10202071         1
# 3    199996  10202157         1
# 4    199997  10202158         1
# 5    199997  10202159         1
# 6    199997  10202160         1

# %%
intersections = set(skill_cost_item_df["skill_id"].astype(float)).intersection(set(skill_complex_final_df["id"].astype(float)))
skill_cost_item_df = skill_cost_item_df[skill_cost_item_df["skill_id"].astype(float).isin(intersections)]

intersections = set(skill_cost_item_df["item_id"].astype(float)).intersection(set(item_final_df["id"].astype(float)))
skill_cost_item_df = skill_cost_item_df[skill_cost_item_df["item_id"].astype(float).isin(intersections)]

# %%
skill_cost_item_final_df = skill_cost_item_df.reset_index().rename(columns={"index": "id"})

# %% [markdown]
# ### Save for database

# %%
skill_cost_item_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_cost_item_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Factor

# %% [markdown]
# ### Parse data

# %%
texts = []

LIMIT = 9029399292
# with open(f"test.txt", "r", encoding="utf8") as filename:
with open(f"{MAIN_CLEANED_DIR}/data_SkillFactor.bytes", "r", encoding="utf8") as filename:
  for i, text in enumerate(filename.readlines()):
    if i == LIMIT:
      break
    else:
      texts.append(text.strip())

texts = " ".join(texts)
texts = re.sub(r'([A-Za-z]+) =', '"\g<1>" :', texts)
texts = re.sub(r'\[[\d]+\] = ', '', texts)

# texts += ']'

skill_factors = literal_eval(texts)

# %%
skill_factors[0]
# Out:
# {'FactorName': 'FactorName18',
#  'FinalFactor': 2,
#  'Precent': 0,
#  'SkillId': 1200128}

# %% [markdown]
# ### Create entries for DataFrame

# %%
skill_factor_entries = []

for skill_factor in skill_factors:
  skill_factor_entry = {}

  default_key_dict = {
      "id": "Id",
      "factor_name": "FactorName",
      "factor_order": "FactorOrder",
      "final_factor": "FinalFactor",
      "skill_id": "SkillId",
      "skill_level": "SkillLevel"
  }

  try:
    skill_factor_entry["id"] = skill_factor["Id"]
  except:
    pass

  for col, def_key in default_key_dict.items():
    try:
      skill_factor_entry[col] = skill_factor[def_key]
    except:
      pass
  skill_factor_entries.append(skill_factor_entry)

skill_factor_df = pd.DataFrame(skill_factor_entries)

# %% [markdown]
# ### Fix missing values

# %%
skill_factor_df["factor_order"] = skill_factor_df["factor_order"].fillna(1)
skill_factor_df["id"] = skill_factor_df["id"].fillna(1)
skill_factor_df["skill_level"] = skill_factor_df["skill_level"].fillna(1)
skill_factor_df["skill_id"] = skill_factor_df["skill_id"].fillna(0)
skill_factor_df["final_factor"] = skill_factor_df["final_factor"].fillna(20)

# %% [markdown]
# ### Save for database

# %%
intersections = set(skill_factor_df["skill_id"].astype(int)).intersection(set(skill_complex_final_df["id"].astype(int)))
skill_factor_final_df = skill_factor_df[skill_factor_df["skill_id"].astype(int).isin(intersections)]

skill_factor_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_factor_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Description Arguments

# %% [markdown]
# ### Create entries for dataframe creation

# %%
skill_desc_args_records = skill_df[skill_df["desc_args"].str.len() != 0][["id", "desc_args"]].to_dict(orient="records")

# %%
skill_desc_args_fins = []

for record in skill_desc_args_records:
  if record["desc_args"] != []:
    for desc_args in record["desc_args"]:
      skill_desc_args_fin = {}
      skill_desc_args_fin["skill_id"] = record["id"]
      skill_desc_args_fin["factor"] = desc_args["Factor"]
      skill_desc_args_fin["factor_bit"] = desc_args["FactorBit"]
      skill_desc_args_fin["level_type"] = desc_args["LevelType"]

      try:
        skill_desc_args_fin["type"] = desc_args["type"]
      except:
        pass
      
      skill_desc_args_fins.append(skill_desc_args_fin)

skill_desc_args_df = pd.DataFrame(skill_desc_args_fins)

# %%
intersections = set(skill_desc_args_df["skill_id"].astype(int)).intersection(set(skill_complex_final_df["id"].astype(int)))
skill_factor_final_df = skill_desc_args_df[skill_desc_args_df["skill_id"].astype(int).isin(intersections)]

# %%
skill_desc_args_final_df = skill_desc_args_df.reset_index().rename(columns={"index": "id"})

# %% [markdown]
# ### Save for database

# %%
skill_desc_args_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_desc_args_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Preskill

# %% [markdown]
# ### Create entries for dataframe creation

# %%
skill_pre_skill_records = skill_df[~skill_df["pre_skill"].isnull()][["id", "pre_skill"]].to_dict(orient="records")

skill_pre_skill_fins = []

for record in skill_pre_skill_records:
  if record["pre_skill"] != []:
    for pre_skill in record["pre_skill"]:
      skill_pre_skill_fin = {}
      skill_pre_skill_fin["skill_id"] = record["id"]
      skill_pre_skill_fin["pre_skill"] = pre_skill["SkillId"]
      skill_pre_skill_fin["pre_skill_level"] = pre_skill["SkillLevel"]
      
      skill_pre_skill_fins.append(skill_pre_skill_fin)

skill_pre_skill_df = pd.DataFrame(skill_pre_skill_fins)

skill_pre_skill_df = skill_pre_skill_df.reset_index().rename(columns={"index": "id"})

# %%
intersections = set(skill_pre_skill_df["pre_skill"].astype(int)).intersection(set(skill_complex_final_df["id"].astype(int)))
skill_pre_skill_df = skill_pre_skill_df[skill_pre_skill_df["pre_skill"].astype(int).isin(intersections)]

intersections = set(skill_pre_skill_df["skill_id"].astype(int)).intersection(set(skill_complex_final_df["id"].astype(int)))
skill_pre_skill_final_df = skill_pre_skill_df[skill_pre_skill_df["skill_id"].astype(int).isin(intersections)]

# %% [markdown]
# ### Save for database

# %%
skill_pre_skill_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_pre_skill_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Required Mount

# %% [markdown]
# ### Create entries for dataframe creation

# %%
skill_require_mount_id_records = skill_df[~skill_df["require_mount_id"].isnull()][["id", "require_mount_id"]].to_dict(orient="records")

skill_require_mount_id_fins = []

for record in skill_require_mount_id_records:
  if record["require_mount_id"] != []:
    for require_mount_id in list(record["require_mount_id"]):
      skill_require_mount_id_fin = {}
      skill_require_mount_id_fin["skill_id"] = record["id"]
      skill_require_mount_id_fin["require_mount_id"] = require_mount_id
      
      skill_require_mount_id_fins.append(skill_require_mount_id_fin)

skill_require_mount_id_df = pd.DataFrame(skill_require_mount_id_fins)

skill_require_mount_id_df = skill_require_mount_id_df.reset_index().rename(columns={"index": "id"})

# %%
intersections = set(skill_require_mount_id_df["skill_id"].astype(float)).intersection(set(skill_complex_final_df["id"].astype(float)))
skill_require_mount_id_final_df = skill_require_mount_id_df[skill_require_mount_id_df["skill_id"].astype(float).isin(intersections)]

# intersections = set(skill_require_mount_id_df["require_mount_id"].astype(float)).intersection(set(item_final_df["id"].astype(float)))
# skill_require_mount_id_final_df = skill_require_mount_id_df[skill_require_mount_id_df["require_mount_id"].astype(float).isin(intersections)]

# %% [markdown]
# ### Save for database

# %%
skill_require_mount_id_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_require_mount_id_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Max HP Cost

# %% [markdown]
# ### Create entries for dataframe creation

# %%
skill_max_hp_cost_records = skill_df[~skill_df["max_hp_cost"].isnull()][["id", "max_hp_cost"]].to_dict(orient="records")

skill_max_hp_cost_fins = []

for record in skill_max_hp_cost_records:
  if record["max_hp_cost"] != []:
    for max_hp_cost in list(record["max_hp_cost"]):
      skill_max_hp_cost_fin = {}
      skill_max_hp_cost_fin["skill_id"] = record["id"]
      skill_max_hp_cost_fin["max_hp_cost"] = max_hp_cost
      
      skill_max_hp_cost_fins.append(skill_max_hp_cost_fin)

skill_max_hp_cost_df = pd.DataFrame(skill_max_hp_cost_fins)

skill_max_hp_cost_df = skill_max_hp_cost_df.reset_index().rename(columns={"index": "id"})

# %%
intersections = set(skill_max_hp_cost_df["skill_id"].astype(float)).intersection(set(skill_complex_final_df["id"].astype(float)))
skill_max_hp_cost_final_df = skill_max_hp_cost_df[skill_max_hp_cost_df["skill_id"].astype(float).isin(intersections)]

# %% [markdown]
# ### Save for database

# %%
skill_max_hp_cost_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_max_hp_cost_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Skill Zeny Cost

# %% [markdown]
# ### Create entries for dataframe creation

# %%
skill_cost_zeny_records = skill_df[~skill_df["cost_zeny"].isnull()][["id", "cost_zeny"]].to_dict(orient="records")

skill_cost_zeny_fins = []

for record in skill_cost_zeny_records:
  if record["cost_zeny"] != []:
    for cost_zeny in list(record["cost_zeny"]):
      skill_cost_zeny_fin = {}
      skill_cost_zeny_fin["skill_id"] = record["id"]
      skill_cost_zeny_fin["cost_zeny"] = cost_zeny
      
      skill_cost_zeny_fins.append(skill_cost_zeny_fin)

skill_cost_zeny_df = pd.DataFrame(skill_cost_zeny_fins)

skill_cost_zeny_df = skill_cost_zeny_df.reset_index().rename(columns={"index": "id"})

# %%
intersections = set(skill_cost_zeny_df["skill_id"].astype(float)).intersection(set(skill_complex_final_df["id"].astype(float)))
skill_zeny_cost_final_df = skill_cost_zeny_df[skill_cost_zeny_df["skill_id"].astype(float).isin(intersections)]

# %% [markdown]
# ### Save for database

# %%
skill_zeny_cost_final_df.to_csv(f"{MAIN_PARSED_DIR}/skill_zeny_cost_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Equip Suit

# %% [markdown]
# ### Parse data

# %%
texts = []

LIMIT = 328932992
with open(f"{MAIN_CLEANED_DIR}/data_equip_EquipmentSuit.bytes", "r", encoding="utf8") as filename:
  for i, text in enumerate(filename.readlines()):
    if i == LIMIT:
      break
    else:
      texts.append(text.strip())

texts = " ".join(texts)
texts = re.sub(r'\[([\w\"]+)\] =', '\g<1>:', texts)
texts = re.sub(r'{ ([\d,]+) }', '[\g<1>]', texts)
texts = re.sub(r'\{([\d\, ]+)\}', '[\g<1>]', texts)
texts = re.sub(r'\:\{([\d\,\ ]+)\}', ':[\g<1>]', texts)

# print(texts)

texts = texts.replace("{ {", "AAAAA")
texts = texts.replace("}, }, },", "BBBBB")
texts = texts.replace("}, }, {", "DDDDD")
texts = re.sub(r'\}, \}, (\d)', 'FFFFF \g<1>', texts)
texts = re.sub(r'\}, \},$', 'EEEEE', texts)
texts = texts.replace("}, },", "CCCCC")

texts = texts.replace("AAAAA", "[ {")
texts = texts.replace("BBBBB", "}, }, ],")
texts = texts.replace("CCCCC", "}, ],")
texts = texts.replace("DDDDD", "}, }, {")
texts = texts.replace("EEEEE", "}, },")
texts = texts.replace("FFFFF", "}, }, ")

texts = "{" + texts + "}"

equipment_suits = literal_eval(texts)

# %% [markdown]
# ### Create entries for DataFrame creation

# %%
equipment_suit_entries = []

for id, parsed_dict in equipment_suits.items():
  equipment_suit_entry = {}

  default_key_dict = {
      "id": "ID",
      "argument_id": "argumentID",
      "argument_order": "argumentOrder",
      "argument_value": "argumentValue",
      "equip_id": "equip_id",
      "name": "name",
      "skill_id": "skillId",
      "suit_id": "suitId",
      "suit_num": "suitNum"
  }
  equipment_suit_entry["id"] = id
  for col, def_key in default_key_dict.items():
    try:
      equipment_suit_entry[col] = parsed_dict[def_key]
    except:
      pass
  equipment_suit_entries.append(equipment_suit_entry)

equip_suit_raw_df = pd.DataFrame(equipment_suit_entries)

# %%
equip_suit_raw_df["argument_value"] = equip_suit_raw_df["argument_value"].apply(list)

# %% [markdown]
# ### Break entries down

# %%
equip_suit_raw_df = equip_suit_raw_df[~equip_suit_raw_df["equip_id"].isnull()]

isnull =equip_suit_raw_df["argument_value"].isnull()
equip_suit_raw_df.loc[isnull, 'argument_value'] = pd.Series([[None]] * isnull.sum()).values

isnull =equip_suit_raw_df["argument_order"].isnull()
equip_suit_raw_df.loc[isnull, 'argument_order'] = pd.Series([[None]] * isnull.sum()).values

equip_suit_rec_df = equip_suit_raw_df[["id", "name", "skill_id", "equip_id", "argument_order", "argument_value", "suit_num"]]
equip_suit_recs = equip_suit_rec_df.to_dict(orient="records")

equip_suit_rec_news = []

for equip_suit_rec in equip_suit_recs:
  for i, equip_id in enumerate(equip_suit_rec["equip_id"]):
    new_entry = {}
    new_entry["id"] = equip_suit_rec["id"]
    new_entry["equip_id"] = equip_id
    new_entry["argument_value"] = equip_suit_rec["argument_value"][0]
    new_entry["argument_order"] = equip_suit_rec["argument_order"][0]
    new_entry["name"] = equip_suit_rec["name"]
    new_entry["skill_id"] = equip_suit_rec["skill_id"]
    new_entry["suit_num"] = equip_suit_rec["suit_num"]
  
    equip_suit_rec_news.append(new_entry)

equip_suit_df = pd.DataFrame(equip_suit_rec_news)

# %% [markdown]
# ### Data manipulation

# %%
equip_suit_manip_df = equip_suit_df[["argument_value", "name", "skill_id", "suit_num"]].drop_duplicates().sort_values("name")

# %%
equip_suit_manip_df["skill_id"] = equip_suit_manip_df["skill_id"].fillna("81010000")
equip_suit_manip_df = equip_suit_manip_df[~equip_suit_manip_df["name"].isnull()]
equip_suit_manip_df = equip_suit_manip_df[~equip_suit_manip_df["name"].str.startswith("Fashion_ShowEffect")]

# %%
def get_blue_argument_value(x):

  try:
    match = re.match("SuitName(\w+)", x["name"])
    equipment_suit_code = int(match.group(1))
  except:
    pass
    # match = re.match("Fashion_ShowEffect(\w+)", x["name"])
    # equipment_suit_code = int(match.group(1))
  
  if 100 < equipment_suit_code and equipment_suit_code < 500:
    if int(x["skill_id"]) == 81010000:
      return (equipment_suit_code - 99) * 0.005
    if int(x["skill_id"]) == 81010001:
      return 0.20 + ((equipment_suit_code - 99) * 0.05)
    if int(x["skill_id"]) == 81010002:
      return (equipment_suit_code - 99) * 0.05
  elif equipment_suit_code == 4:
    return 0.1
  elif equipment_suit_code == 6000:
    return 0.25
  elif equipment_suit_code == 8114:
    return 0.1
  elif equipment_suit_code == 1020:
    if int(x["suit_num"]) == 3:
      return 0.05
    elif int(x["suit_num"]) == 6:
      return 0.075
    elif int(x["suit_num"]) == 8:
      return 0.1
  elif equipment_suit_code == 2020:
    if int(x["suit_num"]) == 3:
      return 0.1
    elif int(x["suit_num"]) == 6:
      return 0.15
    elif int(x["suit_num"]) == 8:
      return 0.2
  elif equipment_suit_code == 2060:
    if int(x["suit_num"]) == 3:
      return 0.05
    elif int(x["suit_num"]) == 6:
      return 0.075
    elif int(x["suit_num"]) == 8:
      return 0.1
  elif equipment_suit_code == 2070:
    if int(x["suit_num"]) == 3:
      return 0.05
    elif int(x["suit_num"]) == 6:
      return 0.075
    elif int(x["suit_num"]) == 8:
      return 0.1
  elif equipment_suit_code == 3020:
    if int(x["suit_num"]) == 3:
      return 0.03
    elif int(x["suit_num"]) == 6:
      return 0.04
    elif int(x["suit_num"]) == 8:
      return 0.05
  elif equipment_suit_code == 4020:
    if int(x["suit_num"]) == 3:
      return 0.1
    elif int(x["suit_num"]) == 6:
      return 0.15
    elif int(x["suit_num"]) == 8:
      return 0.2
  elif equipment_suit_code == 5020:
    if int(x["suit_num"]) == 3:
      return 0.03
    elif int(x["suit_num"]) == 6:
      return 0.04
    elif int(x["suit_num"]) == 8:
      return 0.05

  return np.nan

# %%
equip_suit_manip_df["suit_num"] = equip_suit_manip_df["suit_num"].fillna(3)

equip_suit_manip_df["init_argument_value"] = equip_suit_manip_df.apply(get_blue_argument_value, axis=1)
equip_suit_manip_df["argument_order"] = 1
equip_suit_manip_df = equip_suit_manip_df[~equip_suit_manip_df["init_argument_value"].isnull()]

# %% [markdown]
# #### Manipulate `SuitName101`

# %%
equip_suit_manip_copy_df = equip_suit_manip_df.query("name == 'SuitName102'")
equip_suit_manip_copy_df["name"] = 'SuitName101'

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "init_argument_value"] = 0.005
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "init_argument_value"] = 0.25
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "init_argument_value"] = 0.05

equip_suit_manip_df = equip_suit_manip_df.append(equip_suit_manip_copy_df, ignore_index=True)

# %% [markdown]
# #### Manipulate `SuitName2020`

# %%
equip_suit_manip_df.loc[equip_suit_manip_df["name"] == "SuitName2020", "argument_order"] = 2

equip_suit_manip_copy_df = equip_suit_manip_df.query("name == 'SuitName2020'")

equip_suit_manip_copy_df["argument_order"] = 1

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "init_argument_value"] = 0.3
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "init_argument_value"] = 0.4
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "init_argument_value"] = 0.5
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "argument_value"] = np.nan

equip_suit_manip_df = equip_suit_manip_df.append(equip_suit_manip_copy_df, ignore_index=True)

# %% [markdown]
# #### Manipulate `SuitName2060`

# %%
equip_suit_manip_df.loc[equip_suit_manip_df["name"] == "SuitName2060", "argument_order"] = 3

equip_suit_manip_copy_df = equip_suit_manip_df.query("name == 'SuitName2060'")

equip_suit_manip_copy_df["argument_order"] = 1
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "init_argument_value"] = 2
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "init_argument_value"] = 3
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "init_argument_value"] = 4
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "argument_value"] = np.nan

equip_suit_manip_df = equip_suit_manip_df.append(equip_suit_manip_copy_df.copy(), ignore_index=True)

equip_suit_manip_copy_df["argument_order"] = 2
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "init_argument_value"] = 0.3
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "init_argument_value"] = 0.4
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "init_argument_value"] = 0.5
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "argument_value"] = np.nan

equip_suit_manip_df = equip_suit_manip_df.append(equip_suit_manip_copy_df.copy(), ignore_index=True)

# %% [markdown]
# #### Manipulate `SuitName2070`

# %%
equip_suit_manip_df.loc[equip_suit_manip_df["name"] == "SuitName2070", "argument_order"] = 2

equip_suit_manip_copy_df = equip_suit_manip_df.query("name == 'SuitName2070'")

equip_suit_manip_copy_df["argument_order"] = 1
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "init_argument_value"] = 0.2
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "init_argument_value"] = 0.15
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "init_argument_value"] = 0.1
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "argument_value"] = np.nan

equip_suit_manip_df = equip_suit_manip_df.append(equip_suit_manip_copy_df.copy(), ignore_index=True)

equip_suit_manip_copy_df["argument_order"] = 3
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "init_argument_value"] = 3
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "init_argument_value"] = 4
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "init_argument_value"] = 5
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "argument_value"] = np.nan

equip_suit_manip_df = equip_suit_manip_df.append(equip_suit_manip_copy_df.copy(), ignore_index=True)

# %% [markdown]
# #### Manipulate `SuitName4020`

# %%
equip_suit_manip_copy_df = equip_suit_manip_df.query("name == 'SuitName4020'")

equip_suit_manip_copy_df["argument_order"] = 2
equip_suit_manip_copy_df["init_argument_value"] = 1
equip_suit_manip_copy_df["argument_value"] = 0.5

equip_suit_manip_df = equip_suit_manip_df.append(equip_suit_manip_copy_df.copy(), ignore_index=True)

# %% [markdown]
# #### Manipulate `SuitName5020`

# %%
equip_suit_manip_df.loc[equip_suit_manip_df["name"] == "SuitName5020", "argument_order"] = 2
equip_suit_manip_copy_df = equip_suit_manip_df.query("name == 'SuitName5020'")

equip_suit_manip_copy_df["argument_order"] = 1
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "init_argument_value"] = 3
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 3, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "init_argument_value"] = 4
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 6, "argument_value"] = np.nan

equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "init_argument_value"] = 5
equip_suit_manip_copy_df.loc[equip_suit_manip_df["suit_num"] == 8, "argument_value"] = np.nan

equip_suit_manip_df = equip_suit_manip_df.append(equip_suit_manip_copy_df.copy(), ignore_index=True)

# %% [markdown]
# ### Merge with information from `en_langs`

# %% [markdown]
# #### Suit name

# %%
equip_suit_manip_df["name"] = equip_suit_manip_df["name"].apply(lambda x: int(x.replace("SuitName", "")))
equip_suit_manip_df = equip_suit_manip_df.rename(columns={"name": "suit_id"})

equip_suit_fin_df = equip_suit_manip_df
equip_suit_fin_df = equip_suit_fin_df.drop_duplicates().reset_index(drop=True)

suit_name_df = pd.DataFrame(en_parsed_data["suit_name"])
suit_name_df = suit_name_df.rename(columns={"id": "suit_id", "value": "name"})
suit_name_df["suit_id"] = suit_name_df["suit_id"].apply(int)

equip_suit_fin_df = pd.merge(equip_suit_fin_df, suit_name_df, how="left", left_on="suit_id", right_on="suit_id")

# %% [markdown]
# ### Save data for database

# %% [markdown]
# #### Equipment suit

# %%
equip_suit_df = equip_suit_fin_df[["suit_id", "name"]].drop_duplicates().reset_index(drop=True).rename(columns={"suit_id": "id"})

# %%
equip_suit_final_df = equip_suit_df.copy()

# %%
equip_suit_final_df.to_csv(f"{MAIN_PARSED_DIR}/equip_suit_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# #### Equipment Suit Skill

# %%
 equip_suit_skill_df = equip_suit_fin_df[["suit_id", "skill_id", "suit_num"]].drop_duplicates(["suit_id", "skill_id", "suit_num"]).reset_index().rename(columns={"index": "id"})

# %%
intersections = set(equip_suit_skill_df["skill_id"].astype(float)).intersection(set(skill_complex_final_df["id"].astype(float)))
equip_suit_skill_final_df = equip_suit_skill_df[equip_suit_skill_df["skill_id"].astype(float).isin(intersections)]

# %%
equip_suit_skill_final_df.to_csv(f"{MAIN_PARSED_DIR}/equip_suit_skill_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# #### Equipment Suit Skill Argument

# %%
equip_suit_skill_arg_df = pd.merge(equip_suit_fin_df, equip_suit_skill_final_df, how="left", left_on=["suit_id", "skill_id", "suit_num"], right_on=["suit_id", "skill_id", "suit_num"]).rename(columns={"id": "suit_skill_id"})

# %%
equip_suit_skill_arg_df = equip_suit_skill_arg_df[["suit_skill_id", "argument_order", "init_argument_value", "argument_value"]].reset_index().rename(columns={"index": "id"})

# %%
equip_suit_skill_arg_final_df = equip_suit_skill_arg_df.drop_duplicates(["suit_skill_id",	"argument_order"], keep="first")

# %%
equip_suit_skill_arg_final_df.to_csv(f"{MAIN_PARSED_DIR}/equip_suit_skill_arg_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Equip

# %% [markdown]
# ### Parse data

# %%
texts = []

with open(f"{MAIN_CLEANED_DIR}/data_equip_Equip.bytes", "r", encoding="utf-8") as filename:

  for text in filename.readlines():
    texts.append(text.strip())
    
texts = " ".join(texts)
texts = re.sub(r'\[([\w\"]+)\] =', '\g<1>:', texts)
texts = re.sub(r'{ ([\d,]+) }', '[\g<1>]', texts)
texts = re.sub(r'\{([\d\, ]+)\}', '[\g<1>]', texts)
texts = re.sub(r'\:\{([\d\,\ ]+)\}', ':[\g<1>]', texts)

# print(texts)

texts = texts.replace("{ {", "AAAAA")
texts = texts.replace("}, }, },", "BBBBB")
texts = texts.replace("}, }, {", "DDDDD")
texts = re.sub(r'\}, \}, (\d)', 'FFFFF \g<1>', texts)
texts = re.sub(r'\}, \},$', 'EEEEE', texts)
texts = texts.replace("}, },", "CCCCC")

texts = texts.replace("AAAAA", "[ {")
texts = texts.replace("BBBBB", "}, }, ],")
texts = texts.replace("CCCCC", "}, ],")
texts = texts.replace("DDDDD", "}, }, {")
texts = texts.replace("EEEEE", "}, },")
texts = texts.replace("FFFFF", "}, }, ")

texts = "{" + texts + "}"


equips = literal_eval(texts)

# %% [markdown]
# ### Create entries for DataFrame creation

# %%
equip_entries = []

for id, parsed_dict in equips.items():
  equip_entry = {}

  default_key_dict = {
      "sell_price": 'SellPrice',
      "base_prop": 'baseProperty',
      "name": "name",
      "desc": 'desc',
      "type": 'equipmentType',
      "improved_level": 'improvedLevel',
      "init_holes": 'initHoles',
      "is_all_job": 'isAllJob',
      "is_bind": 'isBind',
      "is_fashion": 'isFashion',
      "job_limit": 'jobLimit',
      "max_holes": 'maxHoles',
      "min_level_limit" : 'minLvLimit',
      "prop_level": 'propLevel',
      "quality": 'quality',
      "res_id": 'resId',
      "trade": 'trade',
      "refine_id": "RefineID",
      "static_id": 'staticId',
      "wardrobe_value":'wardrobeValue',
      "decomposition_output_id": "DecompositionOutputId"
  }

  equip_entry["id"] = id
  for col, def_key in default_key_dict.items():
    try:
      equip_entry[col] = parsed_dict[def_key]
    except:
      pass
  equip_entries.append(equip_entry)

equip_df = pd.DataFrame(equip_entries)

# %% [markdown]
# ### Get equipment information from `en_langs`

# %%
tw_equip_name_df = pd.DataFrame(tw_parsed_data["equip_name"]).rename(columns={"value": "tw_value"})
en_equip_name_df = pd.DataFrame(en_parsed_data["equip_name"])
equip_name_df = pd.merge(tw_equip_name_df, en_equip_name_df, how="left", left_on="id", right_on="id")

equip_name_df["value"] = equip_name_df["value"].fillna(equip_name_df["tw_value"])
equip_name_df = equip_name_df.drop("tw_value", axis=1)

# %%
tw_equip_desc_df = pd.DataFrame(tw_parsed_data["equip_desc"]).rename(columns={"value": "tw_value"})
en_equip_desc_df = pd.DataFrame(en_parsed_data["equip_desc"])
equip_desc_df = pd.merge(tw_equip_desc_df, en_equip_desc_df, how="left", left_on="id", right_on="id")

equip_desc_df["value"] = equip_desc_df["value"].fillna(equip_desc_df["tw_value"])
equip_desc_df = equip_desc_df.drop("tw_value", axis=1)

# %%
tw_equip_type_df = pd.DataFrame(tw_parsed_data["equip_type"]).rename(columns={"value": "tw_value"})
en_equip_type_df = pd.DataFrame(en_parsed_data["equip_type"])
equip_type_df = pd.merge(tw_equip_type_df, en_equip_type_df, how="left", left_on="id", right_on="id")

equip_type_df["value"] = equip_type_df["value"].fillna(equip_type_df["tw_value"])
equip_type_df = equip_type_df.drop("tw_value", axis=1)

# %%
equipment_attr_desc_df = pd.DataFrame(en_parsed_data["property"])

# %% [markdown]
# ### Select columns for database

# %%
equip_all_df = equip_df[["id", "name", "desc", "type", "init_holes", "is_bind", "max_holes", "res_id", "static_id", "improved_level", "min_level_limit", "prop_level", "quality", "refine_id", "sell_price", "is_all_job", "is_fashion", "wardrobe_value", "decomposition_output_id"]]

# %% [markdown]
# ### Merge with information from `en_langs`

# %% [markdown]
# #### Equip name

# %%
equip_name_df["id"] = equip_name_df["id"].apply(lambda x: f"EquipName_{x}")
equip_name_df = equip_name_df.rename(columns={"id": "name", "value":"equipment_name"})
equip_all_df = pd.merge(equip_all_df, equip_name_df, how="left", left_on=["name"], right_on=["name"])

# %% [markdown]
# #### Equip description

# %%
equip_desc_df["id"] = equip_desc_df["id"].apply(lambda x: f"EquipDesc_{x}")
equip_desc_df = equip_desc_df.rename(columns={"id": "desc", "value":"equipment_desc"})
equip_all_df = pd.merge(equip_all_df, equip_desc_df, how="left", left_on=["desc"], right_on=["desc"])

# %% [markdown]
# #### Equip type

# %%
equip_type_df
equip_all_df["type"] = equip_all_df["type"].astype(float)
equip_type_df = equip_type_df.rename(columns={"id": "type", "value":"equipment_type"})
equip_type_df["type"] = equip_type_df["type"].astype(float)
equip_all_df = pd.merge(equip_all_df, equip_type_df, how="left", left_on=["type"], right_on=["type"])

# %%
equip_type_df.loc[ equip_type_df["type"] == 308, "equipment_type"] = "Weapon - Knuckles"

# %%
equip_type_df
# Out:
#      type             equipment_type
# 0   100.0      Weapon - Basic Dagger
# 1   101.0  Weapon - One-Handed Sword
# 2   102.0    Weapon - One-Handed Axe
# 3   103.0    Weapon - One-Handed Rod
# 4   104.0              Weapon - Mace
# 5   105.0            Weapon - Dagger
# 6   106.0          Weapon - Knuckles
# 7   107.0              Weapon - Book
# 8   201.0            Weapon - Shield
# 9   301.0  Weapon - Two-Handed Sword
# 10  302.0    Weapon - Two-Handed Axe
# 11  303.0  Weapon - Two-Handed Spear
# 12  304.0             Weapon - Katar
# 13  305.0           Weapon - Longbow
# 14  306.0    Weapon - Two-Handed Rod
# 15  307.0          Weapon - Shortbow
# 16  308.0          Weapon - Knuckles
# 17  309.0        Weapon - Instrument
# 18  310.0              Weapon - Whip
# 19  311.0                      武器·鞭子
# 20  401.0              Armor - Cloak
# 21  402.0            Armor - Clothes
# 22  403.0              Armor - Shoes
# 23  501.0     Accessory - Decoration
# 24  502.0     Accessory - Decoration
# 25  503.0     Accessory - Decoration
# 26  504.0     Accessory - Decoration
# 27  505.0       Accessory - Talisman
# 28  506.0       Accessory - Talisman
# 29  601.0             Costume - Head
# 30  602.0             Costume - Eyes
# 31  603.0            Costume - Mouth
# 32  604.0           Costume - Outfit
# 33  605.0             Costume - Back
# 34  606.0             Costume - Tail
# 35  996.0                  Water Gun
# 36  997.0         Weapon - Slingshot
# 37  998.0                  Slingshot
# 38  999.0           Weapon - Unarmed

# %% [markdown]
# ### Filter column for database

# %%
equip_final_df = equip_all_df[["id", "equipment_name", "equipment_desc", "equipment_type", "static_id", "res_id", "init_holes", "max_holes", "min_level_limit", "prop_level", "quality", "refine_id", "sell_price", "is_all_job", "wardrobe_value", "improved_level", "decomposition_output_id"]]

# %% [markdown]
# ### Data correction

# %%
equip_final_df["equipment_type"] = equip_final_df["equipment_type"].fillna("Accessory - Decoration")
equip_final_df = equip_final_df[~equip_final_df["equipment_name"].isnull()]
equip_final_df["equipment_name"] = equip_final_df["equipment_name"].str.replace("I", "I")
equip_final_df["equipment_group"] = equip_final_df["equipment_name"].str.replace(" III", "").str.replace(" II", "").str.replace(" IV", "").str.replace(" VI", "").str.replace(" V", "").str.replace(" I", "")
equip_final_df["quality"] = equip_final_df["quality"].fillna(1)
equip_final_df["improved_level"] = equip_final_df["improved_level"].fillna(0)
equipment_group_df = equip_final_df.query("improved_level == 0")[["equipment_group", "static_id"]].rename(columns={"static_id":"correct_static_id"})
equip_final_df = pd.merge(equip_final_df, equipment_group_df, how="left", left_on=["equipment_group"], right_on=["equipment_group"])
equip_final_df["static_id"] = equip_final_df["correct_static_id"]
equip_final_df = equip_final_df.drop_duplicates("id", keep="first")

# %% [markdown]
# ### Add equipment suit info

# %%
def get_final_level(x):
  return (x["prop_level"] - (x["improved_level"]*10))

equip_final_df["final_level"] = equip_final_df.apply(get_final_level, axis=1)

def assign_equipment_suit(x):
  final_level = x["final_level"]
  quality = x["quality"]

  if quality == 1:
    if final_level == 30: 
      return 1020
    elif final_level == 40:
      return 2020
    elif final_level == 50:
      return 3020
    elif final_level == 60:
      return 4020
    elif final_level == 70:
      return 5020
    elif final_level == 80:
      return 2060
    elif final_level == 90:
      return 2070
    elif final_level == 100:
      return 2080
    elif final_level == 110:
      return 2090
    elif final_level == 120:
      return 2100
  elif quality == 2:
    return 100 + (final_level - 20) / 10
  else:
    return np.nan

equip_final_df["suit_id"] = equip_final_df.apply(assign_equipment_suit, axis=1)

# %%
equip_final_df.loc[equip_final_df["suit_id"] == 2080, "suit_id"] = np.nan

# %%
equip_final_df.shape
# Out:
# (3934, 21)

# %%
equip_final_temp_df = equip_final_df[equip_final_df["suit_id"].isnull()]

# %%
intersections = set(equip_final_df["suit_id"].astype(float)).intersection(set(equip_suit_final_df["id"].astype(float)))
equip_final_df = equip_final_df[equip_final_df["suit_id"].astype(float).isin(intersections)]

# %%
equip_final_df = equip_final_df.append(equip_final_temp_df, ignore_index=True)

# %% [markdown]
# ### Save data for database

# %%
equip_final_df = equip_final_df.rename(columns={
    "equipment_name": "name",
    "equipment_desc": "description",
    "equipment_type": "type",
    "decomposition_output_id": "decomposition_id"
}).drop(["equipment_group", "correct_static_id", "final_level"], axis=1)

equip_final_df["name"] = equip_final_df["name"].str.lower()
equip_final_df.to_csv(f"{MAIN_PARSED_DIR}/equip_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Equip Attributes

# %% [markdown]
# ### Get data from Equip

# %%
new_records = []

records = equip_df[["id", "base_prop"]].to_dict(orient="records")

for record in records:
  
  if type(record["base_prop"]) == dict:
    for attr, value in record["base_prop"].items():
      new_record = {}

      new_record["id"] = record["id"]
      new_record["attr"] = attr
      new_record["value"] = value

      new_records.append(new_record)
  else:
    new_record = {}

    new_record["id"] = record["id"]
    new_record["attr"] = np.nan
    new_record["value"] = np.nan

    new_records.append(new_record)

equipment_attributes_df = pd.DataFrame(new_records)

# %% [markdown]
# ### Merge with information from `en_langs`

# %% [markdown]
# #### Attribute Description

# %%
equipment_attr_desc_df = equipment_attr_desc_df.rename(columns={"id": "attr", "value": "attributes"})

equipment_attr_desc_df["attr"] = equipment_attr_desc_df["attr"].astype(float)
equipment_attributes_df["attr"] = equipment_attributes_df["attr"].astype(float)

equipment_attr_fin_df = pd.merge(equipment_attributes_df, equipment_attr_desc_df, how="left", left_on=["attr"], right_on=["attr"])
equipment_attr_fin_df = equipment_attr_fin_df[["id", "attributes", "value"]]

# %% [markdown]
# ### Sava data for database

# %%
equipment_attr_fin_df = equipment_attr_fin_df.rename(columns={
    "id": "equip_id",
    "attributes": "attribute",
    "value": "attribute_value"
})

equipment_attr_fin_df = equipment_attr_fin_df.reset_index(drop=True)
equipment_attr_fin_df["id"] = pd.Series(range(0, equipment_attr_fin_df.shape[0]))

intersections = set(equipment_attr_fin_df["equip_id"].astype(int)).intersection(set(equip_final_df["id"].astype(int)))
equipment_attributes_final_df = equipment_attr_fin_df[equipment_attr_fin_df["equip_id"].astype(int).isin(intersections)]

# %%
equipment_attributes_final_df.to_csv(f"{MAIN_PARSED_DIR}/equip_attributes_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Material

# %% [markdown]
# ### Get equip and item data

# %%
material_one_df = item_final_df[["id", "name", "description", "res_id"]]
material_one_df["is_item"] = 1
material_two_df = equip_final_df[["id", "name", "description", "res_id"]]
material_two_df["is_item"] = 0

# %% [markdown]
# ### Data correction

# %%
material_final_df = material_one_df.append(material_two_df, ignore_index=True)
material_final_df = material_one_df.copy()
material_final_df["name"] = material_final_df["name"].str.lower()

material_final_df.loc[material_final_df["name"].str.contains("card"), 'res_id'] = 99999

# %% [markdown]
# ### Save data for database

# %%
material_final_df.to_csv(f"{MAIN_PARSED_DIR}/material_tw_{APK_DATE}.csv", index=False)

# %%
material_df = material_final_df.copy()

# %% [markdown]
# ## Job

# %% [markdown]
# ### Get data from `en_langs`

# %%
tw_job_name_df = pd.DataFrame(tw_parsed_data["job_name"]).rename(columns={"value": "tw_name"})
tw_job_df = tw_job_name_df

en_job_name_df = pd.DataFrame(en_parsed_data["job_name"]).rename(columns={"value": "name"})
en_job_df = en_job_name_df

job_all_df = pd.merge(tw_job_df, en_job_df, how="left", left_on="id", right_on="id")
job_all_df["name"] = job_all_df["name"].fillna(job_all_df["tw_name"])

# %%
job_final_df = job_all_df.copy()

# %%
job_final_df = job_final_df.drop("tw_name", axis=1)

# %% [markdown]
# ### Save data for database

# %%
job_final_df.to_csv(f"{MAIN_PARSED_DIR}/job_tw_{APK_DATE}.csv", index=False)

# %% [markdown]
# ## Monster

# %% [markdown]
# ### Parse data

# %%
texts = []

with open(f"{MAIN_CLEANED_DIR}/data_monster_Monster.bytes", "r", encoding="utf-8") as filename:

  for text in filename.readlines():
    texts.append(text.strip())
    
  texts = " ".join(texts)

  texts = re.sub(r'\[([\w\"]+)\] =', '\g<1>:', texts)
  texts = re.sub(r'{ ([\d,]+) }', '[\g<1>]', texts)
  texts = re.sub(r'\{([\d\, ]+)\}', '[\g<1>]', texts)
  texts = re.sub(r'\:\{([\d\,\ ]+)\}', ':[\g<1>]', texts)
  
  # print(texts)

  texts = texts.replace("{ {", "AAAAA")
  texts = texts.replace("}, }, },", "BBBBB")
  texts = texts.replace("}, }, {", "DDDDD")
  texts = re.sub(r'\}, \}, (\d)', 'FFFFF \g<1>', texts)
  texts = re.sub(r'\}, \},$', 'EEEEE', texts)
  texts = texts.replace("}, },", "CCCCC")

  texts = texts.replace("AAAAA", "[ {")
  texts = texts.replace("BBBBB", "}, }, ],")
  texts = texts.replace("CCCCC", "}, ],")
  texts = texts.replace("DDDDD", "}, }, {")
  texts = texts.replace("EEEEE", "}, },")
  texts = texts.replace("FFFFF", "}, }, ")

  texts = "{" + texts + "}"

monsters = literal_eval(texts)

# %% [markdown]
# ### Create entries for DataFrame creation

# %%
monster_entries = []

for id, parsed_dict in monsters.items():
  monster_entry = {}

  default_key_dict = {
      'name': 'name',
      'Desc': 'Desc',
      'DpsTestId': 'DpsTestId',
      'DropListKV': 'DropListKV',
      'EffectHang': 'EffectHang',
      'EffectId': 'EffectId',
      'EffectScale': 'EffectScale',
      'ExtraEffect': 'ExtraEffect',
      'HasDieEffect': 'HasDieEffect',
      'IfCanShowInDpsTest': 'IfCanShowInDpsTest',
      'IfIgnoreInvisibility': 'IfIgnoreInvisibility',
      'IsSpecialSkillNotTarget': 'IsSpecialSkillNotTarget',
      'MagicMap': 'MagicMap',
      'MvpRankDrop': 'MvpRankDrop',
      'MvpRareDrop': 'MvpRareDrop',
      'PatrolPos': 'PatrolPos',
      'PetId': 'PetId',
      'RareDropType': 'RareDropType',
      'RingScale': 'RingScale',
      'Scale': 'Scale',
      'ShowRing': 'ShowRing',
      'SkillEffect': 'SkillEffect',
      'Weather': 'Weather',
      'alertRange': 'alertRange',
      'aniSpeed': 'aniSpeed',
      'attackSpeedIncrease': 'attackSpeedIncrease',
      'baseExp': 'baseExp',
      'bloodNums': 'bloodNums',
      'bodily': 'bodily',
      'bornSkillId': 'bornSkillId',
      'bornSound': 'bornSound',
      'bronEffectId': 'bronEffectId',
      'calDamageToCreator': 'calDamageToCreator',
      'canBattleTeleport': 'canBattleTeleport',
      'cantSelect': 'cantSelect',
      'castSkillRate': 'castSkillRate',
      'chaseRange': 'chaseRange',
      'criticalLevel': 'criticalLevel',
      'criticalRate': 'criticalRate',
      'criticalResistanceLevel': 'criticalResistanceLevel',
      'criticalResistanceRate': 'criticalResistanceRate',
      'criticalResistanceValue': 'criticalResistanceValue',
      'criticalValue': 'criticalValue',
      'dialogueBubbleList': 'dialogueBubbleList',
      'dieEffectPath': 'dieEffectPath',
      'dieSound': 'dieSound',
      'dieSoundTime': 'dieSoundTime',
      'dodgeLevel': 'dodgeLevel',
      'dodgeRate': 'dodgeRate',
      'dropAnnouncementId': 'dropAnnouncementId',
      'finalMagicDefenseIncrease': 'finalMagicDefenseIncrease',
      'finalPhysicDefenseIncrease': 'finalPhysicDefenseIncrease',
      'fixedMagicDamage': 'fixedMagicDamage',
      'fixedMagicDamageReduce': 'fixedMagicDamageReduce',
      'fixedPhysicDamage': 'fixedPhysicDamage',
      'fixedPhysicDamageReduce': 'fixedPhysicDamageReduce',
      'followType': 'followType',
      'forceType': 'forceType',
      'hasWhiteEffect': 'hasWhiteEffect',
      'hitIncrease': 'hitIncrease',
      'hitLevel': 'hitLevel',
      'id': 'id',
      'idleSound': 'idleSound',
      'ifActive': 'ifActive',
      'ifChangeTarget': 'ifChangeTarget',
      'ifControlledByPunishment': 'ifControlledByPunishment',
      'ifSelectPlayerFirst': 'ifSelectPlayerFirst',
      'isBeHitBack': 'isBeHitBack',
      'isHideBlood': 'isHideBlood',
      'isHideName': 'isHideName',
      'isIgnoreForceAttack': 'isIgnoreForceAttack',
      'isKeyMonster': 'isKeyMonster',
      'isLevelEffect': 'isLevelEffect',
      'isResetStateLeaveBattle': 'isResetStateLeaveBattle',
      'isShowInMap': 'isShowInMap',
      'isUnmove': 'isUnmove',
      'jobExp': 'jobExp',
      'level': 'level',
      'lootForAll': 'lootForAll',
      'magicDamageIncrease': 'magicDamageIncrease',
      'magicDamagedIncrease': 'magicDamagedIncrease',
      'magicDefenseLevel': 'magicDefenseLevel',
      'magicDps': 'magicDps',
      'magicPenetrationIncrease': 'magicPenetrationIncrease',
      'magicPenetrationLevel': 'magicPenetrationLevel',
      'magicRebound': 'magicRebound',
      'maxHp': 'maxHp',
      'monsterCollectionId': 'monsterCollectionId',
      'monsterTypeForServer': 'monsterTypeForServer',
      'mvpDropId': 'mvpDropId',
      'name': 'name',
      'nameLocalized': 'nameLocalized',
      'navPos': 'navPos',
      'navSceneId': 'navSceneId',
      'navScenesId': 'navScenesId',
      'overChaseChangeHatred': 'overChaseChangeHatred',
      'patrolRange': 'patrolRange',
      'patrolSpeed': 'patrolSpeed',
      'patrolType': 'patrolType',
      'physicDamageIncrease': 'physicDamageIncrease',
      'physicDamagedIncrease': 'physicDamagedIncrease',
      'physicDefenseLevel': 'physicDefenseLevel',
      'physicDps': 'physicDps',
      'physicPenetrationIncrease': 'physicPenetrationIncrease',
      'physicPenetrationLevel': 'physicPenetrationLevel',
      'property': 'property',
      'race': 'race',
      'radius': 'radius',
      'readAttrFrom': 'readAttrFrom',
      'rebound': 'rebound',
      'resId': 'resId',
      'runSound': 'runSound',
      'showMiniProfile': 'showMiniProfile',
      'skills': 'skills',
      'soundVolume': 'soundVolume',
      'speed': 'speed',
      'staticId': 'staticId',
      'tips': 'tips',
      'type': 'type',
      'magicVampire': 'magicVampire',
      'vampire': 'vampire',
      'zeny': 'zeny'
  }

  monster_entry["id"] = id
  for col, def_key in default_key_dict.items():
    try:
      monster_entry[col] = parsed_dict[def_key]
    except:
      pass
  monster_entries.append(monster_entry)

monster_info_df = pd.DataFrame(monster_entries)

# %% [markdown]
# ### Merge with information from `en_langs`

# %% [markdown]
# #### Monster name

# %%
tw_monster_name_df = pd.DataFrame(tw_parsed_data["monster_name"]).rename(columns={"value": "tw_name"})
tw_monster_df = tw_monster_name_df

en_monster_name_df = pd.DataFrame(en_parsed_data["monster_name"]).rename(columns={"value": "name"})
en_monster_df = en_monster_name_df

monster_all_df = pd.merge(tw_monster_df, en_monster_df, how="left", left_on="id", right_on="id")
monster_all_df["name"] = monster_all_df["name"].fillna(monster_all_df["tw_name"])

# %%
monster_all_df = monster_all_df.drop("tw_name", axis=1)

# %%
monster_all_df = monster_all_df.rename(columns={"id": "name_id", "name": "en_name"})
monster_en_name_df = monster_all_df.copy()

# %%
# monster_en_name_df = pd.DataFrame(en_parsed_data["monster_name"])
# monster_en_name_df = monster_en_name_df.rename(columns={"id": "name_id", "value": "en_name"})

monster_info_df["name_id"] = monster_info_df["name"].apply(lambda x: str(x).replace('"', '').replace('MonsterName', ""))
monster_info_df = pd.merge(monster_info_df, monster_en_name_df, how="left", left_on="name_id", right_on="name_id")

# %% [markdown]
# #### Monster description

# %%
tw_monster_desc_df = pd.DataFrame(tw_parsed_data["monster_desc"]).rename(columns={"value": "tw_desc"})
tw_monster_df = tw_monster_desc_df

en_monster_desc_df = pd.DataFrame(en_parsed_data["monster_desc"]).rename(columns={"value": "desc"})
en_monster_df = en_monster_desc_df

monster_all_df = pd.merge(tw_monster_df, en_monster_df, how="left", left_on="id", right_on="id")
monster_all_df["desc"] = monster_all_df["desc"].fillna(monster_all_df["tw_desc"])

monster_all_df = monster_all_df.drop("tw_desc", axis=1)

monster_all_df = monster_all_df.rename(columns={"id": "desc_id", "desc": "en_desc"})
monster_en_desc_df = monster_all_df.copy()

# %%
# monster_en_desc_df = pd.DataFrame(parsed_data["monster_desc"])
monster_en_desc_df["en_desc"] = monster_en_desc_df["en_desc"].apply(lambda x: str(x).replace("<color=#FFFFFF00>jayw</color>", ""))
monster_en_desc_df["en_desc"] = monster_en_desc_df["en_desc"].apply(lambda x: re.sub(r'\<[\/\w\=\#]*\>', '', x))
monster_en_desc_df["en_desc"] = monster_en_desc_df["en_desc"].apply(lambda x: str(x).replace("\\n", "").replace("\\", ""))
# monster_en_desc_df = monster_en_desc_df.rename(columns={"id": "desc_id", "value": "en_desc"})
monster_info_df["desc_id"] = monster_info_df["Desc"].apply(lambda x: str(x).replace('"', '').replace('MonsterCollection', ""))
monster_info_df = pd.merge(monster_info_df, monster_en_desc_df, how="left", left_on="desc_id", right_on="desc_id")

# %% [markdown]
# ### Filter to include field monster only

# %%
monster_df = monster_info_df[(~monster_info_df["DropListKV"].isnull()) & (~monster_info_df["navPos"].isnull()) & (~monster_info_df["en_name"].isnull()) & (~monster_info_df["en_name"].isnull())]
monster_df = monster_df[monster_df["level"] <= 120]
monster_df = monster_df[monster_df["id"] <= 20000]

monster_df = monster_df.drop_duplicates("en_name", keep="first")

# %%
monster_df
# Out:
#         id              name                    Desc  \
# 1    10002  MonsterName10002  MonsterCollection10002
# 2    10003  MonsterName10003  MonsterCollection10003
# 3    10004  MonsterName10004  MonsterCollection10004
# 4    10005  MonsterName10005  MonsterCollection10005
# 5    10006  MonsterName10006  MonsterCollection10006
# 6    10007  MonsterName10007  MonsterCollection10007
# 7    10008  MonsterName10008  MonsterCollection10008
# 8    10009  MonsterName10009  MonsterCollection10009
# 9    10010  MonsterName10010  MonsterCollection10010
# 10   10011  MonsterName10011  MonsterCollection10011
# 11   10012  MonsterName10012  MonsterCollection10012
# 12   10013  MonsterName10013  MonsterCollection10013
# 13   10014  MonsterName10014  MonsterCollection10014
# 14   10015  MonsterName10015  MonsterCollection10015
# 15   10016  MonsterName10016  MonsterCollection10016
# 16   10017  MonsterName10017  MonsterCollection10017
# 17   10018  MonsterName10018  MonsterCollection10018
# 18   10019  MonsterName10019  MonsterCollection10019
# 19   10020  MonsterName10020  MonsterCollection10020
# 20   10021  MonsterName10021  MonsterCollection10021
# 21   10022  MonsterName10022  MonsterCollection10022
# 22   10023  MonsterName10023  MonsterCollection10023
# 23   10024  MonsterName10024  MonsterCollection10024
# 24   10025  MonsterName10025  MonsterCollection10025
# 26   10027  MonsterName10027  MonsterCollection10027
# 27   10028  MonsterName10028  MonsterCollection10028
# 28   10029  MonsterName10029  MonsterCollection10029
# 29   10030  MonsterName10030  MonsterCollection10030
# 30   10031  MonsterName10031  MonsterCollection10031
# 32   10033  MonsterName10033  MonsterCollection10033
# 33   10034  MonsterName10034  MonsterCollection10034
# 34   10035  MonsterName10035  MonsterCollection10035
# 35   10036  MonsterName10036  MonsterCollection10036
# 36   10037  MonsterName10037  MonsterCollection10037
# 37   10038  MonsterName10038  MonsterCollection10038
# 38   10039  MonsterName10039  MonsterCollection10039
# 39   10040  MonsterName10040  MonsterCollection10040
# 40   10041  MonsterName10041  MonsterCollection10041
# 41   10042  MonsterName10042  MonsterCollection10042
# 42   10043  MonsterName10043  MonsterCollection10043
# 43   10044  MonsterName10044  MonsterCollection10044
# 44   10045  MonsterName10045  MonsterCollection10045
# 45   10046  MonsterName10046  MonsterCollection10046
# 46   10047  MonsterName10047  MonsterCollection10047
# 47   10048  MonsterName10048  MonsterCollection10048
# 48   10049  MonsterName10049  MonsterCollection10049
# 49   10050  MonsterName10050  MonsterCollection10050
# 50   10051  MonsterName10051  MonsterCollection10051
# 51   10052  MonsterName10052  MonsterCollection10052
# 52   10053  MonsterName10053  MonsterCollection10053
# 53   10054  MonsterName10054  MonsterCollection10054
# 54   10055  MonsterName10055  MonsterCollection10055
# 55   10056  MonsterName10056  MonsterCollection10056
# 56   10057  MonsterName10057  MonsterCollection10057
# 57   10058  MonsterName10058  MonsterCollection10058
# 58   10059  MonsterName10059  MonsterCollection10059
# 59   10060  MonsterName10060  MonsterCollection10060
# 60   10061  MonsterName10061  MonsterCollection10061
# 61   10062  MonsterName10062  MonsterCollection10062
# 62   10063  MonsterName10063  MonsterCollection10063
# 63   10064  MonsterName10064  MonsterCollection10064
# 64   10065  MonsterName10065  MonsterCollection10065
# 65   10066  MonsterName10066  MonsterCollection10066
# 66   10067  MonsterName10067  MonsterCollection10067
# 67   10068  MonsterName10068  MonsterCollection10068
# 68   10069  MonsterName10069  MonsterCollection10069
# 70   10071  MonsterName10071  MonsterCollection10071
# 71   10072  MonsterName10072  MonsterCollection10072
# 72   10073  MonsterName10073  MonsterCollection10073
# 73   10074  MonsterName10074  MonsterCollection10074
# 74   10075  MonsterName10075  MonsterCollection10075
# 75   10076  MonsterName10076  MonsterCollection10076
# 76   10077  MonsterName10077  MonsterCollection10077
# 77   10078  MonsterName10078  MonsterCollection10078
# 78   10079  MonsterName10079  MonsterCollection10079
# 79   10080  MonsterName10080  MonsterCollection10080
# 80   10081  MonsterName10081  MonsterCollection10081
# 81   10082  MonsterName10082  MonsterCollection10082
# 82   10083  MonsterName10083  MonsterCollection10083
# 83   10084  MonsterName10084  MonsterCollection10084
# 84   10085  MonsterName10085  MonsterCollection10085
# 85   10086  MonsterName10086  MonsterCollection10086
# 86   10087  MonsterName10087  MonsterCollection10087
# 87   10088  MonsterName10088  MonsterCollection10088
# 88   10089  MonsterName10089  MonsterCollection10089
# 89   10090  MonsterName10090  MonsterCollection10090
# 90   10091  MonsterName10091  MonsterCollection10091
# 91   10092  MonsterName10092  MonsterCollection10092
# 92   10093  MonsterName10093  MonsterCollection10093
# 93   10094  MonsterName10094  MonsterCollection10094
# 94   10095  MonsterName10095  MonsterCollection10095
# 95   10096  MonsterName10096  MonsterCollection10096
# 96   10097  MonsterName10097  MonsterCollection10097
# 97   10098  MonsterName10098  MonsterCollection10098
# 98   10099  MonsterName10099  MonsterCollection10099
# 99   10100  MonsterName10100  MonsterCollection10100
# 100  10101  MonsterName10101  MonsterCollection10101
# 101  10102  MonsterName10102  MonsterCollection10102
# 102  10103  MonsterName10103  MonsterCollection10103
# 103  10104  MonsterName10104  MonsterCollection10104
# 104  10105  MonsterName10105  MonsterCollection10105
# 105  10106  MonsterName10106  MonsterCollection10106
# 106  10107  MonsterName10107  MonsterCollection10107
# 107  10108  MonsterName10108  MonsterCollection10108
# 108  10109  MonsterName10109  MonsterCollection10109
# 109  10110  MonsterName10110  MonsterCollection10110
# 110  10111  MonsterName10111  MonsterCollection10111
# 111  10112  MonsterName10112  MonsterCollection10112
# 112  10113  MonsterName10113  MonsterCollection10113
# 113  10114  MonsterName10114  MonsterCollection10114
# 114  10115  MonsterName10115  MonsterCollection10115
# 115  10116  MonsterName10116  MonsterCollection10116
# 116  10117  MonsterName10117  MonsterCollection10117
# 117  10118  MonsterName10118  MonsterCollection10118
# 118  10119  MonsterName10119  MonsterCollection10119
# 119  10120  MonsterName10120  MonsterCollection10120
# 120  10121  MonsterName10121  MonsterCollection10121
# 121  10122  MonsterName10122  MonsterCollection10122
# 122  10123  MonsterName10123  MonsterCollection10123
# 123  10124  MonsterName10124  MonsterCollection10124
# 124  10125  MonsterName10125  MonsterCollection10125
# 125  10126  MonsterName10126  MonsterCollection10126
# 126  10127  MonsterName10127  MonsterCollection10127
# 127  10128  MonsterName10128  MonsterCollection10128
# 128  10129  MonsterName10129  MonsterCollection10129
# 129  10130  MonsterName10130  MonsterCollection10130
# 130  10131  MonsterName10131  MonsterCollection10131
# 131  10132  MonsterName10132  MonsterCollection10132
# 132  10133  MonsterName10133  MonsterCollection10133
# 133  10134  MonsterName10134  MonsterCollection10134
# 134  10135  MonsterName10135  MonsterCollection10135
# 135  10136  MonsterName10136  MonsterCollection10136
# 136  10137  MonsterName10137  MonsterCollection10137
# 137  10138  MonsterName10138  MonsterCollection10138
# 138  10139  MonsterName10139  MonsterCollection10139
# 140  10141  MonsterName10141  MonsterCollection10141
# 141  10142  MonsterName10142  MonsterCollection10142
# 142  10143  MonsterName10143  MonsterCollection10143
# 143  10144  MonsterName10144  MonsterCollection10144
# 144  10145  MonsterName10145  MonsterCollection10145
# 146  10147  MonsterName10147  MonsterCollection10147
# 147  10148  MonsterName10148  MonsterCollection10148
# 148  10149  MonsterName10149  MonsterCollection10149
# 149  10150  MonsterName10150  MonsterCollection10150
# 150  10151  MonsterName10151  MonsterCollection10151
# 151  10152  MonsterName10152  MonsterCollection10152
# 153  10154  MonsterName10154  MonsterCollection10154
# 154  10155  MonsterName10155  MonsterCollection10155
# 156  10157  MonsterName10157  MonsterCollection10157
# 157  10158  MonsterName10158  MonsterCollection10158
# 158  10159  MonsterName10159  MonsterCollection10159
# 162  10163  MonsterName10163  MonsterCollection10163
# 163  10164  MonsterName10164  MonsterCollection10164
# 165  10166  MonsterName10166  MonsterCollection10166
# 166  10167  MonsterName10167  MonsterCollection10167
# 167  10168  MonsterName10168  MonsterCollection10168
# 168  10170  MonsterName10170  MonsterCollection10170
# 169  10171  MonsterName10171  MonsterCollection10171
# 170  10172  MonsterName10172  MonsterCollection10172
# 171  10173  MonsterName10173  MonsterCollection10173
# 172  10175  MonsterName10175  MonsterCollection10175
# 173  10179  MonsterName10179  MonsterCollection10179
# 174  10180  MonsterName10180  MonsterCollection10180
# 175  10182  MonsterName10182  MonsterCollection10182
# 176  10184  MonsterName10184  MonsterCollection10184
# 177  10185  MonsterName10185  MonsterCollection10185
# 178  10187  MonsterName10187  MonsterCollection10187
# 179  10190  MonsterName10190  MonsterCollection10190
# 181  10192  MonsterName10192  MonsterCollection10192
# 182  10193  MonsterName10193  MonsterCollection10193
# 183  10194  MonsterName10194  MonsterCollection10194
# 184  10195  MonsterName10195  MonsterCollection10195
# 185  10196  MonsterName10196  MonsterCollection10196
# 186  10197  MonsterName10197  MonsterCollection10197
# 187  10198  MonsterName10198  MonsterCollection10198
# 188  10199  MonsterName10199  MonsterCollection10199
# 189  10200  MonsterName10200  MonsterCollection10200
# 190  10201  MonsterName10201  MonsterCollection10201
# 191  10202  MonsterName10202  MonsterCollection10202
# 192  10203  MonsterName10203  MonsterCollection10203
# 193  10204  MonsterName10204  MonsterCollection10204
# 194  10205  MonsterName10205  MonsterCollection10205
# 195  10206  MonsterName10206  MonsterCollection10206
# 196  10207  MonsterName10207  MonsterCollection10207
# 197  10208  MonsterName10208  MonsterCollection10208
# 198  10209  MonsterName10209  MonsterCollection10209
# 199  10210  MonsterName10210  MonsterCollection10210
# 200  10211  MonsterName10211  MonsterCollection10211
# 201  10212  MonsterName10212  MonsterCollection10212
# 202  10213  MonsterName10213  MonsterCollection10212
# 203  10214  MonsterName10214  MonsterCollection10214
# 204  10215  MonsterName10215  MonsterCollection10215
# 205  10216  MonsterName10216  MonsterCollection10216
# 206  10217  MonsterName10217  MonsterCollection10217
# 207  10218  MonsterName10218  MonsterCollection10218
# 208  10219  MonsterName10219  MonsterCollection10219
# 209  10220  MonsterName10220  MonsterCollection10220
# 210  10221  MonsterName10221  MonsterCollection10221
# 212  10223  MonsterName10223  MonsterCollection10223
# 213  10224  MonsterName10224  MonsterCollection10224
# 214  10225  MonsterName10225  MonsterCollection10225
# 215  10226  MonsterName10226  MonsterCollection10226
# 216  10227  MonsterName10227  MonsterCollection10227
# 217  10228  MonsterName10228  MonsterCollection10228
# 218  10229  MonsterName10229  MonsterCollection10229
# 219  10230  MonsterName10230  MonsterCollection10230
# 220  10231  MonsterName10231  MonsterCollection10231
# 221  10232  MonsterName10232  MonsterCollection10232
# 222  10233  MonsterName10233  MonsterCollection10233
# 223  10234  MonsterName10234  MonsterCollection10234
# 224  10235  MonsterName10235  MonsterCollection10235
# 225  10236  MonsterName10236  MonsterCollection10236
#
#                                             DropListKV  HasDieEffect  \
# 1    {'0': 1, '1000201': 1, '1000202': 1, '1000203'...           1.0
# 2    {'1000301': 1, '1000302': 1, '1000303': 1, '10...           1.0
# 3    {'1000401': 1, '1000403': 1, '1000404': 1, '10...           NaN
# 4    {'1000501': 1, '1000503': 1, '1000504': 1, '10...           1.0
# 5    {'1000601': 1, '1000602': 1, '1000603': 1, '10...           NaN
# 6    {'1000701': 1, '1000702': 1, '1000703': 1, '10...           NaN
# 7    {'1000801': 1, '1000802': 1, '1000803': 1, '10...           NaN
# 8    {'1000901': 1, '1000904': 1, '1000905': 1, '10...           NaN
# 9    {'1001001': 1, '1001002': 1, '1001003': 1, '10...           NaN
# 10   {'1001101': 1, '1001102': 1, '1001103': 1, '10...           1.0
# 11   {'1001201': 1, '1001202': 1, '1001203': 1, '10...           1.0
# 12   {'1001301': 1, '1001303': 1, '1001304': 1, '10...           1.0
# 13   {'1001401': 1, '1001402': 1, '1001403': 1, '10...           1.0
# 14   {'1001501': 1, '1001502': 1, '1001503': 1, '10...           NaN
# 15   {'1001601': 1, '1001602': 1, '1001603': 1, '10...           NaN
# 16   {'1001701': 1, '1001702': 1, '1001703': 1, '10...           NaN
# 17   {'1001801': 1, '1001802': 1, '1001803': 1, '10...           NaN
# 18   {'1001901': 1, '1001902': 1, '1001903': 1, '10...           NaN
# 19   {'1002001': 1, '1002003': 1, '1002004': 1, '10...           NaN
# 20   {'1002101': 1, '1002102': 1, '1002103': 1, '10...           NaN
# 21   {'1002201': 1, '1002204': 1, '1002205': 1, '10...           NaN
# 22   {'1002301': 1, '1002302': 1, '1002304': 1, '10...           NaN
# 23   {'1002401': 1, '1002402': 1, '1002403': 1, '10...           NaN
# 24   {'1002501': 1, '1002502': 1, '1002503': 1, '10...           NaN
# 26   {'1002701': 1, '1002702': 1, '1002703': 1, '10...           NaN
# 27   {'1002801': 1, '1002802': 1, '1002803': 1, '10...           NaN
# 28   {'1002901': 1, '1002902': 1, '1002903': 1, '10...           NaN
# 29   {'1003001': 1, '1003002': 1, '1003003': 1, '10...           NaN
# 30   {'1003101': 1, '1003102': 1, '1003103': 1, '10...           NaN
# 32   {'1003301': 1, '1003303': 1, '1003304': 1, '10...           NaN
# 33   {'1003402': 1, '1003403': 1, '1003404': 1, '10...           NaN
# 34   {'1003502': 1, '1003503': 1, '1003504': 1, '10...           NaN
# 35   {'1003601': 1, '1003602': 1, '1003603': 1, '10...           NaN
# 36   {'1003701': 1, '1003704': 1, '1003705': 1, '10...           NaN
# 37   {'1003801': 1, '1003802': 1, '1003803': 1, '10...           NaN
# 38   {'1003901': 1, '1003902': 1, '1003903': 1, '10...           NaN
# 39   {'1004001': 1, '1004002': 1, '1004003': 1, '10...           NaN
# 40   {'1004101': 1, '1004104': 1, '1004105': 1, '10...           NaN
# 41   {'1004201': 1, '1004202': 1, '1004204': 1, '10...           NaN
# 42   {'1004301': 1, '1004302': 1, '1004304': 1, '10...           NaN
# 43   {'1004401': 1, '1004404': 1, '1004405': 1, '10...           NaN
# 44   {'1004501': 1, '1004502': 1, '1004503': 1, '10...           NaN
# 45   {'1004601': 1, '1004602': 1, '1004603': 1, '10...           NaN
# 46   {'1004701': 1, '1004703': 1, '1004704': 1, '10...           NaN
# 47   {'1004801': 1, '1004804': 1, '1004805': 1, '10...           NaN
# 48   {'1004901': 1, '1004904': 1, '1004905': 1, '10...           NaN
# 49   {'1005001': 1, '1005002': 1, '1005003': 1, '10...           NaN
# 50   {'1005101': 1, '1005102': 1, '1005103': 1, '10...           NaN
# 51   {'1005201': 1, '1005203': 1, '1005204': 1, '10...           1.0
# 52   {'1005301': 1, '1005302': 1, '1005303': 1, '10...           NaN
# 53   {'1005401': 1, '1005402': 1, '1005404': 1, '10...           NaN
# 54   {'1005501': 1, '1005502': 1, '1005504': 1, '10...           NaN
# 55   {'1005601': 1, '1005602': 1, '1005603': 1, '10...           NaN
# 56   {'1005701': 1, '1005702': 1, '1005703': 1, '10...           NaN
# 57   {'1005801': 1, '1005802': 1, '1005804': 1, '10...           NaN
# 58   {'1005901': 1, '1005902': 1, '1005903': 1, '10...           NaN
# 59   {'1006001': 1, '1006002': 1, '1006004': 1, '10...           NaN
# 60   {'1006101': 1, '1006104': 1, '1006105': 1, '10...           NaN
# 61   {'1006201': 1, '1006203': 1, '1006204': 1, '10...           NaN
# 62   {'1006301': 1, '1006303': 1, '1006304': 1, '10...           NaN
# 63   {'1006401': 1, '1006404': 1, '1006405': 1, '10...           1.0
# 64   {'1006501': 1, '1006502': 1, '1006503': 1, '10...           NaN
# 65   {'1006601': 1, '1006602': 1, '1006603': 1, '10...           NaN
# 66   {'1006701': 1, '1006702': 1, '1006704': 1, '10...           NaN
# 67   {'1006801': 1, '1006802': 1, '1006803': 1, '10...           NaN
# 68   {'1006901': 1, '1006902': 1, '1006903': 1, '10...           NaN
# 70   {'1007101': 1, '1007102': 1, '1007103': 1, '10...           NaN
# 71   {'1007201': 1, '1007202': 1, '1007203': 1, '10...           NaN
# 72   {'1007301': 1, '1007302': 1, '1007303': 1, '10...           NaN
# 73   {'1007401': 1, '1007402': 1, '1007403': 1, '10...           NaN
# 74   {'1007501': 1, '1007502': 1, '1007503': 1, '10...           NaN
# 75   {'1007601': 1, '1007602': 1, '1007603': 1, '10...           NaN
# 76   {'1007701': 1, '1007702': 1, '1007703': 1, '10...           NaN
# 77   {'1007801': 1, '1007802': 1, '1007803': 1, '10...           NaN
# 78   {'1007901': 1, '1007902': 1, '1007903': 1, '10...           NaN
# 79   {'1008001': 1, '1008002': 1, '1008003': 1, '10...           NaN
# 80   {'1008101': 1, '1008102': 1, '1008103': 1, '10...           NaN
# 81   {'1008201': 1, '1008202': 1, '1008203': 1, '10...           NaN
# 82   {'1008301': 1, '1008302': 1, '1008303': 1, '10...           NaN
# 83   {'1008401': 1, '1008404': 1, '1008405': 1, '10...           NaN
# 84   {'1008501': 1, '1008502': 1, '1008504': 1, '10...           NaN
# 85   {'1008601': 1, '1008602': 1, '1008603': 1, '10...           NaN
# 86   {'1008701': 1, '1008704': 1, '1008705': 1, '10...           NaN
# 87   {'1008801': 1, '1008804': 1, '1008805': 1, '10...           NaN
# 88   {'1008901': 1, '1008903': 1, '1008904': 1, '10...           1.0
# 89   {'1009001': 1, '1009003': 1, '1009004': 1, '10...           1.0
# 90   {'1009101': 1, '1009102': 1, '1009103': 1, '10...           NaN
# 91   {'1009201': 1, '1009202': 1, '1009203': 1, '10...           NaN
# 92   {'1009301': 1, '1009302': 1, '1009303': 1, '10...           NaN
# 93   {'1009401': 1, '1009404': 1, '1009405': 1, '10...           NaN
# 94   {'1009501': 1, '1009504': 1, '1009505': 1, '10...           NaN
# 95   {'1009601': 1, '1009603': 1, '1009604': 1, '10...           NaN
# 96   {'1009701': 1, '1009704': 1, '1009705': 1, '10...           NaN
# 97   {'1009801': 1, '1009804': 1, '1009805': 1, '10...           NaN
# 98   {'1009901': 1, '1009903': 1, '1009904': 1, '10...           NaN
# 99   {'1010001': 1, '1010003': 1, '1010004': 1, '10...           1.0
# 100  {'1010101': 1, '1010103': 1, '1010104': 1, '10...           NaN
# 101  {'1010201': 1, '1010203': 1, '1010204': 1, '10...           NaN
# 102  {'1010301': 1, '1010304': 1, '1010305': 1, '10...           NaN
# 103  {'1010401': 1, '1010402': 1, '1010403': 1, '10...           NaN
# 104  {'1010501': 1, '1010503': 1, '1010504': 1, '10...           NaN
# 105  {'1010601': 1, '1010602': 1, '1010603': 1, '10...           NaN
# 106  {'1010701': 1, '1010702': 1, '1010703': 1, '10...           NaN
# 107  {'1010801': 1, '1010804': 1, '1010805': 1, '10...           NaN
# 108  {'1010901': 1, '1010902': 1, '1010903': 1, '10...           NaN
# 109  {'1011001': 1, '1011002': 1, '1011003': 1, '10...           NaN
# 110  {'1011101': 1, '1011102': 1, '1011103': 1, '10...           NaN
# 111  {'1011201': 1, '1011203': 1, '1011204': 1, '10...           NaN
# 112  {'1011301': 1, '1011302': 1, '1011303': 1, '10...           NaN
# 113  {'1011401': 1, '1011403': 1, '1011404': 1, '10...           NaN
# 114  {'1011501': 1, '1011502': 1, '1011503': 1, '10...           NaN
# 115  {'1011601': 1, '1011602': 1, '1011603': 1, '10...           NaN
# 116  {'1011701': 1, '1011703': 1, '1011704': 1, '10...           NaN
# 117  {'1011801': 1, '1011802': 1, '1011803': 1, '10...           NaN
# 118  {'1011901': 1, '1011902': 1, '1011903': 1, '10...           NaN
# 119  {'1012001': 1, '1012004': 1, '1012005': 1, '10...           NaN
# 120  {'1012101': 1, '1012102': 1, '1012103': 1, '10...           NaN
# 121  {'1012201': 1, '1012203': 1, '1012204': 1, '10...           NaN
# 122  {'1012301': 1, '1012302': 1, '1012303': 1, '10...           NaN
# 123  {'1012401': 1, '1012403': 1, '1012404': 1, '10...           NaN
# 124  {'1012501': 1, '1012502': 1, '1012503': 1, '10...           NaN
# 125  {'1012601': 1, '1012602': 1, '1012603': 1, '10...           NaN
# 126  {'1012701': 1, '1012702': 1, '1012703': 1, '10...           NaN
# 127  {'1012801': 1, '1012802': 1, '1012803': 1, '10...           NaN
# 128  {'1012901': 1, '1012903': 1, '1012904': 1, '10...           NaN
# 129  {'1013001': 1, '1013002': 1, '1013003': 1, '10...           NaN
# 130  {'1013101': 1, '1013102': 1, '1013103': 1, '10...           NaN
# 131  {'1013201': 1, '1013202': 1, '1013204': 1, '10...           1.0
# 132  {'1013301': 1, '1013303': 1, '1013304': 1, '10...           NaN
# 133  {'1013401': 1, '1013403': 1, '1013404': 1, '10...           NaN
# 134  {'1013501': 1, '1013504': 1, '1013505': 1, '10...           1.0
# 135  {'1013601': 1, '1013603': 1, '1013604': 1, '10...           NaN
# 136  {'1013701': 1, '1013702': 1, '1013703': 1, '10...           NaN
# 137  {'1013801': 1, '1013803': 1, '1013804': 1, '10...           NaN
# 138  {'1013901': 1, '1013903': 1, '1013904': 1, '10...           NaN
# 140  {'1014101': 1, '1014102': 1, '1014103': 1, '10...           NaN
# 141  {'1014201': 1, '1014204': 1, '1014205': 1, '10...           NaN
# 142  {'1014301': 1, '1014304': 1, '1014305': 1, '10...           1.0
# 143  {'1014401': 1, '1014403': 1, '1014404': 1, '10...           NaN
# 144  {'1014501': 1, '1014504': 1, '1014505': 1, '10...           NaN
# 146  {'1014701': 1, '1014703': 1, '1014704': 1, '10...           NaN
# 147  {'1014801': 1, '1014804': 1, '1014805': 1, '10...           NaN
# 148  {'1014901': 1, '1014902': 1, '1014903': 1, '10...           NaN
# 149  {'1015001': 1, '1015003': 1, '1015004': 1, '10...           NaN
# 150  {'1015101': 1, '1015103': 1, '1015104': 1, '10...           NaN
# 151  {'1015201': 1, '1015202': 1, '1015203': 1, '10...           NaN
# 153  {'1015401': 1, '1015403': 1, '1015404': 1, '10...           NaN
# 154  {'1015501': 1, '1015504': 1, '1015505': 1, '10...           1.0
# 156  {'1015701': 1, '1015704': 1, '1015705': 1, '10...           NaN
# 157  {'1015801': 1, '1015802': 1, '1015803': 1, '10...           NaN
# 158  {'1015901': 1, '1015902': 1, '1015903': 1, '10...           NaN
# 162  {'1016301': 1, '1016302': 1, '1016304': 1, '10...           NaN
# 163  {'1016401': 1, '1016404': 1, '1016405': 1, '10...           NaN
# 165  {'1016601': 1, '1016602': 1, '1016603': 1, '10...           NaN
# 166  {'1016701': 1, '1016704': 1, '1016705': 1, '10...           NaN
# 167  {'1016801': 1, '1016804': 1, '1016805': 1, '10...           NaN
# 168  {'1017001': 1, '1017003': 1, '1017004': 1, '10...           NaN
# 169  {'1017101': 1, '1017102': 1, '1017103': 1, '10...           NaN
# 170  {'1017201': 1, '1017204': 1, '1017205': 1, '10...           NaN
# 171  {'10173': 1, '1017301': 1, '1017302': 1, '1017...           NaN
# 172  {'10175': 1, '1017501': 1, '1017502': 1, '1017...           NaN
# 173  {'10173': 1, '1017901': 1, '1017903': 1, '1017...           NaN
# 174  {'10173': 1, '1018001': 1, '1018004': 1, '1018...           NaN
# 175  {'10173': 1, '1018201': 1, '1018202': 1, '1018...           NaN
# 176  {'10175': 1, '1018401': 1, '1018403': 1, '1018...           NaN
# 177  {'10174': 1, '1018501': 1, '1018503': 1, '1018...           NaN
# 178  {'10174': 1, '1018701': 1, '1018704': 1, '1018...           NaN
# 179  {'10175': 1, '1019001': 1, '1019003': 1, '1019...           NaN
# 181  {'10175': 1, '1019201': 1, '1019203': 1, '1019...           NaN
# 182  {'10174': 1, '1019301': 1, '1019302': 1, '1019...           NaN
# 183  {'10175': 1, '1019401': 1, '1019404': 1, '1019...           NaN
# 184  {'10175': 1, '1019501': 1, '1019505': 1, '1019...           NaN
# 185  {'10173': 1, '1019601': 1, '1019602': 1, '1019...           NaN
# 186  {'10173': 1, '1019701': 1, '1019702': 1, '1019...           NaN
# 187  {'10174': 1, '1019801': 1, '1019802': 1, '1019...           NaN
# 188  {'10173': 1, '1019901': 1, '1019902': 1, '1019...           NaN
# 189  {'10174': 1, '1020001': 1, '1020002': 1, '1020...           NaN
# 190  {'10174': 1, '1020101': 1, '1020102': 1, '1020...           NaN
# 191  {'10174': 1, '1020201': 1, '1020202': 1, '1020...           NaN
# 192  {'10174': 1, '1020301': 1, '1020302': 1, '1020...           NaN
# 193  {'10173': 1, '1020401': 1, '1020404': 1, '1020...           NaN
# 194  {'10173': 1, '1020501': 1, '1020502': 1, '1020...           NaN
# 195  {'10174': 1, '1020601': 1, '1020603': 1, '1020...           NaN
# 196  {'10173': 1, '1020701': 1, '1020702': 1, '1020...           NaN
# 197  {'10175': 1, '1020801': 1, '1020802': 1, '1020...           NaN
# 198  {'10175': 1, '1020901': 1, '1020903': 1, '1020...           NaN
# 199  {'10174': 1, '1021001': 1, '1021002': 1, '1021...           NaN
# 200  {'10175': 1, '1021101': 1, '1021104': 1, '1021...           NaN
# 201  {'10174': 1, '1021201': 1, '1021202': 1, '1021...           NaN
# 202  {'10174': 1, '1021201': 1, '1021202': 1, '1021...           NaN
# 203  {'10174': 1, '1021401': 1, '1021404': 1, '1021...           NaN
# 204  {'10175': 1, '1021501': 1, '1021504': 1, '1021...           NaN
# 205  {'10174': 1, '1021201': 1, '1021202': 1, '1021...           NaN
# 206  {'10173': 1, '1021701': 1, '1021702': 1, '1021...           NaN
# 207  {'10174': 1, '1021201': 1, '1021202': 1, '1021...           NaN
# 208  {'1021901': 1, '1021903': 1, '1021904': 1, '10...           NaN
# 209  {'10174': 1, '1022001': 1, '1022002': 1, '1022...           NaN
# 210  {'10173': 1, '1022101': 1, '1022103': 1, '1022...           NaN
# 212  {'10174': 1, '1022301': 1, '1022303': 1, '1022...           NaN
# 213  {'10174': 1, '1022401': 1, '1022402': 1, '1022...           NaN
# 214  {'10173': 1, '1022501': 1, '1022502': 1, '1022...           NaN
# 215  {'10175': 1, '1022601': 1, '1022603': 1, '1022...           NaN
# 216  {'10174': 1, '1022701': 1, '1022703': 1, '1022...           NaN
# 217  {'10174': 1, '1022801': 1, '1022803': 1, '1022...           NaN
# 218  {'10174': 1, '1022901': 1, '1022902': 1, '1022...           NaN
# 219  {'10175': 1, '1023001': 1, '1023003': 1, '1023...           NaN
# 220  {'10174': 1, '1023101': 1, '1023104': 1, '1023...           NaN
# 221  {'10174': 1, '1023201': 1, '1023202': 1, '1023...           NaN
# 222  {'10174': 1, '1023301': 1, '1023302': 1, '1023...           NaN
# 223  {'10174': 1, '1023401': 1, '1023402': 1, '1023...           NaN
# 224  {'10174': 1, '1023501': 1, '1023502': 1, '1023...           NaN
# 225  {'10175': 1, '1023601': 1, '1023602': 1, '1023...           NaN
#
#      IfCanShowInDpsTest    PetId  \
# 1                   1.0      NaN
# 2                   1.0      NaN
# 3                   1.0  82003.0
# 4                   1.0      NaN
# 5                   1.0      NaN
# 6                   1.0      NaN
# 7                   1.0      NaN
# 8                   1.0      NaN
# 9                   1.0  82007.0
# 10                  1.0      NaN
# 11                  1.0      NaN
# 12                  1.0      NaN
# 13                  1.0      NaN
# 14                  1.0      NaN
# 15                  1.0  82011.0
# 16                  1.0      NaN
# 17                  1.0      NaN
# 18                  1.0      NaN
# 19                  1.0      NaN
# 20                  1.0      NaN
# 21                  1.0      NaN
# 22                  1.0      NaN
# 23                  1.0      NaN
# 24                  1.0      NaN
# 26                  1.0  82005.0
# 27                  1.0      NaN
# 28                  1.0      NaN
# 29                  1.0      NaN
# 30                  1.0      NaN
# 32                  1.0      NaN
# 33                  1.0      NaN
# 34                  1.0      NaN
# 35                  1.0      NaN
# 36                  1.0      NaN
# 37                  1.0      NaN
# 38                  1.0      NaN
# 39                  1.0      NaN
# 40                  1.0      NaN
# 41                  1.0      NaN
# 42                  1.0      NaN
# 43                  1.0  82009.0
# 44                  1.0      NaN
# 45                  1.0      NaN
# 46                  1.0      NaN
# 47                  1.0      NaN
# 48                  1.0      NaN
# 49                  1.0      NaN
# 50                  1.0      NaN
# 51                  1.0      NaN
# 52                  1.0      NaN
# 53                  1.0      NaN
# 54                  1.0      NaN
# 55                  1.0      NaN
# 56                  1.0      NaN
# 57                  1.0      NaN
# 58                  1.0      NaN
# 59                  1.0      NaN
# 60                  1.0      NaN
# 61                  1.0      NaN
# 62                  1.0      NaN
# 63                  1.0      NaN
# 64                  1.0      NaN
# 65                  1.0      NaN
# 66                  1.0      NaN
# 67                  1.0      NaN
# 68                  1.0      NaN
# 70                  1.0      NaN
# 71                  1.0      NaN
# 72                  1.0      NaN
# 73                  1.0      NaN
# 74                  1.0      NaN
# 75                  1.0      NaN
# 76                  1.0      NaN
# 77                  1.0      NaN
# 78                  1.0      NaN
# 79                  1.0      NaN
# 80                  1.0      NaN
# 81                  1.0      NaN
# 82                  1.0      NaN
# 83                  1.0      NaN
# 84                  1.0      NaN
# 85                  1.0      NaN
# 86                  1.0      NaN
# 87                  1.0      NaN
# 88                  1.0      NaN
# 89                  1.0      NaN
# 90                  1.0      NaN
# 91                  1.0      NaN
# 92                  1.0      NaN
# 93                  1.0      NaN
# 94                  1.0      NaN
# 95                  1.0      NaN
# 96                  1.0      NaN
# 97                  1.0      NaN
# 98                  1.0      NaN
# 99                  1.0      NaN
# 100                 1.0      NaN
# 101                 1.0      NaN
# 102                 1.0      NaN
# 103                 1.0      NaN
# 104                 1.0      NaN
# 105                 1.0      NaN
# 106                 1.0      NaN
# 107                 1.0      NaN
# 108                 1.0      NaN
# 109                 1.0      NaN
# 110                 1.0      NaN
# 111                 1.0      NaN
# 112                 1.0      NaN
# 113                 1.0      NaN
# 114                 1.0      NaN
# 115                 1.0      NaN
# 116                 1.0      NaN
# 117                 1.0      NaN
# 118                 1.0      NaN
# 119                 1.0      NaN
# 120                 1.0      NaN
# 121                 1.0      NaN
# 122                 1.0      NaN
# 123                 NaN      NaN
# 124                 1.0      NaN
# 125                 1.0      NaN
# 126                 1.0      NaN
# 127                 1.0      NaN
# 128                 1.0      NaN
# 129                 1.0      NaN
# 130                 1.0      NaN
# 131                 1.0      NaN
# 132                 1.0      NaN
# 133                 1.0      NaN
# 134                 1.0      NaN
# 135                 1.0      NaN
# 136                 1.0      NaN
# 137                 1.0      NaN
# 138                 1.0      NaN
# 140                 1.0      NaN
# 141                 1.0      NaN
# 142                 1.0      NaN
# 143                 1.0      NaN
# 144                 1.0      NaN
# 146                 1.0      NaN
# 147                 1.0      NaN
# 148                 1.0      NaN
# 149                 1.0      NaN
# 150                 1.0      NaN
# 151                 1.0      NaN
# 153                 1.0      NaN
# 154                 1.0      NaN
# 156                 1.0      NaN
# 157                 1.0      NaN
# 158                 1.0      NaN
# 162                 1.0      NaN
# 163                 1.0      NaN
# 165                 1.0      NaN
# 166                 1.0      NaN
# 167                 1.0      NaN
# 168                 1.0      NaN
# 169                 1.0      NaN
# 170                 1.0      NaN
# 171                 1.0      NaN
# 172                 1.0      NaN
# 173                 1.0      NaN
# 174                 1.0      NaN
# 175                 1.0      NaN
# 176                 1.0      NaN
# 177                 1.0      NaN
# 178                 1.0      NaN
# 179                 1.0      NaN
# 181                 1.0      NaN
# 182                 1.0      NaN
# 183                 1.0      NaN
# 184                 1.0      NaN
# 185                 1.0      NaN
# 186                 1.0      NaN
# 187                 1.0      NaN
# 188                 1.0      NaN
# 189                 1.0      NaN
# 190                 1.0      NaN
# 191                 1.0      NaN
# 192                 1.0      NaN
# 193                 1.0      NaN
# 194                 1.0      NaN
# 195                 1.0      NaN
# 196                 1.0      NaN
# 197                 1.0      NaN
# 198                 1.0      NaN
# 199                 1.0      NaN
# 200                 1.0      NaN
# 201                 1.0      NaN
# 202                 1.0      NaN
# 203                 1.0      NaN
# 204                 1.0      NaN
# 205                 1.0      NaN
# 206                 1.0      NaN
# 207                 1.0      NaN
# 208                 NaN      NaN
# 209                 1.0      NaN
# 210                 NaN      NaN
# 212                 1.0      NaN
# 213                 1.0      NaN
# 214                 1.0      NaN
# 215                 1.0      NaN
# 216                 1.0      NaN
# 217                 1.0      NaN
# 218                 1.0      NaN
# 219                 1.0      NaN
# 220                 1.0      NaN
# 221                 1.0      NaN
# 222                 1.0      NaN
# 223                 1.0      NaN
# 224                 1.0      NaN
# 225                 1.0      NaN
#
#                                                Weather  alertRange  aniSpeed  \
# 1    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.50
# 2    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         0.0       NaN
# 3    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         7.0       NaN
# 4    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         0.0       NaN
# 5    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 6    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 7    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      5.00
# 8    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 9    [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         2.0      3.30
# 10   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.00
# 11   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 12   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         0.0       NaN
# 13   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         7.0      3.80
# 14   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      1.80
# 15   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      5.00
# 16   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      6.00
# 17   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      0.83
# 18   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.30
# 19   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 20   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.50
# 21   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0       NaN
# 22   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 23   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      7.00
# 24   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.50
# 26   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      6.00
# 27   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      1.50
# 28   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.50
# 29   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      6.00
# 30   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 32   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 33   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.50
# 34   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      7.00
# 35   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      1.40
# 36   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 37   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      2.30
# 38   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      2.50
# 39   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.10
# 40   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         4.0      3.50
# 41   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 42   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      8.00
# 43   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      6.00
# 44   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 45   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.30
# 46   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.80
# 47   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.50
# 48   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.50
# 49   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      7.00
# 50   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 51   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.00
# 52   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 53   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      5.00
# 54   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.30
# 55   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.50
# 56   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      5.00
# 57   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 58   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 59   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      6.00
# 60   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.00
# 61   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 62   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 63   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      6.00
# 64   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.80
# 65   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 66   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.50
# 67   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.70
# 68   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 70   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.00
# 71   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 72   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0       NaN
# 73   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      5.00
# 74   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.80
# 75   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 76   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 77   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 78   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.00
# 79   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.50
# 80   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.50
# 81   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.50
# 82   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.50
# 83   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      8.00
# 84   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.50
# 85   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 86   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.60
# 87   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 88   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.50
# 89   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.50
# 90   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 91   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN     10.00
# 92   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 93   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 94   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      1.00
# 95   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 96   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.60
# 97   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.80
# 98   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         2.0      7.00
# 99   [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      0.90
# 100  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.80
# 101  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 102  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      4.00
# 103  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      4.00
# 104  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      7.50
# 105  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      6.00
# 106  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 107  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      5.50
# 108  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.70
# 109  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.70
# 110  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.70
# 111  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.70
# 112  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.70
# 113  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.70
# 114  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.70
# 115  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.40
# 116  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.50
# 117  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      2.50
# 118  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      1.70
# 119  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      1.50
# 120  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0       NaN
# 121  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      2.10
# 122  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.50
# 123  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      7.50
# 124  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.50
# 125  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.50
# 126  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      3.00
# 127  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 128  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 129  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         8.0      2.40
# 130  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.40
# 131  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.20
# 132  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 133  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.50
# 134  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0     12.00
# 135  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 136  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 137                                                NaN         NaN      8.00
# 138                                                NaN         NaN      3.00
# 140  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 141                                                NaN         NaN      3.00
# 142  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         0.0       NaN
# 143  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 144  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 146  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 147  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.00
# 148  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      3.30
# 149  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      2.30
# 150  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.00
# 151  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      1.00
# 153  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      3.50
# 154  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0       NaN
# 156  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      2.60
# 157  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN       NaN
# 158  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      4.00
# 162  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         NaN      4.00
# 163  [{'AffixMonsterRate': 0, 'Prefix': [{'AffixId'...         3.0      4.00
# 165                                                NaN         NaN      3.00
# 166                                                NaN         NaN      2.00
# 167                                                NaN         3.0      6.00
# 168                                                NaN         NaN      3.00
# 169                                                NaN         3.0      3.00
# 170                                                NaN         3.0      2.00
# 171                                                NaN         NaN      3.00
# 172                                                NaN         NaN      9.00
# 173                                                NaN         NaN      3.00
# ...
# 129                Kobold Archer   10130
# 130          Axe-wielding Kobold   10131
# 131                         Jakk   10132
# 132                   Marionette   10133
# 133                    Deviruchi   10134
# 134                    Nightmare   10135
# 135                        Cramp   10136
# 136                         Punk   10137
# 137                      Bathory   10138
# 138                        Alarm   10139
# 140                        Clock   10141
# 141          Clock Tower Manager   10142
# 142                    Ant Larva   10143
# 143                     Penomena   10144
# 144             Soldier Skeleton   10145
# 146                Dead Plankton   10147
# 147  Dagger-wielding Skel Pirate   10148
# 148                       Rocker   10149
# 149                    Sasquatch   10150
# 150                 Baphomet Jr.   10151
# 151                Picky (Shell)   10152
# 153                       Anubis   10154
# 154                Giant Whisper   10155
# 156             Skeleton General   10157
# 157                     Orc Baby   10158
# 158                  Rotar Zairo   10159
# 162                   Wind Ghost   10163
# 163                       Wraith   10164
# 165                        Carat   10166
# 166                    Injustice   10167
# 167                      Raydric   10168
# 168               Raydric Archer   10170
# 169                    Majoruros   10171
# 170              Zombie Prisoner   10172
# 171                     Brilight   10173
# 172                        Joker   10175
# 173                     Sageworm   10179
# 174                   Dark Frame   10180
# 175                        Sting   10182
# 176                  Khalitzburg   10184
# 177                    Zherlthsh   10185
# 178            Skeleton Prisoner   10187
# 179                        Rybio   10190
# 181                     Phendark   10192
# 182                     Wanderer   10193
# 183               Abysmal Knight   10194
# 184                Bloody Knight   10195
# 185                        Aster   10196
# 186                         Crab   10197
# 187                    Sea Otter   10198
# 188                      Raggler   10199
# 189                      Anolian   10200
# 190                    Stem Worm   10201
# 191                   Thara Frog   10202
# 192                     Galapago   10203
# 193                         Pest   10204
# 194                    Tri Joint   10205
# 195                        Rogue   10206
# 196                       Nereid   10207
# 197                    Alligator   10208
# 198                     Megalith   10209
# 199                         Seal   10210
# 200              Stalactic Golem   10211
# 201                     Gargoyle   10212
# 202                         Lude   10212
# 203                       Medusa   10214
# 204              Bloody Murderer   10215
# 205                         Quve   10216
# 206                  Beetle King   10217
# 207                   Heirozoist   10218
# 208                  Flame Skull   10219
# 209               Wootan Shooter   10220
# 210                    Hellhound   10221
# 212                Ragged Zombie   10223
# 213               Wootan Fighter   10224
# 214                        Choco   10225
# 215                       Gibbet   10226
# 216             Zombie Slaughter   10227
# 217                     Dullahan   10228
# 218                     Parasite   10229
# 219                    Loli Ruri   10230
# 220                      Banshee   10231
# 221                  Dragon Tail   10232
# 222                        Dryad   10233
# 223                Stone Shooter   10234
# 224                      Driller   10235
# 225                 Wooden Golem   10236
#
#                                                en_desc
# 1     Fabres, often found near crops, has only one ...
# 2     When Fabres reach a certain stage of growth, ...
# 3     The bunny monster which dwells near Prontera ...
# 4     In the kingdom's sewers, brown spherical obje...
# 5     A flying monster with big watery eyes. Accord...
# 6     A sentient plant monster freed from the restr...
# 7     An amazing saltwater frog most often found dw...
# 8     Once an insignificant bug, but mutated once c...
# 9     A grasshopper-shaped monster with a violin in...
# 10    A cute chick monster that never seems to grow...
# 11    A Fire Poring with a cute appearance similar ...
# 12    Pecopeco Egg Shells can be grounded into a sh...
# 13    Condors living in the desert are extremely pr...
# 14    A monster which passes off as cute and innoce...
# 15    To quicken the growth of their pups, Desert W...
# 16    A bird monster which can only walk upright de...
# 17    A desert monster with amazing facial expressi...
# 18    Some Grasshoppers have gone astray in the pur...
# 19    New adventurers easily overlook how poisonous...
# 20    A formidable existence in the desert. Its sti...
# 21    A monster with very obvious man-made traces. ...
# 22    Few are the adventurers who have seen Hodes i...
# 23    Due to the cruel experiences they went throug...
# 24    A dangerous-looking animal with ugly features...
# 26    Death after a stinging attack is a thing of t...
# 27    A slow, crawling animal on the surface. The m...
# 28    A mouse with a giant onion growing on its bod...
# 29    A Chonchon that is fast-moving and with sharp...
# 30    An aggressive fellow. The Horn on its head is...
# 32    An Anacondaq residing inside a pyramid. Altho...
# 33    The branch of Petite dragons dwelling on land...
# 34    The branch of Petite dragons capable of fligh...
# 35    Monster researchers have discovered after man...
# 36    A strange creature shrouded in mystery, shari...
# 37    A large bear with brown fur. Docile in nature...
# 38    No discovery of baby monsters with matching b...
# 39    Magnolia, with its mysterious origins, has al...
# 40    Demi-humans from a primitive civilization. Re...
# 41    Flames wandering where the dead are found. An...
# 42    A stone tablet inscribed with "Great General ...
# 43    A weak creature living in the darkness. Unles...
# 44    Appears harmless, but the Spore Hat on its he...
# 45    A very docile monster that likes playing with...
# 46    Permanently dwells in the damp and dark sewer...
# 47    A mutated Thief Bug monster corrupted by the ...
# 48    A mutated Thief Bug monster corrupted by the ...
# 49    Pack monsters. They appear to be like a norma...
# 50    A colorful carnivorous plant that wanders aim...
# 51    Although the Poison Poporing also has a sizab...
# 52    An Anacondaq living in Payon's forests. It lo...
# 53    Fabre's imago form. It only inhabits the Laby...
# 54    A brightly colored insect. It has many natura...
# 55    It belongs to the same race as Chonchons but ...
# 56    A cute monster with a big tail. The bushy tai...
# 57    Despite having the appearance of a cute anima...
# 58    A weak and cowardly monster willing to sacrif...
# 59    Often, some adventurer is deceived by the inn...
# 60    A skeleton dressed as a sailor. They must hav...
# 61   在邪骸家族庞大的族谱中，似乎只是一支不起眼的旁系，但依然无法改变它们拥有残暴天性的事实。下颚...
# 62    A mushroom monster that appears in dark sewer...
# 63    A ghostly creature drifting aboard the Treasu...
# 64    A Carapace animal living on the seabed, it oc...
# 65    A bright-colored mollusk living on the seabed...
# 66   栖息在克克魔海边的浅滩上，性格胆小怯懦，一般不会主动攻击人类，只有在受到威胁时才会爆发出惊人...
# 67    An aggressive sea warrior. Despite being a ta...
# 68    A cute, naive, and peaceful sea creature and ...
# 70   A gloomy underwater creature, which is said to...
# 71    A fighter of the sea, battling continually wi...
# 72    Usually curled into a ball in a corner and co...
# 73    The most common fish in the sea, mutated as a...
# 74    An intelligent creature living on the seabed ...
# 75    Many adventurers find themselves going soft-h...
# 76   鱼首人身的魔物，拥有两套呼吸系统，可以同时适应陆上和水中的生活。平时蛰伏于深海中，有时会因为...
# 77    A fish with a very strange ecology. Apparentl...
# 78    A Deviace may appear to move slowly, but the ...
# 79    Ordinary inhabitants with golden bodies. Howe...
# 80    Builders with yellowish green bodies. They ar...
# 81    Defenders with red bodies. They are the regul...
# 82    Maya guards with black bodies. Their special ...
# 83    A mutated form of Familiars living in the Ant...
# 84    A Demi-Human monster that sighs "waka waka" a...
# 85    Appears to look like a strange beetle. Howeve...
# 86    Skel Pirates have simple equipment but they m...
# 87    A corpse wandering in the world without consc...
# 88    An undead creature with an exotic aura that i...
# 89    An undead creature with an exotic aura and, f...
# 90    An undead creature with an exotic aura and ve...
# 91    An animal symbolizing good luck in Payon's cu...
# 92    A very cowardly creature. Very few humans hav...
# 93    Miners who met with a mining accident and sti...
# 94    A mysterious monster living in the Jade and S...
# 95    In her right hand a crucifix twined with rose...
# 96    Very skilled in the techniques of wielding tw...
# 97    An archer without any combat skills but has p...
# 98    Its appearance resembles wolves, but it is re...
# 99    All of them were ancient Egyptian noblemen be...
# 100   A pet carcass reborn after absorbing power fr...
# 101   From their attire, they look to be ancient ad...
# 102   Serpent spirits with extraordinarily bewitchi...
# 103   An ox monster wielding a heavy Warhammer in i...
# 104   Originally a normal spider, it mutated after ...
# 105   Why it carries a retro messenger bag all year...
# 106   It is difficult to determine whether it is an...
# 107   A strange insect with a hundred feet and stra...
# 108   The fifth in the goblin family. Possesses imm...
# 109   The fourth in the goblin family. Brawny and a...
# 110   The third in the goblin family. It can move w...
# 111   The second in the Goblin family. Slow in move...
# 112   The eldest in the Goblin family. Has superb d...
# 113   A highly intelligent member of the Goblin fam...
# 114   A highly intelligent Goblin. The jet machine ...
# 115   Stonemasons who took part in the building of ...
# 116   Carpenters who took part in building the Sphi...
# 117   Originally an ancient Egyptian warlock, but t...
# 118   Nobody knows their exact identity, and whethe...
# 119   If an orc fights to its last moments without ...
# 120   The Orcs are the best example of a race in wh...
# 121   The shaman magic handed down amongst Orcs can...
# 122   A female orc, but its combat abilities are in...
# 123   It is said that they are a branch of orcs cur...
# 124   The formidable ones of the Chonchons. Apart f...
# 125   An Orc that uses a bow and arrows as its weap...
# 126   An Orc Warrior who has already proved itself,...
# 127   A Chain-wielding Kobold warrior with the inbo...
# 128   A Hammer-wielding Kobold warrior with the inb...
# 129   A Kobold good at using crossbows and with the...
# 130   A Kobold good at using axes. They keep a supe...
# 131   An elegant gentleman in black formal wear wit...
# 132   A monster wandering around blindly undergroun...
# 133   A troublemaker amongst Demons. It holds a min...
# 134   Demons born from people's nightmares. Their p...
# 135   Compared to a common Tarou, Cramps have a stu...
# 136   The Punk that inhabits one of the floors of t...
# 137   When one thinks of witches, one typically ass...
# 138   Monsters with clock-like appearances tend to ...
# 140   Clocks are a slow-moving monster. Its cumbers...
# 141   These guardians have been devoutly guarding t...
# 142   The infant form of Ants. Completely impossibl...
# 143   "Penomena tentacles are soft and chewy, and h...
# 144   If you underestimate it just because it looks...
# 146   Despite being very similar to Planktons, its ...
# 147   A Skel Pirate equipped with a double-edged da...
# 148   Those Grasshoppers that pursued music with mo...
# 149   A large bear with pure white fur. Docile in n...
# 150   Apart from their mini stature, there is almos...
# 151   Dwells together with the Picky in Morroc all ...
# 153   A messenger transformed from the soul power l...
# 154   Legend has it that a Whisper's Cloth is actua...
# 156   The strongest warrior amongst Skeletons. Its ...
# 157   A baby orc. Its adorable features betray no h...
# 158   A Goblin which battles by controlling some st...
# 162   A Wizard obsessed with studying magic before ...
# 163   An Undead monster which perished due to starv...
# 165   A clown troupe performing at a noble banquet ...
# 166   Once a great power of the world, Glast Heim w...
# 167   As the only soldiers of the Chivalry whose bo...
# 168   As the empire's former iron bastion, although...
# 169   Majoruros brandishes the large hammer in its ...
# 170   In the long-abandoned Glast Heim Prison roams...
# 171   It is similar in appearance to a common Stain...
# 172   If I have to name a monster that is the epito...
# 173   As the oldest group of insect monsters, they ...
# 174   Just who was it who sealed Dark Frame in the ...
# 175   Perhaps it is because they have been entangle...
# 176   Who could have imagined that in the glorious ...
# 177   Although the Zherlthsh roaming the Glast Heim...
# 178   A civilization's prosperity is always accompa...
# 179   With one hand wielding a hook and the other w...
# 181   Phendarks with absolute power are the last ba...
# 182   Battle is their entire reason for being. In t...
# 183   Once the world-renowned White Knights of Glas...
# 184   If it is not for the bloody stench of their b...
# 185  潜伏在浅海处的珊瑚礁中，借由珊瑚鲜艳的外表来隐藏自己，伺机捕猎路过的鱼类。身上有着形似瞳孔的...
# 186  当钝拙的双钳不再适应海底暗流涌动的生活，就连螃蟹也会想要安享晚年。而平静悠然的克魔岛显然是个...
# 187  本应是栖息在海洋中的魔物，近年来却渐渐迁移到了干燥的沙漠地带居住。为了适应陆地上的生活而藏起...
# 188  由于双翼较为短小而无法飞翔，天生跛足则被认为是一种遗传性的基因疾病。据说毕生都在寻找重新回到...
# 189  具有社会性的魔物，族群内等级森明、分工明确，具有较强的学习能力，可以使用工具。喜欢在潮湿的水...
# 190  背脊上高耸的枝干是为了吸收阳光存在，可以在向阳的地方一动不动待上一整天。而令人惊奇的是，灰森...
# 191  与喜欢将身体全部浸泡在海水中的罗达娃不同，达拉蛙更热衷于将身体暴露在空气中，借由体表所分泌的...
# 192  会将巢穴筑造在沙地中的神奇企鹅，在习性上比起鸟类，似乎与土拨鼠更为相似。虽然体型圆润，动作却...
# 193  虽然名为单眼虫，但看起来很像瞳孔的器官其实是口器，真正的眼睛则因为长时间生活在地底而完全失去...
# 194  拥有坚硬背壳的虫类魔物，多足无翅，上颚突出如角，可以用来捕食猎物或威吓敌人。个体寿命极短，但...
# 195  盘踞在美妙铃音乐队驻地外围的不良团伙，主要工作是打家劫舍，对象有且只有驻地内的舞娘与吟游诗人...
# 196  身体细长、光滑无阻，四肢短小但肌肉发达，移动起来十分迅速。拥有一对隐藏在口腔皮下的毒腺，会在...
# 197  群居在基乃依沼泽的东北部，以湖泊河流为据点的魔物，善于通过水流来隐藏自己并狩猎食物。虽然外表...
# 198  十分古老而又神秘的魔物，一生中大部分时间都在休眠，仅靠着克魔岛洞穴中充盈的魔力维持生存，基本...
# 199  记性很差的魔物，总是抱着脑袋回忆重要的事情，一旦想不起来就会陷入暴躁状态，引发剧烈的头痛症状...
# 200  被誉为魔物中最坚固的壁垒，几乎无法从物理层面对其造成伤害。但与此相对，移动力和敏捷性则大大降...
# 201  以速度和平衡性见长的魔物，同时也拥有极佳的动态视力，能在高速飞行中准确锁定猎物的位置。作为武...
# 202  以速度和平衡性见长的魔物，同时也拥有极佳的动态视力，能在高速飞行中准确锁定猎物的位置。作为武...
# 203  美麗之物總是帶毒，而用這句話來形容米杜莎真是再合適不過了。這種外表豔麗的魔物善於利用自己的美...
# 204  在沒有法度的尼芙菲姆，冥界女王支持一切釋放自我的行為，而嗜血怪人正是以鮮血滋養而成的族群。在...
# 205                                                NaN
# 206  居住於卡拉拉森林中的昆蟲魔物，生性溫和，不喜爭鬥。以砂石泥土中蘊含的魔力為食，也會以自身的排...
# 207                                                NaN
# 208  位於阿魯納貝茲教國海域內的無名島，是一處秘密的行刑之地。這裡不僅是流放者的聚集所，也是死刑者...
# 209  與伍坦戰士同出一族，但關係並不和睦。他們是被族群淘汰的「弱者」，因在成年之際未能通過族群的考...
# 210  地獄犬是冥界女王海拉最忠誠的奴僕。然而這份忠誠並非發自內心，而是來自一紙無法廢棄的靈魂契約。...
# 212  從地底世界歸來的亡者，即使身體已經腐爛，也不願意安眠於泥土之中。但也有隱秘的崇拜者認為這是死...
# 213  卡拉拉森林的實際統治者，管理並領導著森林中的其他族群。崇尚力量，即使在族群內部，也不接受體格...
# 214  活潑又吵鬧的魔物，擁有不輸給人類的智慧，在汶巴拉的雨林成為旅遊勝地之前，就和當地的土著雨檀族...
# 215  相當詭異而邪惡的魔物，在吸收大量的靈魂後，就會結出如嬰孩外形的果實。果實會在鬼娃樹的枝頭生長...
# 216  在外形上與變異殭屍十分相似，但對於兩者是否從屬於同一類的魔物，至今學界仍有分歧。究其原因，大...
# 217  有很多人好奇為何亡者國度遍地都是南瓜，但如果你曾遭遇過無顱武士的襲擊，那就不會再有這樣的疑惑...
# 218  在雨檀族的傳說中，靈魂樹是由世界樹的嫩芽栽種而成，而作為靈魂樹的子嗣，苗娃也被視為是繼承了世...
# 219  從可愛的外形來看，是與亡者國度完全不相符的魔物，不過銀月魔女卻是主動以某些代價和冥界女王換取...
# 220  傳說中能夠預言死亡的魔物，會穿著由屍布製成的衣物，在黑夜中散播死亡降臨的訊號，因而被人們視為...
# 221  刺蝟蜻蜓是一種十分溫順的魔物，但絕不能因此就小瞧牠們的破壞力。成年的刺蝟蜻蜓會在破蛹後獲得強...
# 222  擁有與人類高度相似的外表，實際上卻是由樹木化身的魔物。在習性上仍與植物十分相似，會尋找陽光充...
# 223  石砲火樹在製作方式上與機木人十分相似，它們的身體由精密的機械構成，外表卻被偽裝成了植物系的魔...
# 224  比起普通的傘蜥，擁有更加堅韌的外皮及爪牙，以確保牠們能夠挖掘泥土深層的蟲卵為食。不喜陽光，總...
# 225  雖然被劃分為魔物，但機木人實際上卻更像是一座精密的儀器。它們會日復一日完成固定的行程，無人知...

# %% [markdown]
# ### Save data for Monster Drop

# %%
monster_drop_records = monster_df[["id", "en_name", "DropListKV"]].to_dict(orient="records")

# %% [markdown]
# ### Monster Skills

# %%
monster_skills_raw_df = monster_df[["id", "skills"]]

# %% [markdown]
# ### Filter columns and column name correction

# %%
monster_df = monster_df.rename(columns={
    "id": "id",
    "attackSpeedIncrease": "final_aspd",
    "baseExp": "b_exp",
    "criticalLevel": "crit",
    "criticalRate": "final_crit",
    "criticalResistanceLevel": "crit_res",
    "criticalResistanceRate" : "final_crit_res",
    "dodgeLevel": "dodge",
    "dodgeRate": "final_dodge",
    "hitLevel": "hit",
    "hitIncrease": "final_hit",
    "jobExp": "j_exp",
    "magicDefenseLevel": "m_def",
    "finalMagicDefenseIncrease" : "final_m_def",
    "magicDamageIncrease": "final_m_dmg_bonus",
    "magicDamagedIncrease": "final_m_dmg_res",
    "magicDps": "m_dps",
    "magicPenetrationLevel": "m_pen",
    "magicPenetrationIncrease": "final_m_pen",
    "magicRebound": "m_reflect",
    "magicVampire": "m_lifesteal",
    "fixedMagicDamage": "m_dmg_bonus",
    "fixedMagicDamageReduce": "m_dmg_res",
    "maxHp": "max_hp",
    "navSceneId": "location",
    "bodily": "size",
    "physicDefenseLevel": "p_def",
    "physicDps": "p_dps",
    "physicDamageIncrease": "final_p_dmg_bonus",
    "fixedPhysicDamage": "p_dmg_bonus",
    "physicDamagedIncrease" : "final_p_dmg_res",
    "physicPenetrationIncrease": "final_p_pen",
    "finalPhysicDefenseIncrease": "final_p_def",
    "physicPenetrationLevel": "p_pen",
    "fixedPhysicDamageReduce": "p_dmg_res",
    "vampire": "p_lifesteal",
    "rebound": 'p_reflect',
    "property": "property",
    "race": "race",
    "type": "type",
    "level": "level",
    "resId": "res_id",
    "en_desc": "description"
    })

monster_df = monster_df[['id', 'en_name', 'b_exp', 'crit', 'final_crit', 'crit_res', 'final_crit_res', 'dodge', 'final_dodge', 'final_aspd', 'hit', 'final_hit', 'j_exp', 'm_def', 'final_m_def', 'final_m_dmg_bonus', 'final_m_dmg_res', 'm_dps', 'm_pen', 'final_m_pen', 'm_dmg_bonus', 'm_dmg_res', 'max_hp', 'location', 'size', 'p_def', 'final_p_def', 'p_dps', 'final_p_dmg_bonus', 'final_p_dmg_res', 'final_p_pen', 'p_pen', 'p_reflect', 'p_dmg_res', 'p_dmg_bonus', 'property', 'race', 'type', 'level', 'res_id', 'description', "zeny"]]

# %% [markdown]
# ### Data correction

# %%
cols = ['crit', 'crit_res', 'dodge', 'hit', 'j_exp', 'm_def', 'm_dps', 'm_pen', 'max_hp', 'location', 'p_def', 'p_dps', 'p_pen']

for col in cols:
  monster_df[col] = monster_df[col].fillna(0)

monster_df["size"] = monster_df["size"].fillna(1)
monster_df["race"] = monster_df["race"].fillna(32)

cols = ['property', 'type']

for col in cols:
  monster_df[col] = monster_df[col].fillna(0)

monster_df["level"] = monster_df["level"].fillna(1)
monster_df = monster_df.rename(columns={"size": "size_id", "property": "attr_id", "race": "race_id", "type": "type_id", "location": "loc_id"})

# %% [markdown]
# ### Merge with information from `en_langs`

# %% [markdown]
# #### Monster size

# %%
monster_size_df = pd.DataFrame({"size_id": [0, 1, 2, 3], "size": ["Large", "Medium", "Small", "Giant"]})
monster_df["size_id"] = monster_df["size_id"].astype(float)
monster_df = pd.merge(monster_df, monster_size_df, how="left", left_on="size_id", right_on="size_id")

# %% [markdown]
# #### Monster attributes

# %%
monster_attr_df = pd.DataFrame(en_parsed_data["attr"])
monster_attr_df = monster_attr_df.rename(columns={"id": "attr_id", "value": "attr"})
monster_attr_df["attr_id"] = monster_attr_df["attr_id"].astype(float)
monster_df["attr_id"] = monster_df["attr_id"].astype(float)
monster_attr_df["attr_id"] = monster_attr_df["attr_id"] - 1
monster_df = pd.merge(monster_df, monster_attr_df, how="left", left_on="attr_id", right_on="attr_id")

# %% [markdown]
# #### Monster race

# %%
monster_race_df = pd.DataFrame(en_parsed_data["race"])
monster_race_df = monster_race_df.rename(columns={"id": "race_id", "value": "race"})
monster_race_df["race_id"] = monster_race_df["race_id"].astype(float)
monster_df["race_id"] = monster_df["race_id"].astype(float)
monster_df = pd.merge(monster_df, monster_race_df, how="left", left_on="race_id", right_on="race_id")

# %% [markdown]
# #### Monster location

# %%
monster_loc_df = pd.DataFrame(en_parsed_data["scene_name"])
monster_loc_df = monster_loc_df.rename(columns={"id": "loc_id", "value": "loc"})
monster_loc_df["loc_id"] = monster_loc_df["loc_id"].astype(float)
monster_df["loc_id"] = monster_df["loc_id"].astype(float)
monster_df = pd.merge(monster_df, monster_loc_df, how="left", left_on="loc_id", right_on="loc_id")

# %% [markdown]
# ### Data correction (cont)

# %%
monster_df = monster_df.drop(["size_id", "attr_id", "race_id"], axis=1)
cols = ["en_name", "size", "attr", "race"]

for col in cols:
  monster_df[col] = monster_df[col].str.lower()

monster_df["race"] = monster_df["race"].fillna("demi-human")
monster_df = monster_df.drop("type_id", axis=1)
monster_df = monster_df.rename(columns={
    "en_name": "name",
})

# %%
monster_df = monster_df.query("loc != '???'")

# %%
monster_final_df = monster_df.copy()

# %%
monster_final_df
# Out:
#         id                         name   b_exp    crit  final_crit  crit_res  \
# 0    10002                        fabre    17.0     1.0         NaN       1.0
# 1    10003                         pupa    18.0     2.0         NaN       2.0
# 2    10004                      lunatic    19.0     2.0         NaN       2.0
# 3    10005                thief bug egg    28.0     3.0         NaN       3.0
# 4    10006                     chonchon    41.0     3.0         NaN       3.0
# 5    10007                       willow    50.0     2.0         NaN       2.0
# 6    10008                    roda frog    48.0    14.0         NaN      14.0
# 7    10009                    thief bug    23.0     4.0         NaN       4.0
# 8    10010                  grasshopper    78.0     2.0         NaN       2.0
# 9    10011                        picky    21.0     2.0         NaN       2.0
# 10   10012                        drops    33.0     2.0         NaN       2.0
# 11   10013                 pecopeco egg    20.0     2.0         NaN       2.0
# 12   10014                       condor    46.0     2.0         NaN       2.0
# 13   10015                  savage bebe    31.0     4.0         NaN       4.0
# 14   10016             baby desert wolf    33.0     5.0         NaN       5.0
# 15   10017                     pecopeco   275.0    29.0         NaN      29.0
# 16   10018                         muka   221.0    26.0         NaN      26.0
# 17   10019                     metaller   158.0    31.0         NaN     109.0
# 18   10020                    anacondaq    65.0    34.0         NaN      34.0
# 19   10021                     scorpion    67.0    36.0         NaN     126.0
# 20   10022                        golem   259.0    39.0         NaN      39.0
# 21   10023                         hode   146.0    44.0         NaN      44.0
# 22   10024                  desert wolf   113.0    47.0         NaN      47.0
# 23   10025                    frilldora   166.0    61.0         NaN      61.0
# 24   10027                       hornet    37.0     6.0         NaN       6.0
# 25   10028                    ambernite   176.0     8.0         NaN       8.0
# 26   10029                     wormtail   202.0    87.0         NaN      87.0
# 27   10030                    dustiness    35.0    13.0         NaN      13.0
# 28   10031                         horn   128.0    17.0         NaN      17.0
# 29   10033                  side winder   138.0    39.0         NaN      39.0
# 30   10034                ground petite   304.0   150.0         NaN     150.0
# 31   10035                   sky petite   349.0   154.0         NaN     154.0
# 32   10036                 elder willow   339.0   100.0         NaN     100.0
# 33   10037                       eggyra   125.0   114.0         NaN     399.0
# 34   10038                      bigfoot   234.0    90.0         NaN      90.0
# 35   10039                       savage   142.0    31.0         NaN      31.0
# 36   10040                     magnolia    89.0    41.0         NaN      41.0
# 37   10041                       dokebi   149.0   107.0         NaN     107.0
# 38   10042                       horong   128.0   117.0         NaN     117.0
# 39   10043             greatest general   446.0   107.0         NaN     107.0
# 40   10044                     familiar    32.0     4.0         NaN       4.0
# 41   10045                        spore    62.0     9.0         NaN       9.0
# 42   10046                     plankton    45.0     6.0         NaN       6.0
# 43   10047                        tarou    29.0     7.0         NaN       7.0
# 44   10048             female thief bug    68.0     5.0         NaN       5.0
# 45   10049               male thief bug    60.0     8.0         NaN       8.0
# 46   10050                         wolf   268.0    93.0         NaN     327.0
# 47   10051                   mandragora    44.0     3.0         NaN       3.0
# 48   10052                     poporing    70.0     6.0         NaN       6.0
# 49   10053                        snake   104.0    90.0         NaN      90.0
# 50   10054                       creamy    63.0    10.0         NaN      10.0
# 51   10055                      stainer    46.0    13.0         NaN      44.0
# 52   10056               steel chonchon    55.0    11.0         NaN      11.0
# 53   10057                         coco    46.0    13.0         NaN      13.0
# 54   10058                       smokie    71.0    13.0         NaN      47.0
# 55   10059                      caramel    25.0    15.0         NaN      15.0
# 56   10060                         yoyo    78.0    18.0         NaN      18.0
# 57   10061              pirate skeleton   108.0    20.0         NaN      20.0
# 58   10062                    megalodon   504.0   562.0     0.18723    1123.0
# 59   10063                 poison spore    43.0    10.0         NaN      10.0
# 60   10064                      whisper    43.0    24.0         NaN      83.0
# 61   10065                        kukre    50.0    16.0         NaN      16.0
# 62   10066                        hydra    64.0    17.0         NaN      17.0
# 63   10067                    shellfish   166.0   548.0     0.18254    1095.0
# 64   10068                        vadon    59.0    54.0         NaN      54.0
# 65   10069                       marina    61.0    57.0         NaN     200.0
# 66   10071                     cornutus    64.0    64.0         NaN      64.0
# 67   10072                         phen   131.0    68.0         NaN      68.0
# 68   10073                marine sphere    91.0    74.0         NaN     260.0
# 69   10074                    swordfish   140.0    77.0         NaN      77.0
# 70   10075                      obeaune   147.0    83.0         NaN      83.0
# 71   10076                        marse    95.0    80.0         NaN     281.0
# 72   10077                       merman   613.0   668.0     0.22280    1337.0
# 73   10078                         marc   116.0   104.0         NaN     104.0
# 74   10079                      deviace    61.0   111.0         NaN     111.0
# 75   10080                        andre    75.0    47.0         NaN      47.0
# 76   10081                        piere    77.0    51.0         NaN     177.0
# 77   10082                       deniro    83.0    61.0         NaN      61.0
# 78   10083                       vitata    43.0    64.0         NaN      64.0
# 79   10084                    drainliar    34.0    12.0         NaN      12.0
# 80   10085                      giearth    53.0    19.0         NaN      66.0
# 81   10086                     arclouze   123.0    83.0         NaN      83.0
# 82   10087     axe-wielding skel pirate   106.0    19.0         NaN      19.0
# 83   10088                       zombie   125.0    16.0         NaN      16.0
# 84   10089                        munak   226.0   100.0         NaN     351.0
# 85   10090                       bongun   232.0   104.0         NaN     104.0
# 86   10091                        sohee   244.0   111.0         NaN     387.0
# 87   10092                    nine tail   125.0   114.0         NaN     114.0
# 88   10093                       martin    26.0    18.0         NaN      62.0
# 89   10094              skeleton worker   110.0    21.0         NaN      73.0
# 90   10095                         myst   214.0    24.0         NaN      24.0
# 91   10096                   evil druid   927.0   250.0     0.08329     250.0
# 92   10097                     skeleton   220.0    97.0         NaN      97.0
# 93   10098              archer skeleton   122.0    57.0         NaN      57.0
# 94   10099                        matyr   146.0    44.0         NaN      44.0
# 95   10100                        mummy   261.0    68.0         NaN     236.0
# 96   10101                        verit   178.0    71.0         NaN     249.0
# 97   10102                        ghoul   292.0   141.0         NaN     141.0
# 98   10103                         isis   341.0    74.0         NaN      74.0
# 99   10104                     minorous   349.0    77.0         NaN      77.0
# 100  10105                        argos   133.0    26.0         NaN      26.0
# 101  10106                       mantis   122.0    29.0         NaN      29.0
# 102  10107                        flora   195.0    34.0         NaN      34.0
# 103  10108                      argiope   237.0    54.0         NaN      54.0
# 104  10109         mace-wielding goblin   268.0   125.0         NaN     125.0
# 105  10110       hammer-wielding goblin   350.0   133.0         NaN     133.0
# 106  10111        flail-wielding goblin   320.0   117.0         NaN     117.0
# 107  10112          axe-wielding goblin   292.0   141.0         NaN     141.0
# 108  10113       dagger-wielding goblin   304.0   150.0         NaN     150.0
# 109  10114                goblin archer   119.0   161.0         NaN     161.0
# 110  10115            goblin steamrider   170.0   180.0         NaN     180.0
# 111  10116                        zerom   238.0    80.0         NaN      80.0
# 112  10117                      requiem   253.0    87.0         NaN      87.0
# 113  10118                       marduk   200.0    71.0         NaN      71.0
# 114  10119                       pasana   321.0    93.0         NaN      93.0
# 115  10120                   orc zombie   295.0   121.0         NaN     121.0
# 116  10121                  orc warrior   210.0   133.0         NaN     465.0
# 117  10122                 orc skeleton   429.0   137.0         NaN     480.0
# 118  10123                     orc lady   328.0   170.0         NaN     170.0
# 119  10124                       zenorc   334.0   175.0         NaN     175.0
# 120  10125                   hunter fly    69.0    21.0         NaN      21.0
# 121  10126                   orc archer   358.0   194.0         NaN     194.0
# 122  10127                     high orc   649.0   184.0         NaN     184.0
# 123  10128         mace-wielding kobold   335.0   125.0         NaN     125.0
# 124  10129       hammer-wielding kobold   286.0   137.0         NaN     137.0
# 125  10130                kobold archer   161.0   166.0         NaN     580.0
# 126  10131          axe-wielding kobold   340.0   180.0         NaN     180.0
# 127  10132                         jakk   206.0   129.0         NaN     451.0
# 128  10133                   marionette   149.0   145.0         NaN     145.0
# 129  10134                    deviruchi   246.0   170.0         NaN     170.0
# 130  10135                    nightmare   660.0   189.0         NaN     189.0
# 131  10136                        cramp   287.0   219.0     0.07290     765.0
# 132  10137                         punk   150.0   237.0     0.07908     237.0
# 133  10138                      bathory   485.0   225.0     0.07494     225.0
# 134  10139                        alarm   296.0   231.0     0.07700     231.0
# 135  10141                        clock   636.0   263.0     0.08776     921.0
# 136  10142          clock tower manager   645.0   270.0     0.09005     946.0
# 137  10143                    ant larva    71.0    41.0         NaN     145.0
# 138  10144                     penomena   761.0   291.0     0.09687     291.0
# 139  10145             soldier skeleton   193.0    51.0         NaN      51.0
# 140  10147                dead plankton    49.0    15.0         NaN      53.0
# 141  10148  dagger-wielding skel pirate   162.0    20.0         NaN      20.0
# 142  10149                       rocker   144.0    14.0         NaN      14.0
# 143  10150                    sasquatch   201.0    36.0         NaN      36.0
# 144  10151                 baphomet jr.    78.0   154.0         NaN     154.0
# 145  10152                picky (shell)    24.0     2.0         NaN       2.0
# 146  10154                       anubis   495.0    97.0         NaN      97.0
# 147  10155                giant whisper   335.0   145.0         NaN     145.0
# 148  10157             skeleton general   274.0   129.0         NaN     129.0
# 149  10158                     orc baby   131.0   121.0         NaN     121.0
# 150  10159                  rotar zairo   671.0   194.0         NaN     678.0
# 151  10163                   wind ghost   546.0   199.0         NaN     199.0
# 152  10164                       wraith   833.0   205.0         NaN     205.0
# 153  10166                        carat   158.0   161.0         NaN     161.0
# 154  10167                    injustice   478.0   219.0     0.07290     219.0
# 155  10168                      raydric   242.0   166.0         NaN     580.0
# 156  10170               raydric archer   400.0   237.0     0.07908     830.0
# 157  10171                    majoruros   519.0   184.0         NaN     184.0
# 158  10172              zombie prisoner   182.0   199.0         NaN     698.0
# 159  10173                     brilight    94.0   213.0     0.07088     213.0
# 160  10175                        joker   761.0   244.0     0.08118     244.0
# 161  10179                     sageworm   220.0   189.0         NaN     189.0
# 162  10180                   dark frame   206.0   250.0     0.08329     250.0
# 163  10182                        sting   141.0   213.0     0.07088     213.0
# 164  10184                  khalitzburg   470.0   256.0     0.08549     256.0
# 165  10185                    zherlthsh   424.0   263.0     0.08776     263.0
# 166  10187            skeleton prisoner   388.0   225.0     0.07494     225.0
# 167  10190                        rybio   555.0   205.0         NaN     205.0
# 168  10192                     phendark   323.0   270.0     0.09005     270.0
# 169  10193                     wanderer   209.0   256.0     0.08549     256.0
# 170  10194               abysmal knight   739.0   231.0     0.07700     231.0
# 171  10195                bloody knight   376.0   175.0         NaN     175.0
# 172  10196                        aster   345.0   590.0     0.19673    2164.0
# 173  10197                         crab   242.0   647.0     0.21567    2372.0
# 174  10198                    sea otter   448.0   562.0     0.18723    1123.0
# 175  10199                      raggler   164.0   355.0     0.11841     355.0
# 176  10200                      anolian   478.0   632.0     0.21072    1264.0
# 177  10201                    stem worm   341.0   576.0     0.19196    1152.0
# 178  10202                   thara frog   221.0   548.0     0.18254    1095.0
# 179  10203                     galapago   354.0   617.0     0.20582    2264.0
# 180  10204                         pest   295.0   617.0     0.20582    1235.0
# 181  10205                    tri joint   327.0   533.0     0.17762    1066.0
# 182  10206                        rogue   478.0   632.0     0.21072    1264.0
# 183  10207                       nereid   170.0   576.0     0.19196    2112.0
# 184  10208                    alligator  1049.0   603.0     0.20095    1206.0
# 185  10209                     megalith   690.0   590.0     0.19673    1180.0
# 186  10210                         seal   350.0   603.0     0.20095    1206.0
# 187  10211              stalactic golem   368.0   668.0     0.22280    1337.0
# 188  10212                     gargoyle   484.0   647.0     0.21567    2372.0
# 189  10213                         lude   484.0   647.0     0.21567    2372.0
# 190  10214                       medusa   260.0   898.0     0.29920    1346.0
# 191  10215              bloody murderer   825.0  1005.0     0.33510    1005.0
# 192  10216                         quve   484.0   647.0     0.21567    2372.0
# 193  10217                  beetle king   248.0   821.0     0.27350    1231.0
# 194  10218                   heirozoist   484.0   647.0     0.21567    2372.0
# 195  10219                  flame skull   408.0   977.0     0.32570    1466.0
# 196  10220               wootan shooter   538.0   957.0     0.31910    1436.0
# 197  10221                    hellhound   251.0   839.0     0.27980    1259.0
# 198  10223                ragged zombie   635.0   858.0     0.28600    1287.0
# 199  10224               wootan fighter  1157.0   878.0     0.29280    1318.0
# 200  10225                        choco   310.0   821.0     0.27350    1231.0
# 201  10226                       gibbet   395.0   917.0     0.30560    1375.0
# 202  10227             zombie slaughter   550.0  1005.0     0.33510    1005.0
# 203  10228                     dullahan   508.0   858.0     0.28600     858.0
# 204  10229                     parasite   532.0   936.0     0.31210    1404.0
# 205  10230                    loli ruri   816.0   977.0     0.32570    1466.0
# 206  10231                      banshee   658.0   917.0     0.30560    1375.0
# 207  10232                  dragon tail   386.0   878.0     0.29280    1318.0
# 208  10233                        dryad   650.0   898.0     0.29920    1346.0
# 209  10234                stone shooter   599.0   936.0     0.31210    1404.0
# 210  10235                      driller   404.0   957.0     0.31910    1436.0
# 211  10236                 wooden golem   377.0   839.0     0.27980    1259.0
#
#      final_crit_res   dodge  final_dodge  final_aspd    hit  final_hit  \
# 0               NaN     1.0          NaN         NaN    1.0        NaN
# 1               NaN     2.0          NaN         NaN    2.0        NaN
# 2               NaN     2.0          NaN         NaN    2.0        NaN
# 3               NaN     3.0          NaN         NaN    3.0        NaN
# 4               NaN     3.0          NaN         NaN    3.0        NaN
# 5               NaN     2.0          NaN         NaN    2.0        NaN
# 6               NaN    14.0          NaN         NaN   14.0        NaN
# 7               NaN     4.0          NaN         NaN    4.0        NaN
# 8               NaN     2.0          NaN         NaN    2.0        NaN
# 9               NaN     2.0          NaN         NaN    2.0        NaN
# 10              NaN     2.0          NaN         NaN    2.0        NaN
# 11              NaN     2.0          NaN         NaN    2.0        NaN
# 12              NaN     2.0          NaN         NaN    2.0        NaN
# 13              NaN     4.0          NaN         NaN    4.0        NaN
# 14              NaN     5.0          NaN         NaN    5.0        NaN
# 15              NaN    29.0          NaN         NaN   29.0        NaN
# 16              NaN    26.0          NaN         NaN   26.0        NaN
# 17              NaN   109.0          NaN         NaN   31.0        NaN
# 18              NaN    34.0          NaN         NaN   34.0        NaN
# 19              NaN   126.0          NaN         NaN   36.0        NaN
# 20              NaN    39.0          NaN         NaN   39.0        NaN
# 21              NaN    44.0          NaN         NaN   44.0        NaN
# 22              NaN    47.0          NaN         NaN   47.0        NaN
# 23              NaN    61.0          NaN         NaN   61.0        NaN
# 24              NaN     6.0          NaN         NaN    6.0        NaN
# 25              NaN     8.0          NaN         NaN    8.0        NaN
# 26              NaN    87.0          NaN         NaN   87.0        NaN
# 27              NaN    13.0          NaN         NaN   13.0        NaN
# 28              NaN    17.0          NaN         NaN   17.0        NaN
# 29              NaN    39.0          NaN         NaN   39.0        NaN
# 30              NaN   150.0          NaN         NaN  150.0        NaN
# 31              NaN   154.0          NaN         NaN  154.0        NaN
# 32              NaN   100.0          NaN         NaN  100.0        NaN
# 33              NaN   399.0          NaN         NaN  114.0        NaN
# 34              NaN    90.0          NaN         NaN   90.0        NaN
# 35              NaN    31.0          NaN         NaN   31.0        NaN
# 36              NaN    41.0          NaN         NaN   41.0        NaN
# 37              NaN   107.0          NaN         NaN  107.0        NaN
# 38              NaN   117.0          NaN         NaN  117.0        NaN
# 39              NaN   107.0          NaN         NaN  107.0        NaN
# 40              NaN     4.0          NaN         NaN    4.0        NaN
# 41              NaN     9.0          NaN         NaN    9.0        NaN
# 42              NaN     6.0          NaN         NaN    6.0        NaN
# 43              NaN     7.0          NaN         NaN    7.0        NaN
# 44              NaN     5.0          NaN         NaN    5.0        NaN
# 45              NaN     8.0          NaN         NaN    8.0        NaN
# 46              NaN   327.0          NaN         NaN   93.0        NaN
# 47              NaN     3.0          NaN         NaN    3.0        NaN
# 48              NaN     6.0          NaN         NaN    6.0        NaN
# 49              NaN    90.0          NaN         NaN   90.0        NaN
# 50              NaN    10.0          NaN         NaN   10.0        NaN
# 51              NaN    44.0          NaN         NaN   13.0        NaN
# 52              NaN    11.0          NaN         NaN   11.0        NaN
# 53              NaN    13.0          NaN         NaN   13.0        NaN
# 54              NaN    47.0          NaN         NaN   13.0        NaN
# 55              NaN    15.0          NaN         NaN   15.0        NaN
# 56              NaN    18.0          NaN         NaN   18.0        NaN
# 57              NaN    20.0          NaN         NaN   20.0        NaN
# 58          0.39941   749.0      0.24963         NaN  562.0    0.18723
# 59              NaN    10.0          NaN         NaN   10.0        NaN
# 60              NaN    83.0          NaN         NaN   24.0        NaN
# 61              NaN    16.0          NaN         NaN   16.0        NaN
# 62              NaN    17.0          NaN         NaN   17.0        NaN
# 63          0.38941   730.0      0.24338         NaN  548.0    0.18254
# 64              NaN    54.0          NaN         NaN   54.0        NaN
# 65              NaN   200.0          NaN         NaN   57.0        NaN
# 66              NaN    64.0          NaN         NaN   64.0        NaN
# 67              NaN    68.0          NaN         NaN   68.0        NaN
# 68              NaN   260.0          NaN         NaN   74.0        NaN
# 69              NaN    77.0          NaN         NaN   77.0        NaN
# 70              NaN    83.0          NaN         NaN   83.0        NaN
# 71              NaN   281.0          NaN         NaN   80.0        NaN
# 72          0.47531   891.0      0.29707         NaN  668.0    0.22280
# 73              NaN   104.0          NaN         NaN  104.0        NaN
# 74              NaN   111.0          NaN         NaN  111.0        NaN
# 75              NaN    47.0          NaN         NaN   47.0        NaN
# 76              NaN   177.0          NaN         NaN   51.0        NaN
# 77              NaN    61.0          NaN         NaN   61.0        NaN
# 78              NaN    64.0          NaN         NaN   64.0        NaN
# 79              NaN    12.0          NaN         NaN   12.0        NaN
# 80              NaN    66.0          NaN         NaN   19.0        NaN
# 81              NaN    83.0          NaN         NaN   83.0        NaN
# 82              NaN    19.0          NaN         NaN   19.0        NaN
# 83              NaN    16.0          NaN         NaN   16.0        NaN
# 84              NaN   351.0          NaN         NaN  100.0        NaN
# 85              NaN   104.0          NaN         NaN  104.0        NaN
# 86              NaN   387.0          NaN         NaN  111.0        NaN
# 87              NaN   114.0          NaN         NaN  114.0        NaN
# 88              NaN    62.0          NaN         NaN   18.0        NaN
# 89              NaN    73.0          NaN         NaN   21.0        NaN
# 90              NaN    24.0          NaN         NaN   24.0        NaN
# 91          0.16658   250.0      0.16658         NaN  250.0    0.08329
# 92              NaN    97.0          NaN         NaN   97.0        NaN
# 93              NaN    57.0          NaN         NaN   57.0        NaN
# 94              NaN    44.0          NaN         NaN   44.0        NaN
# 95              NaN   236.0          NaN         NaN   68.0        NaN
# 96              NaN   249.0          NaN         NaN   71.0        NaN
# 97              NaN   141.0          NaN         NaN  141.0        NaN
# 98              NaN    74.0          NaN         NaN   74.0        NaN
# 99              NaN    77.0          NaN         NaN   77.0        NaN
# 100             NaN    26.0          NaN         NaN   26.0        NaN
# 101             NaN    29.0          NaN         NaN   29.0        NaN
# 102             NaN    34.0          NaN         NaN   34.0        NaN
# 103             NaN    54.0          NaN         NaN   54.0        NaN
# 104             NaN   125.0          NaN         NaN  125.0        NaN
# 105             NaN   133.0          NaN         NaN  133.0        NaN
# 106             NaN   117.0          NaN         NaN  117.0        NaN
# 107             NaN   141.0          NaN         NaN  141.0        NaN
# 108             NaN   150.0          NaN         NaN  150.0        NaN
# 109             NaN   161.0          NaN         NaN  161.0        NaN
# 110             NaN   180.0          NaN         NaN  180.0        NaN
# 111             NaN    80.0          NaN         NaN   80.0        NaN
# 112             NaN    87.0          NaN         NaN   87.0        NaN
# 113             NaN    71.0          NaN         NaN   71.0        NaN
# 114             NaN    93.0          NaN         NaN   93.0        NaN
# 115             NaN   121.0          NaN         NaN  121.0        NaN
# 116             NaN   465.0          NaN         NaN  133.0        NaN
# 117             NaN   480.0          NaN         NaN  137.0        NaN
# 118             NaN   170.0          NaN         NaN  170.0        NaN
# 119             NaN   175.0          NaN         NaN  175.0        NaN
# 120             NaN    21.0          NaN         NaN   21.0        NaN
# 121             NaN   194.0          NaN         NaN  194.0        NaN
# 122             NaN   184.0          NaN         NaN  184.0        NaN
# 123             NaN   125.0          NaN         NaN  125.0        NaN
# 124             NaN   137.0          NaN         NaN  137.0        NaN
# 125             NaN   580.0          NaN         NaN  166.0        NaN
# 126             NaN   180.0          NaN         NaN  180.0        NaN
# 127             NaN   451.0          NaN         NaN  129.0        NaN
# 128             NaN   145.0          NaN         NaN  145.0        NaN
# 129             NaN   170.0          NaN         NaN  170.0        NaN
# 130             NaN   189.0          NaN         NaN  189.0        NaN
# 131         0.14581   765.0      0.14581         NaN  219.0    0.07290
# 132         0.15816   237.0      0.15816         NaN  237.0    0.07908
# 133         0.14989   225.0      0.14989         NaN  225.0    0.07494
# 134         0.15400   231.0      0.15400         NaN  231.0    0.07700
# 135         0.17552   921.0      0.17552         NaN  263.0    0.08776
# 136         0.18010   946.0      0.18010         NaN  270.0    0.09005
# 137             NaN   145.0          NaN         NaN   41.0        NaN
# 138         0.19375   291.0      0.19375         NaN  291.0    0.09687
# 139             NaN    51.0          NaN         NaN   51.0        NaN
# 140             NaN    53.0          NaN         NaN   15.0        NaN
# 141             NaN    20.0          NaN         NaN   20.0        NaN
# 142             NaN    14.0          NaN         NaN   14.0        NaN
# 143             NaN    36.0          NaN         NaN   36.0        NaN
# 144             NaN   154.0          NaN         NaN  154.0        NaN
# 145             NaN     2.0          NaN         NaN    2.0        NaN
# 146             NaN    97.0          NaN         NaN   97.0        NaN
# 147             NaN   145.0          NaN         NaN  145.0        NaN
# 148             NaN   129.0          NaN         NaN  129.0        NaN
# 149             NaN   121.0          NaN         NaN  121.0        NaN
# 150             NaN   678.0          NaN         NaN  194.0        NaN
# 151             NaN   199.0          NaN         NaN  199.0        NaN
# 152             NaN   205.0          NaN         NaN  205.0        NaN
# 153             NaN   161.0          NaN         NaN  161.0        NaN
# 154         0.14581   219.0      0.14581         NaN  219.0    0.07290
# 155             NaN   580.0          NaN         NaN  166.0        NaN
# 156         0.15816   830.0      0.15816         NaN  237.0    0.07908
# 157             NaN   184.0          NaN         NaN  184.0        NaN
# 158             NaN   698.0          NaN         NaN  199.0        NaN
# 159         0.14177   213.0      0.14177         NaN  213.0    0.07088
# 160         0.16235   244.0      0.16235         NaN  244.0    0.08118
# 161             NaN   189.0          NaN         NaN  189.0        NaN
# 162         0.16658   250.0      0.16658         NaN  250.0    0.08329
# 163         0.14177   213.0      0.14177         NaN  213.0    0.07088
# 164         0.17097   256.0      0.17097         NaN  256.0    0.08549
# 165         0.17552   263.0      0.17552         NaN  263.0    0.08776
# 166         0.14989   225.0      0.14989         NaN  225.0    0.07494
# 167             NaN   205.0          NaN         NaN  205.0        NaN
# 168         0.18010   270.0      0.18010         NaN  270.0    0.09005
# 169         0.17097   256.0      0.17097         NaN  256.0    0.08549
# 170         0.15400   231.0      0.15400         NaN  231.0    0.07700
# 171             NaN   175.0          NaN         NaN  175.0        NaN
# 172         0.41969  1771.0      0.26230         NaN  590.0    0.19673
# 173         0.46010  1941.0      0.28756         NaN  647.0    0.21567
# 174         0.39941   749.0      0.24963         NaN  562.0    0.18723
# 175         0.23682   355.0      0.23682         NaN  355.0    0.11841
# 176         0.44954   843.0      0.28096         NaN  632.0    0.21072
# 177         0.40951   768.0      0.25594         NaN  576.0    0.19196
# 178         0.38941   730.0      0.24338         NaN  548.0    0.18254
# 179         0.43908  1852.0      0.27442         NaN  617.0    0.20582
# 180         0.43908   823.0      0.27442         NaN  617.0    0.20582
# 181         0.37892   710.0      0.23682         NaN  533.0    0.17762
# 182         0.44954   843.0      0.28096         NaN  632.0    0.21072
# 183         0.40951  1728.0      0.25594         NaN  576.0    0.19196
# 184         0.42870   804.0      0.26794         NaN  603.0    0.20095
# 185         0.41969   787.0      0.26230         NaN  590.0    0.19673
# 186         0.42870   804.0      0.26794         NaN  603.0    0.20095
# 187         0.47531   891.0      0.29707         NaN  668.0    0.22280
# 188         0.46010  1941.0      0.28756         NaN  647.0    0.21567
# 189         0.46010  1941.0      0.28756         NaN  647.0    0.21567
# 190         0.47870   449.0      0.23930         NaN  583.0    0.29920
# 191         0.33510  2011.0      0.33510         NaN  653.0    0.33510
# 192         0.46010  1941.0      0.28756         NaN  647.0    0.21567
# 193         0.43770   410.0      0.21880         NaN  533.0    0.27350
# 194         0.46010  1941.0      0.28756         NaN  647.0    0.21567
# 195         0.52110   489.0      0.26050         NaN  635.0    0.32570
# 196         0.51050   479.0      0.25530         NaN  622.0    0.31910
# 197         0.44760   420.0      0.22380         NaN  546.0    0.27980
# 198         0.45770   429.0      0.22880         NaN  558.0    0.28600
# 199         0.46850   439.0      0.23420         NaN  571.0    0.29280
# 200         0.43770   410.0      0.21880         NaN  533.0    0.27350
# 201         0.48900   458.0      0.24450         NaN  596.0    0.30560
# 202         0.33510  2011.0      0.33510         NaN  653.0    0.33510
# 203         0.28600  1716.0      0.28600         NaN  558.0    0.28600
# 204         0.49940   468.0      0.24970         NaN  609.0    0.31210
# 205         0.52110   489.0      0.26050         NaN  635.0    0.32570
# 206         0.48900   458.0      0.24450         NaN  596.0    0.30560
# 207         0.46850   439.0      0.23420         NaN  571.0    0.29280
# 208         0.47870   449.0      0.23930         NaN  583.0    0.29920
# 209         0.49940   468.0      0.24970         NaN  609.0    0.31210
# 210         0.51050   479.0      0.25530         NaN  622.0    0.31910
# 211         0.44760   420.0      0.22380         NaN  546.0    0.27980
#
#       j_exp   m_def  final_m_def  final_m_dmg_bonus  final_m_dmg_res  \
# 0      17.0     7.0          NaN                NaN              NaN
# 1      18.0     8.0          NaN                NaN              NaN
# 2      19.0     6.0          NaN                NaN              NaN
# 3      28.0    18.0          NaN                NaN              NaN
# 4      14.0    13.0          NaN                NaN              NaN
# 5      50.0    10.0          NaN                NaN              NaN
# 6     144.0    86.0          NaN                NaN              NaN
# 7      38.0    19.0          NaN                NaN              NaN
# 8      26.0     9.0          NaN                NaN              NaN
# 9      21.0     7.0          NaN                NaN              NaN
# 10     55.0     7.0          NaN                NaN              NaN
# 11     20.0     8.0          NaN                NaN              NaN
# 12     46.0     7.0          NaN                NaN              NaN
# 13     31.0    16.0          NaN                NaN              NaN
# 14     33.0    19.0          NaN                NaN              NaN
# 15     92.0   115.0          NaN                NaN              NaN
# 16    133.0   157.0          NaN                NaN              NaN
# 17     95.0    78.0          NaN                NaN              NaN
# 18    195.0   168.0          NaN                NaN              NaN
# 19     67.0    90.0          NaN                NaN              NaN
# 20    155.0   193.0          NaN                NaN              NaN
# 21    146.0   222.0          NaN                NaN              NaN
# 22    188.0   189.0          NaN                NaN              NaN
# 23    166.0   242.0          NaN                NaN              NaN
# 24     37.0    25.0          NaN                NaN              NaN
# 25     59.0    46.0          NaN                NaN              NaN
# 26    202.0   347.0          NaN                NaN              NaN
# 27     59.0    67.0          NaN                NaN              NaN
# 28     77.0    84.0          NaN                NaN              NaN
# 29    138.0   193.0          NaN                NaN              NaN
# 30    304.0   748.0          NaN                NaN              NaN
# 31    581.0   615.0          NaN                NaN              NaN
# 32    339.0   502.0          NaN                NaN              NaN
# 33    375.0   285.0          NaN                NaN              NaN
# 34    390.0   540.0          NaN                NaN              NaN
# 35    236.0   186.0          NaN                NaN              NaN
# 36     53.0   166.0          NaN                NaN              NaN
# 37     89.0   429.0          NaN                NaN              NaN
# 38    128.0   585.0          NaN                NaN              NaN
# 39    268.0   429.0          NaN                NaN              NaN
# 40     32.0    18.0          NaN                NaN              NaN
# 41    103.0    36.0          NaN                NaN              NaN
# 42     27.0    36.0          NaN                NaN              NaN
# 43     48.0    35.0          NaN                NaN              NaN
# 44     68.0    26.0          NaN                NaN              NaN
# 45    100.0    50.0          NaN                NaN              NaN
# 46    161.0   234.0          NaN                NaN              NaN
# 47     73.0    14.0          NaN                NaN              NaN
# 48     70.0    22.0          NaN                NaN              NaN
# 49    312.0   450.0          NaN                NaN              NaN
# 50     21.0    49.0          NaN                NaN              NaN
# 51     46.0    32.0          NaN                NaN              NaN
# 52     33.0    67.0          NaN                NaN              NaN
# 53     46.0    76.0          NaN                NaN              NaN
# 54     24.0    34.0          NaN                NaN              NaN
# 55     74.0    75.0          NaN                NaN              NaN
# 56     26.0    71.0          NaN                NaN              NaN
# 57    108.0    79.0          NaN                NaN              NaN
# 58    840.0  2696.0      0.39941            0.31204         -0.57416
# 59    129.0    63.0          NaN                NaN              NaN
# 60     71.0    60.0          NaN                NaN              NaN
# 61     50.0    80.0          NaN                NaN              NaN
# 62     38.0    67.0          NaN                NaN              NaN
# 63    276.0  2629.0      0.38941            0.18254         -0.55978
# 64     99.0   323.0          NaN                NaN              NaN
# 65    101.0   143.0          NaN                NaN              NaN
# 66    106.0   384.0          NaN                NaN              NaN
# 67    218.0   270.0          NaN                NaN              NaN
# 68     91.0   185.0          NaN                NaN              NaN
# 69    419.0   464.0          NaN                NaN              NaN
# 70    245.0   417.0          NaN                NaN              NaN
# 71     95.0   201.0          NaN                NaN              NaN
# 72    368.0  2763.0      0.47531            0.22280         -0.68326
# 73    116.0   519.0          NaN                NaN              NaN
# 74    183.0   664.0          NaN                NaN              NaN
# 75     75.0   237.0          NaN                NaN              NaN
# 76     77.0   126.0          NaN                NaN              NaN
# 77     83.0   303.0          NaN                NaN              NaN
# 78    128.0   256.0          NaN                NaN              NaN
# 79     56.0    48.0          NaN                NaN              NaN
# 80     53.0    47.0          NaN                NaN              NaN
# 81     74.0   500.0          NaN                NaN              NaN
# 82    106.0   113.0          NaN                NaN              NaN
# 83     75.0    64.0          NaN                NaN              NaN
# 84    226.0   251.0          NaN                NaN              NaN
# 85    232.0   519.0          NaN                NaN              NaN
# 86    244.0   277.0          NaN                NaN              NaN
# 87    125.0   571.0          NaN                NaN              NaN
# 88     78.0    44.0          NaN                NaN              NaN
# 89    110.0    52.0          NaN                NaN              NaN
# 90    128.0   143.0          NaN                NaN              NaN
# 91    309.0  1499.0      0.16658            0.08329         -0.16658
# 92    220.0   388.0          NaN                NaN              NaN
# 93    203.0   343.0          NaN                NaN              NaN
# 94    146.0   266.0          NaN                NaN              NaN
# 95     87.0   169.0          NaN                NaN              NaN
# 96    178.0   178.0          NaN                NaN              NaN
# 97    292.0   706.0          NaN                NaN              NaN
# 98    205.0   371.0          NaN                NaN              NaN
# 99    209.0   386.0          NaN                NaN              NaN
# 100   221.0   105.0          NaN                NaN              NaN
# 101   122.0   143.0          NaN                NaN              NaN
# 102   195.0   134.0          NaN                NaN              NaN
# 103   237.0   269.0          NaN                NaN              NaN
# 104   268.0   499.0          NaN                NaN              NaN
# 105   210.0   798.0          NaN                NaN              NaN
# 106   192.0   468.0          NaN                NaN              NaN
# 107   292.0   706.0          NaN                NaN              NaN
# 108   304.0   598.0          NaN                NaN              NaN
# 109   198.0   966.0          NaN                NaN              NaN
# 110   510.0   719.0          NaN                NaN              NaN
# 111   143.0   321.0          NaN                NaN              NaN
# 112   152.0   347.0          NaN                NaN              NaN
# 113   334.0   427.0          NaN                NaN              NaN
# 114   321.0   561.0          NaN                NaN              NaN
# 115   491.0   604.0          NaN                NaN              NaN
# 116   630.0   332.0          NaN                NaN              NaN
# 117   429.0   343.0          NaN                NaN              NaN
# 118   328.0  1022.0          NaN                NaN              NaN
# 119   334.0   875.0          NaN                NaN              NaN
# 120    41.0   124.0          NaN                NaN              NaN
# 121   358.0   775.0          NaN                NaN              NaN
# 122   389.0   737.0          NaN                NaN              NaN
# 123   201.0   624.0          NaN                NaN              NaN
# 124   286.0   685.0          NaN                NaN              NaN
# 125   161.0   414.0          NaN                NaN              NaN
# 126   340.0  1078.0          NaN                NaN              NaN
# 127    69.0   322.0          NaN                NaN              NaN
# 128   149.0   582.0          NaN                NaN              NaN
# 129    82.0  1022.0          NaN                NaN              NaN
# 130   396.0   756.0          NaN                NaN              NaN
# 131    96.0   547.0      0.14581            0.07290         -0.14581
# 132   250.0  1423.0      0.15816            0.07908         -0.15816
# 133   291.0  1349.0      0.14989            0.14989         -0.14989
# 134   493.0   924.0      0.15400            0.15400         -0.15400
# 135   212.0   658.0      0.17552            0.17552         -0.17552
# 136   645.0   675.0      0.18010            0.18010         -0.18010
# 137    71.0   104.0          NaN                NaN              NaN
# 138   457.0  1744.0      0.19375            0.19375         -0.19375
# 139   116.0   253.0          NaN                NaN              NaN
# 140    49.0    38.0          NaN                NaN              NaN
# 141    54.0    99.0          NaN                NaN              NaN
# 142    48.0    86.0          NaN                NaN              NaN
# 143   201.0   217.0          NaN                NaN              NaN
# 144   233.0   769.0          NaN                NaN              NaN
# 145    24.0    10.0          NaN                NaN              NaN
# 146   165.0   581.0          NaN                NaN              NaN
# 147   559.0   873.0          NaN                NaN              NaN
# 148   274.0   773.0          NaN                NaN              NaN
# 149   131.0   483.0          NaN                NaN              NaN
# 150   403.0   485.0          NaN                NaN              NaN
# 151   182.0  1196.0          NaN                NaN              NaN
# 152   278.0   819.0          NaN                NaN              NaN
# 153   158.0   805.0          NaN                NaN              NaN
# 154   287.0  1312.0      0.14581            0.14581         -0.14581
# 155   403.0   414.0          NaN                NaN              NaN
# 156   400.0   593.0      0.15816            0.15816         -0.15816
# 157   519.0  1106.0          NaN                NaN              NaN
# 158   546.0   498.0          NaN                NaN              NaN
# 159   282.0  1063.0      0.14177            0.07088         -0.14177
# 160   457.0   974.0      0.16235            0.16235         -0.16235
# 161   132.0  1134.0          NaN                NaN              NaN
# 162   206.0  1499.0      0.16658            0.16658         -0.16658
# 163   235.0  1276.0      0.14177            0.14177         -0.14177
# 164   784.0  1026.0      0.17097            0.08549         -0.17097
# 165   424.0  1053.0      0.17552            0.08776         -0.17552
# 166   388.0  1124.0      0.14989            0.07494         -0.14989
# 167   555.0  1024.0          NaN                NaN              NaN
# 168   968.0  1351.0      0.18010            0.09005         -0.18010
# 169   627.0  1026.0      0.17097            0.08549         -0.17097
# 170   443.0  1155.0      0.15400            0.15400         -0.15400
# 171   626.0   875.0          NaN                NaN              NaN
# 172   115.0  1456.0      0.41969            0.32788         -0.60330
# 173   242.0  1596.0      0.46010            0.35945         -0.66139
# 174   448.0  1947.0      0.39941            0.18723         -0.57416
# 175   273.0  2131.0      0.23682            0.11841         -0.23682
# 176   478.0  2192.0      0.44954            0.35121         -0.64622
# 177   568.0  1996.0      0.40951            0.19196         -0.58866
# 178   663.0  2629.0      0.38941            0.30423         -0.55978
# 179   590.0  1523.0      0.43908            0.34303         -0.63117
# 180   177.0  2140.0      0.43908            0.20582         -0.63117
# 181   109.0  1847.0      0.37892            0.29603         -0.54470
# 182   478.0  2192.0      0.44954            0.35121         -0.64622
# 183   284.0  1420.0      0.40951            0.31993         -0.58866
# 184   350.0  2090.0      0.42870            0.33492         -0.61626
# 185   690.0  2046.0      0.41969            0.19673         -0.60330
# 186   583.0  2090.0      0.42870            0.20095         -0.61626
# 187  1103.0  2317.0      0.47531            0.37134         -0.68326
# 188   484.0  1596.0      0.46010            0.35945         -0.66139
# 189   484.0  1596.0      0.46010            0.35945         -0.66139
# 190   260.0  2693.0      0.44880            0.15000         -0.68810
# 191   825.0  2011.0      0.33510            0.33500         -0.77080
# 192   484.0  1596.0      0.46010            0.35945         -0.66139
# 193   248.0  1641.0      0.27350            0.27400         -0.62920
# 194   484.0  1596.0      0.46010            0.35945         -0.66139
# 195   136.0  3908.0      0.65140            0.16300         -0.74910
# 196   538.0  1915.0      0.31910            0.31900         -0.73390
# 197   251.0  2518.0      0.41970            0.14000         -0.64350
# 198   381.0  1716.0      0.28600            0.28600         -0.65790
# 199   386.0  1757.0      0.29280            0.29300         -0.67340
# 200   186.0  2462.0      0.41030            0.27400         -0.62920
# 201  1184.0  1834.0      0.30560            0.15300         -0.70290
# 202   550.0  2011.0      0.33510            0.33500         -0.77080
# 203   508.0  1716.0      0.28600            0.28600         -0.65790
# 204   532.0  2809.0      0.46810            0.15600         -0.71780
# 205   816.0  1954.0      0.32570            0.16300         -0.74910
# 206   395.0  2751.0      0.45840            0.15300         -0.70290
# ...
# 167   90.0  10190.0   With one hand wielding a hook and the other w...  157.0
# 168  100.0  10192.0   Phendarks with absolute power are the last ba...  180.0
# 169   98.0  10193.0   Battle is their entire reason for being. In t...  117.0
# 170   94.0  10194.0   Once the world-renowned White Knights of Glas...  166.0
# 171   84.0  10195.0   If it is not for the bloody stench of their b...  144.0
# 172  105.0  10196.0  潜伏在浅海处的珊瑚礁中，借由珊瑚鲜艳的外表来隐藏自己，伺机捕猎路过的鱼类。身上有着形似瞳孔的...   63.0
# 173  109.0  10197.0  当钝拙的双钳不再适应海底暗流涌动的生活，就连螃蟹也会想要安享晚年。而平静悠然的克魔岛显然是个...   67.0
# 174  103.0  10198.0  本应是栖息在海洋中的魔物，近年来却渐渐迁移到了干燥的沙漠地带居住。为了适应陆地上的生活而藏起...  124.0
# 175  101.0  10199.0  由于双翼较为短小而无法飞翔，天生跛足则被认为是一种遗传性的基因疾病。据说毕生都在寻找重新回到...   60.0
# 176  108.0  10200.0  具有社会性的魔物，族群内等级森明、分工明确，具有较强的学习能力，可以使用工具。喜欢在潮湿的水...  132.0
# 177  104.0  10201.0  背脊上高耸的枝干是为了吸收阳光存在，可以在向阳的地方一动不动待上一整天。而令人惊奇的是，灰森...  126.0
# 178  102.0  10202.0  与喜欢将身体全部浸泡在海水中的罗达娃不同，达拉蛙更热衷于将身体暴露在空气中，借由体表所分泌的...  123.0
# 179  107.0  10203.0  会将巢穴筑造在沙地中的神奇企鹅，在习性上比起鸟类，似乎与土拨鼠更为相似。虽然体型圆润，动作却...  131.0
# 180  107.0  10204.0  虽然名为单眼虫，但看起来很像瞳孔的器官其实是口器，真正的眼睛则因为长时间生活在地底而完全失去...   65.0
# 181  101.0  10205.0  拥有坚硬背壳的虫类魔物，多足无翅，上颚突出如角，可以用来捕食猎物或威吓敌人。个体寿命极短，但...   60.0
# 182  108.0  10206.0  盘踞在美妙铃音乐队驻地外围的不良团伙，主要工作是打家劫舍，对象有且只有驻地内的舞娘与吟游诗人...  132.0
# 183  104.0  10207.0  身体细长、光滑无阻，四肢短小但肌肉发达，移动起来十分迅速。拥有一对隐藏在口腔皮下的毒腺，会在...   63.0
# 184  106.0  10208.0  群居在基乃依沼泽的东北部，以湖泊河流为据点的魔物，善于通过水流来隐藏自己并狩猎食物。虽然外表...  194.0
# 185  105.0  10209.0  十分古老而又神秘的魔物，一生中大部分时间都在休眠，仅靠着克魔岛洞穴中充盈的魔力维持生存，基本...  191.0
# 186  106.0  10210.0  记性很差的魔物，总是抱着脑袋回忆重要的事情，一旦想不起来就会陷入暴躁状态，引发剧烈的头痛症状...  129.0
# 187  110.0  10211.0  被誉为魔物中最坚固的壁垒，几乎无法从物理层面对其造成伤害。但与此相对，移动力和敏捷性则大大降...  204.0
# 188  109.0  10212.0  以速度和平衡性见长的魔物，同时也拥有极佳的动态视力，能在高速飞行中准确锁定猎物的位置。作为武...  134.0
# 189  111.0  10213.0  以速度和平衡性见长的魔物，同时也拥有极佳的动态视力，能在高速飞行中准确锁定猎物的位置。作为武...  134.0
# 190  115.0  10214.0  美麗之物總是帶毒，而用這句話來形容米杜莎真是再合適不過了。這種外表豔麗的魔物善於利用自己的美...   72.0
# 191  120.0  10215.0  在沒有法度的尼芙菲姆，冥界女王支持一切釋放自我的行為，而嗜血怪人正是以鮮血滋養而成的族群。在...  230.0
# 192  111.0  10216.0                                                NaN  134.0
# 193  111.0  10217.0  居住於卡拉拉森林中的昆蟲魔物，生性溫和，不喜爭鬥。以砂石泥土中蘊含的魔力為食，也會以自身的排...   69.0
# 194  111.0  10218.0                                                NaN  134.0
# 195  119.0  10219.0  位於阿魯納貝茲教國海域內的無名島，是一處秘密的行刑之地。這裡不僅是流放者的聚集所，也是死刑者...   76.0
# 196  118.0  10220.0  與伍坦戰士同出一族，但關係並不和睦。他們是被族群淘汰的「弱者」，因在成年之際未能通過族群的考...  150.0
# 197  112.0  10221.0  地獄犬是冥界女王海拉最忠誠的奴僕。然而這份忠誠並非發自內心，而是來自一紙無法廢棄的靈魂契約。...   70.0
# 198  113.0  10223.0  從地底世界歸來的亡者，即使身體已經腐爛，也不願意安眠於泥土之中。但也有隱秘的崇拜者認為這是死...  141.0
# 199  114.0  10224.0  卡拉拉森林的實際統治者，管理並領導著森林中的其他族群。崇尚力量，即使在族群內部，也不接受體格...  214.0
# 200  111.0  10225.0  活潑又吵鬧的魔物，擁有不輸給人類的智慧，在汶巴拉的雨林成為旅遊勝地之前，就和當地的土著雨檀族...   69.0
# 201  116.0  10226.0  相當詭異而邪惡的魔物，在吸收大量的靈魂後，就會結出如嬰孩外形的果實。果實會在鬼娃樹的枝頭生長...  219.0
# 202  120.0  10227.0  在外形上與變異殭屍十分相似，但對於兩者是否從屬於同一類的魔物，至今學界仍有分歧。究其原因，大...  153.0
# 203  113.0  10228.0  有很多人好奇為何亡者國度遍地都是南瓜，但如果你曾遭遇過無顱武士的襲擊，那就不會再有這樣的疑惑...  141.0
# 204  117.0  10229.0  在雨檀族的傳說中，靈魂樹是由世界樹的嫩芽栽種而成，而作為靈魂樹的子嗣，苗娃也被視為是繼承了世...  148.0
# 205  119.0  10230.0  從可愛的外形來看，是與亡者國度完全不相符的魔物，不過銀月魔女卻是主動以某些代價和冥界女王換取...  227.0
# 206  116.0  10231.0  傳說中能夠預言死亡的魔物，會穿著由屍布製成的衣物，在黑夜中散播死亡降臨的訊號，因而被人們視為...  146.0
# 207  114.0  10232.0  刺蝟蜻蜓是一種十分溫順的魔物，但絕不能因此就小瞧牠們的破壞力。成年的刺蝟蜻蜓會在破蛹後獲得強...  143.0
# 208  115.0  10233.0  擁有與人類高度相似的外表，實際上卻是由樹木化身的魔物。在習性上仍與植物十分相似，會尋找陽光充...  144.0
# 209  117.0  10234.0  石砲火樹在製作方式上與機木人十分相似，它們的身體由精密的機械構成，外表卻被偽裝成了植物系的魔...  221.0
# 210  118.0  10235.0  比起普通的傘蜥，擁有更加堅韌的外皮及爪牙，以確保牠們能夠挖掘泥土深層的蟲卵為食。不喜陽光，總...   74.0
# 211  112.0  10236.0  雖然被劃分為魔物，但機木人實際上卻更像是一座精密的儀器。它們會日復一日完成固定的行程，無人知...  209.0
#
#        size     attr        race                    loc
# 0     small    earth      insect    Prontera South Gate
# 1     small    earth      insect    Prontera South Gate
# 2     small  neutral       brute    Prontera South Gate
# 3     small   shadow      insect       Capital Sewer 1F
# 4     small     wind      insect                 Morroc
# 5    medium    earth       plant            Payon South
# 6    medium    water        fish              Shipwreck
# 7     small  neutral      insect       Capital Sewer 1F
# 8    medium    earth      insect     Prontera West Gate
# 9     small     fire       brute                 Morroc
# 10   medium     fire       plant                 Morroc
# 11    small  neutral    formless                 Morroc
# 12   medium     wind       brute    Prontera South Gate
# 13    small    earth       brute     Prontera West Gate
# 14    small     fire       brute                 Morroc
# 15    large     fire       brute                 Morroc
# 16    large    earth       plant                 Morroc
# 17   medium     fire      insect                 Morroc
# 18   medium   poison       brute                 Morroc
# 19    small     fire      insect          Sograt Desert
# 20    large  neutral    formless          Sograt Desert
# 21   medium    earth      insect          Sograt Desert
# 22   medium     fire       brute          Sograt Desert
# 23   medium     fire       brute          Sograt Desert
# 24    small     wind      insect      Mjolnir Mountains
# 25    large    water      insect      Mjolnir Mountains
# 26   medium    earth       plant            Payon South
# 27    small     wind      insect      Mjolnir Mountains
# 28   medium    earth      insect       Labyrinth Forest
# 29   medium   poison       brute             Pyramid 1F
# 30   medium    earth      dragon      Mjolnir Mountains
# 31    large     wind      dragon      Mjolnir Mountains
# 32    large     fire       plant      Payon East Forest
# 33   medium    ghost    formless      Payon East Forest
# 34    large    earth       brute             Payon West
# 35    large    earth       brute       Labyrinth Forest
# 36    small    water  demi-human          Sograt Desert
# 37    small   shadow  demi-human          Munak Cave 1F
# 38    small     fire    formless          Munak Cave 2F
# 39    large     fire    formless      Payon East Forest
# 40    small   shadow       brute       Capital Sewer 1F
# 41   medium    water       plant            Payon South
# 42    small    water       plant       Capital Sewer 1F
# 43    small   shadow       brute       Capital Sewer 1F
# 44   medium   shadow      insect       Capital Sewer 1F
# 45   medium   shadow      insect       Capital Sewer 2F
# 46   medium    earth       brute             Payon West
# 47   medium    earth       plant     Prontera West Gate
# 48   medium   poison       plant            Payon South
# 49   medium    earth       brute             Payon West
# 50    small     wind      insect      Mjolnir Mountains
# 51    small     wind      insect      Mjolnir Mountains
# 52    small     wind      insect       Labyrinth Forest
# 53    small    earth       brute       Labyrinth Forest
# 54    small    earth       brute       Labyrinth Forest
# 55    small    earth      insect      Mjolnir Mountains
# 56    small    earth       brute       Labyrinth Forest
# 57   medium   undead      undead          Treasure Ship
# 58    large   undead      undead            Comodo Cave
# 59   medium   poison       plant       Capital Sewer 2F
# 60    small    ghost  demi-human          Treasure Ship
# 61    small    water      insect          Treasure Ship
# 62    small    water       plant          Treasure Ship
# 63    small    water        fish           Kokomo Beach
# 64    small    water        fish        Underwater Cave
# 65    small    water       plant        Underwater Cave
# 66    small    water        fish        Underwater Cave
# 67   medium    water        fish        Underwater Cave
# 68    small    water       plant        Underwater Cave
# 69    large    water        fish      Underwater Temple
# 70   medium    water        fish      Underwater Temple
# 71    small    water        fish      Underwater Temple
# 72   medium    water  demi-human           Kokomo Beach
# 73    small    water        fish      Underwater Temple
# 74    small    water        fish      Underwater Temple
# 75    small    earth      insect             Ant Cavern
# 76    small    earth      insect             Ant Cavern
# 77    small    earth      insect             Ant Cavern
# 78    small    earth      insect             Ant Cavern
# 79    small   shadow       brute       Capital Sewer 2F
# 80    small    earth  demi-human    Mjolnir Dead Pit 1F
# 81    small    earth      insect             Pyramid 2F
# 82   medium   undead      undead              Shipwreck
# 83   medium   undead      undead              Shipwreck
# 84   medium   undead      undead          Munak Cave 1F
# 85   medium   undead      undead          Munak Cave 1F
# 86   medium    water  demi-human          Munak Cave 2F
# 87    small     fire       brute             Payon West
# 88    small    earth       brute    Mjolnir Dead Pit 1F
# 89   medium   undead      undead    Mjolnir Dead Pit 1F
# 90    large   poison    formless    Mjolnir Dead Pit 1F
# 91    large   undead      undead         Clock Tower 1F
# 92   medium   undead      undead          Munak Cave 1F
# 93   medium   undead      undead             Pyramid 1F
# 94   medium   shadow       brute             Pyramid 1F
# 95   medium   undead      undead             Pyramid 1F
# 96   medium   undead      undead             Pyramid 2F
# 97   medium   undead      undead      Geffen Dungeon 1F
# 98    large   shadow  demi-human             Pyramid 2F
# 99    large     fire       brute             Pyramid 2F
# 100   large   poison      insect      Mjolnir Mountains
# 101  medium    earth      insect       Labyrinth Forest
# 102   large    earth       plant      Mjolnir Mountains
# 103   large   poison      insect      Mjolnir Mountains
# 104  medium    water  demi-human          Goblin Forest
# 105  medium    earth  demi-human          Goblin Forest
# 106  medium     fire  demi-human          Goblin Forest
# 107  medium   poison  demi-human          Goblin Forest
# 108  medium     wind  demi-human          Goblin Forest
# 109   small   poison  demi-human          Goblin Forest
# 110  medium     wind  demi-human          Goblin Forest
# 111  medium     fire  demi-human          Sphinx Cavern
# 112  medium   shadow  demi-human          Sphinx Cavern
# 113   large     fire  demi-human          Sphinx Cavern
# 114   large     fire  demi-human          Sphinx Cavern
# 115   large   undead      undead            Orc Dungeon
# 116   large    earth  demi-human            Orc Village
# 117   large   undead      undead            Orc Dungeon
# 118  medium    earth  demi-human            Orc Village
# 119  medium   shadow  demi-human            Orc Dungeon
# 120   small     wind      insect       Labyrinth Forest
# 121  medium    earth  demi-human            Orc Dungeon
# 122   large     fire  demi-human            Orc Village
# 123  medium     fire  demi-human           Kordt Forest
# 124  medium   poison  demi-human           Kordt Forest
# 125   small     fire  demi-human           Kordt Forest
# 126  medium     wind  demi-human           Kordt Forest
# 127   small     fire    formless      Geffen Dungeon 1F
# 128   small    ghost  demi-human      Geffen Dungeon 1F
# 129   small   shadow  demi-human      Geffen Dungeon 2F
# 130   large    ghost  demi-human      Geffen Dungeon 2F
# 131   small   poison       brute         Clock Tower B1
# 132   small     wind       plant         Clock Tower 1F
# 133  medium   shadow  demi-human         Clock Tower 2F
# 134  medium  neutral    formless         Clock Tower B2
# 135  medium    earth    formless         Clock Tower B2
# 136   large  neutral    formless         Clock Tower B2
# 137   small  neutral      insect             Ant Cavern
# 138   large   poison        fish         Clock Tower B1
# 139  medium   undead      undead             Pyramid 1F
# 140   small   undead      undead              Shipwreck
# 141  medium   undead      undead              Shipwreck
# 142  medium    earth      insect       Labyrinth Forest
# 143   large  neutral       brute       Labyrinth Forest
# 144   small   shadow  demi-human       Labyrinth Forest
# 145   small     fire       brute                 Morroc
# 146   large   undead  demi-human          Sphinx Cavern
# 147   large    ghost  demi-human          Munak Cave 2F
# 148  medium   undead      undead          Munak Cave 2F
# 149   small    earth  demi-human            Orc Village
# 150   large     wind  demi-human          Goblin Forest
# 151  medium     wind  demi-human      Geffen Dungeon 2F
# 152   large   undead      undead      Geffen Dungeon 2F
# 153   small     wind  demi-human             Glast Heim
# 154  medium   shadow      undead  Glast Heim Churchyard
# 155  medium   shadow  demi-human   Glast Heim St. Abbey
# 156  medium   shadow  demi-human   Glast Heim St. Abbey
# 157   large     fire       brute             Glast Heim
# 158  medium   undead      undead      Glast Heim Prison
# 159   small     fire      insect         Clock Tower 1F
# 160   large     wind  demi-human         Clock Tower 2F
# 161   small  neutral       brute       Glast Heim Sewer
# 162   small   shadow  demi-human         Clock Tower B1
# 163   small    earth    formless       Glast Heim Sewer
# 164   large   undead      undead         Clock Tower 2F
# 165  medium  neutral  demi-human  Nightmare Clock Tower
# 166  medium   undead      undead      Glast Heim Prison
# 167   large  neutral  demi-human  Glast Heim Churchyard
# 168   large  neutral  demi-human  Nightmare Clock Tower
# 169  medium     wind  demi-human  Nightmare Clock Tower
# 170   large   shadow  demi-human    Glast Heim Chivalry
# 171   large   shadow    formless    Glast Heim Chivalry
# 172   small    earth        fish           Kokomo Beach
# 173   small    water        fish           Kokomo Beach
# 174  medium    water       brute         Sanderman East
# 175   small     wind       brute         Sanderman East
# 176  medium    water        fish           Zenhai Marsh
# 177  medium     wind       plant      Papuchicha Forest
# 178  medium    water        fish      Papuchicha Forest
# 179  medium    earth       brute         Sanderman East
# 180   small   shadow       brute      Papuchicha Forest
# 181   small    earth      insect           Zenhai Marsh
# 182  medium  neutral  demi-human      Papuchicha Forest
# 183   small    earth       brute           Zenhai Marsh
# 184   large    water       brute           Zenhai Marsh
# 185   large  neutral    formless            Comodo Cave
# 186  medium    water       brute         Sanderman East
# 187   large  neutral    formless            Comodo Cave
# 188  medium     wind  demi-human            Comodo Cave
# 189   large   undead      undead            Comodo Cave
# 190   small  neutral  demi-human                    NaN
# 191   large   shadow  demi-human                    NaN
# 192   large   undead      undead            Comodo Cave
# 193   small    earth      insect                    NaN
# 194   large   undead      undead            Comodo Cave
# 195   small    ghost  demi-human                    NaN
# 196  medium    earth  demi-human                    NaN
# 197   small   shadow  demi-human                    NaN
# 198  medium   undead      undead                    NaN
# 199   large     fire  demi-human                    NaN
# 200   small     fire       brute                    NaN
# 201   large   shadow  demi-human                    NaN
# 202  medium   undead      undead                    NaN
# 203  medium   undead      undead                    NaN
# 204  medium     wind       plant                    NaN
# 205   large   shadow  demi-human                    NaN
# 206  medium   shadow  demi-human                    NaN
# 207  medium     wind      insect                    NaN
# 208  medium    earth       plant                    NaN
# 209   large     fire       plant                    NaN
# 210   small    earth       brute                    NaN
# 211   large    earth       plant                    NaN

# %% [markdown]
# #### Save data for database

# %%
monster_final_df.to_csv(f"{MAIN_PARSED_DIR}/monster_tw_{APK_DATE}.csv", index=False)
